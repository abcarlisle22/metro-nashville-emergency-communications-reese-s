# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster
import json

from folium.features import GeoJson, GeoJsonTooltip, GeoJsonPopup

# %matplotlib inline

# %%
tornado_calls = pd.read_csv('data/tornado_calls.csv')
tornado_calls.head()
# Out:
#   Seizure DateTime CallTypeId  ALI Latitude  ALI Longitude  \
# 0    3/3/2020 0:34  911 Calls     36.072708     -86.665779
# 1    3/3/2020 0:36  911 Calls     36.159634     -86.841904
# 2    3/3/2020 0:36  911 Calls     36.264153     -86.708862
# 3    3/3/2020 0:36  911 Calls           NaN            NaN
# 4    3/3/2020 0:36  911 Calls     36.233467     -86.721077
#
#            Cell Tower Address
# 0  620 Richards RD - N Sector
# 1      4507D KENTUCKY AV - SE
# 2    329 THELMA ST - S Sector
# 3              526 FOUNDRY DR
# 4        5007B RUSKIN AVE - N

# %%
tornado_calls.shape
# Out:
# (475, 5)

# %%
tornado_calls = tornado_calls.dropna(subset=['ALI Longitude'])
tornado_calls = tornado_calls.dropna(subset=['ALI Latitude'])

# %%
tornado_calls.shape
# Out:
# (450, 5)

# %%
tornado_dispatch = pd.read_csv('data/tornado_dispatch.csv', skiprows=3)
tornado_dispatch.head()
# Out:
#            IncidentDate                  Location  Latitude1  Longitude1  \
# 0  3/3/2020 12:36:34 AM   6205 COCKRILL BEND CIR   36.182002  -86.894052
# 1  3/3/2020 12:37:24 AM  7337 COCKRILL BEND BLVD   36.175666  -86.894978
# 2  3/3/2020 12:38:17 AM      110 TUNE AIRPORT DR   36.179299  -86.883727
# 3  3/3/2020 12:39:40 AM          555 MARRIOTT DR   36.151108  -86.689921
# 4  3/3/2020 12:39:42 AM  1414 COUNTY HOSPITAL RD   36.177926  -86.845934
#
#                       IncidentTypeDescription1
# 0  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 1  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 2       STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# 3  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# 4  GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD

# %%
tornado_dispatch.shape
# Out:
# (260, 5)

# %%
tornado_dispatch.value_counts(['IncidentTypeDescription1'])
# Out:
# IncidentTypeDescription1
# GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD    27
# OUTSIDE ODOR                                   26
# WIRES DOWN WITH NO SMOKE OR ARCING             17
# SMALL BUILDING INVESTIGATION                   15
# ELECTRICAL HAZARD WITH OR NEAR WATER           12
#                                                ..
# HOUSE FIRE                                      1
# HIGH LIFE HAZARD   ODOR WITH PATIENT            1
# HEART PROBLEMS UNKNOWN STATUS                   1
# GENERAL ALARM HIGH LIFE HAZARD                  1
# ABDOMINAL PAIN - NOT ALERT                      1
# Length: 90, dtype: int64

# %%
derecho_calls = pd.read_csv('data/derecho_calls.csv')
derecho_calls.head()
# Out:
#   Seizure DateTime CallTypeId  ALI Latitude  ALI Longitude  \
# 0   5/3/2020 16:30  911 Calls     36.247802     -86.716847
# 1   5/3/2020 16:30  911 Calls     36.143108     -86.800621
# 2   5/3/2020 16:30  911 Calls     36.100516     -87.056329
# 3   5/3/2020 16:30  911 Calls     36.130021     -86.927819
# 4   5/3/2020 16:31  911 Calls     36.142380     -86.881882
#
#       Cell Tower Address
# 0        WIRELESS CALLER
# 1    1161 21ST AV S - SE
# 2  8013 C MCCRORY LN - N
# 3     5758 RIVER RD - SW
# 4   3744B ANNEX AVE - SE

# %%
derecho_calls.shape
# Out:
# (1549, 5)

# %%
derecho_calls = derecho_calls.dropna(subset=['ALI Longitude'])
derecho_calls = derecho_calls.dropna(subset=['ALI Latitude'])

# %%
derecho_calls.shape
# Out:
# (1483, 5)

# %%
derecho_dispatch = pd.read_csv('data/derecho_dispatch.csv', skiprows=3)
derecho_dispatch.head()
# Out:
#           IncidentDate            Location  Latitude1  Longitude1  \
# 0  5/3/2020 4:31:07 PM    901 KENWICK CT W  36.046877  -86.962526
# 1  5/3/2020 4:32:18 PM       8036 ARBOR DR  36.082491  -86.940680
# 2  5/3/2020 4:32:23 PM   119 DUE WEST AV E  36.248029  -86.716875
# 3  5/3/2020 4:33:04 PM  630 GALLATIN PKE S  36.256491  -86.714817
# 4  5/3/2020 4:33:52 PM   615 W HILLWOOD DR  36.129690  -86.879834
#
#   IncidentTypeDescription1
# 0        ELECTRICAL HAZARD
# 1        ELECTRICAL HAZARD
# 2           NOT ALERT COPD
# 3           ABDOMINAL PAIN
# 4        ELECTRICAL HAZARD

# %%
derecho_dispatch.shape
# Out:
# (627, 5)

# %%
derecho_dispatch.value_counts('IncidentTypeDescription1')
# Out:
# IncidentTypeDescription1
# ELECTRICAL HAZARD                              370
# GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD     23
# MVA INJURIES:                                    8
# UNKNOWN STATUS:                                  6
# SMALL BUILDING INVESTIGATION                     6
#                                               ...
# NOT ALERT COPD                                   1
# NOT ALERT STRONG EVIDENCE <3 HOURS               1
# OBVIOUS DEATH                                    1
# OTHER PAIN                                       1
# 3RD TRIMESTER HEMORRHAGE                         1
# Length: 122, dtype: int64

# %%
for row in tornado_calls.iterrows():
    print('row: ', row, '\n')
    print('first item: ', row[0], '\n')
    print('second item: ', row[1], '\n')
# Out:
# row:  (0, Seizure DateTime                   3/3/2020 0:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.0727
# ALI Longitude                           -86.6658
# Cell Tower Address    620 Richards RD - N Sector
# Name: 0, dtype: object)
#
# first item:  0
#
# second item:  Seizure DateTime                   3/3/2020 0:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.0727
# ALI Longitude                           -86.6658
# Cell Tower Address    620 Richards RD - N Sector
# Name: 0, dtype: object
#
# row:  (1, Seizure DateTime               3/3/2020 0:36
# CallTypeId                         911 Calls
# ALI Latitude                         36.1596
# ALI Longitude                       -86.8419
# Cell Tower Address    4507D KENTUCKY AV - SE
# Name: 1, dtype: object)
#
# first item:  1
#
# second item:  Seizure DateTime               3/3/2020 0:36
# CallTypeId                         911 Calls
# ALI Latitude                         36.1596
# ALI Longitude                       -86.8419
# Cell Tower Address    4507D KENTUCKY AV - SE
# Name: 1, dtype: object
#
# row:  (2, Seizure DateTime                 3/3/2020 0:36
# CallTypeId                           911 Calls
# ALI Latitude                           36.2642
# ALI Longitude                         -86.7089
# Cell Tower Address    329 THELMA ST - S Sector
# Name: 2, dtype: object)
#
# first item:  2
#
# second item:  Seizure DateTime                 3/3/2020 0:36
# CallTypeId                           911 Calls
# ALI Latitude                           36.2642
# ALI Longitude                         -86.7089
# Cell Tower Address    329 THELMA ST - S Sector
# Name: 2, dtype: object
#
# row:  (4, Seizure DateTime             3/3/2020 0:36
# CallTypeId                       911 Calls
# ALI Latitude                       36.2335
# ALI Longitude                     -86.7211
# Cell Tower Address    5007B RUSKIN AVE - N
# Name: 4, dtype: object)
#
# first item:  4
#
# second item:  Seizure DateTime             3/3/2020 0:36
# CallTypeId                       911 Calls
# ALI Latitude                       36.2335
# ALI Longitude                     -86.7211
# Cell Tower Address    5007B RUSKIN AVE - N
# Name: 4, dtype: object
#
# row:  (5, Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                   36.149
# ALI Longitude                -86.7957
# Cell Tower Address    WIRELESS CALLER
# Name: 5, dtype: object)
#
# first item:  5
#
# second item:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                   36.149
# ALI Longitude                -86.7957
# Cell Tower Address    WIRELESS CALLER
# Name: 5, dtype: object
#
# row:  (6, Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1758
# ALI Longitude                -86.8957
# Cell Tower Address    WIRELESS CALLER
# Name: 6, dtype: object)
#
# first item:  6
#
# second item:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1758
# ALI Longitude                -86.8957
# Cell Tower Address    WIRELESS CALLER
# Name: 6, dtype: object
#
# row:  (7, Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1805
# ALI Longitude                -86.8837
# Cell Tower Address    WIRELESS CALLER
# Name: 7, dtype: object)
#
# first item:  7
#
# second item:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1805
# ALI Longitude                -86.8837
# Cell Tower Address    WIRELESS CALLER
# Name: 7, dtype: object
#
# row:  (8, Seizure DateTime                         3/3/2020 0:38
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.071
# ALI Longitude                                   -86.94
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 8, dtype: object)
#
# first item:  8
#
# second item:  Seizure DateTime                         3/3/2020 0:38
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.071
# ALI Longitude                                   -86.94
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 8, dtype: object
#
# row:  (9, Seizure DateTime      3/3/2020 0:38
# CallTypeId                911 Calls
# ALI Latitude                36.1632
# ALI Longitude              -86.7797
# Cell Tower Address    415 CHURCH ST
# Name: 9, dtype: object)
#
# first item:  9
#
# second item:  Seizure DateTime      3/3/2020 0:38
# CallTypeId                911 Calls
# ALI Latitude                36.1632
# ALI Longitude              -86.7797
# Cell Tower Address    415 CHURCH ST
# Name: 9, dtype: object
#
# row:  (10, Seizure DateTime                  3/3/2020 0:38
# CallTypeId                            911 Calls
# ALI Latitude                            36.0521
# ALI Longitude                          -86.6483
# Cell Tower Address    745 BELL RD - OMNI Sector
# Name: 10, dtype: object)
#
# first item:  10
#
# second item:  Seizure DateTime                  3/3/2020 0:38
# CallTypeId                            911 Calls
# ALI Latitude                            36.0521
# ALI Longitude                          -86.6483
# Cell Tower Address    745 BELL RD - OMNI Sector
# Name: 10, dtype: object
#
# row:  (11, Seizure DateTime          3/3/2020 0:39
# CallTypeId                    911 Calls
# ALI Latitude                    36.1732
# ALI Longitude                  -86.7973
# Cell Tower Address    907 12TH AV N - N
# Name: 11, dtype: object)
#
# first item:  11
#
# second item:  Seizure DateTime          3/3/2020 0:39
# CallTypeId                    911 Calls
# ALI Latitude                    36.1732
# ALI Longitude                  -86.7973
# Cell Tower Address    907 12TH AV N - N
# Name: 11, dtype: object
#
# row:  (12, Seizure DateTime           3/3/2020 0:39
# CallTypeId                     911 Calls
# ALI Latitude                     36.1549
# ALI Longitude                   -86.7634
# Cell Tower Address    18B ACADEMY PL - E
# Name: 12, dtype: object)
#
# first item:  12
#
# second item:  Seizure DateTime           3/3/2020 0:39
# CallTypeId                     911 Calls
# ALI Latitude                     36.1549
# ALI Longitude                   -86.7634
# Cell Tower Address    18B ACADEMY PL - E
# Name: 12, dtype: object
#
# row:  (13, Seizure DateTime                                3/3/2020 0:40
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 13, dtype: object)
#
# first item:  13
#
# second item:  Seizure DateTime                                3/3/2020 0:40
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 13, dtype: object
#
# row:  (14, Seizure DateTime                         3/3/2020 0:40
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0796
# ALI Longitude                                 -86.9334
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 14, dtype: object)
#
# first item:  14
#
# second item:  Seizure DateTime                         3/3/2020 0:40
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0796
# ALI Longitude                                 -86.9334
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 14, dtype: object
#
# row:  (15, Seizure DateTime                   3/3/2020 0:40
# CallTypeId                             911 Calls
# ALI Latitude                             36.1039
# ALI Longitude                           -86.7978
# Cell Tower Address    3901 GRANNY WHITE PIKE - N
# Name: 15, dtype: object)
#
# first item:  15
#
# second item:  Seizure DateTime                   3/3/2020 0:40
# CallTypeId                             911 Calls
# ALI Latitude                             36.1039
# ALI Longitude                           -86.7978
# Cell Tower Address    3901 GRANNY WHITE PIKE - N
# Name: 15, dtype: object
#
# row:  (16, Seizure DateTime                   3/3/2020 0:41
# CallTypeId                             911 Calls
# ALI Latitude                             36.1206
# ALI Longitude                           -86.8045
# Cell Tower Address    2505 21ST AV - SECTOR SE S
# Name: 16, dtype: object)
#
# first item:  16
#
# second item:  Seizure DateTime                   3/3/2020 0:41
# CallTypeId                             911 Calls
# ALI Latitude                             36.1206
# ALI Longitude                           -86.8045
# Cell Tower Address    2505 21ST AV - SECTOR SE S
# Name: 16, dtype: object
#
# row:  (17, Seizure DateTime                                3/3/2020 0:41
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 17, dtype: object)
#
# first item:  17
#
# second item:  Seizure DateTime                                3/3/2020 0:41
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 17, dtype: object
#
# row:  (18, Seizure DateTime                          3/3/2020 0:41
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1834
# ALI Longitude                                  -86.7716
# Cell Tower Address    1608 ROSA L PARKS BLVD - E Sector
# Name: 18, dtype: object)
#
# first item:  18
#
# second item:  Seizure DateTime                          3/3/2020 0:41
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1834
# ALI Longitude                                  -86.7716
# Cell Tower Address    1608 ROSA L PARKS BLVD - E Sector
# Name: 18, dtype: object
#
# row:  (19, Seizure DateTime                 3/3/2020 0:41
# CallTypeId                           911 Calls
# ALI Latitude                           36.1754
# ALI Longitude                         -86.7827
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 19, dtype: object)
#
# first item:  19
#
# second item:  Seizure DateTime                 3/3/2020 0:41
# CallTypeId                           911 Calls
# ALI Latitude                           36.1754
# ALI Longitude                         -86.7827
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 19, dtype: object
#
# row:  (20, Seizure DateTime        3/3/2020 0:41
# CallTypeId                  911 Calls
# ALI Latitude                  36.1663
# ALI Longitude                -86.8539
# Cell Tower Address    WIRELESS CALLER
# Name: 20, dtype: object)
#
# first item:  20
#
# second item:  Seizure DateTime        3/3/2020 0:41
# CallTypeId                  911 Calls
# ALI Latitude                  36.1663
# ALI Longitude                -86.8539
# Cell Tower Address    WIRELESS CALLER
# Name: 20, dtype: object
#
# row:  (21, Seizure DateTime                         3/3/2020 0:41
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 21, dtype: object)
#
# first item:  21
#
# second item:  Seizure DateTime                         3/3/2020 0:41
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 21, dtype: object
#
# row:  (22, Seizure DateTime                        3/3/2020 0:41
# CallTypeId                                  911 Calls
# ALI Latitude                                    36.22
# ALI Longitude                                -86.8064
# Cell Tower Address    615 Moormans Arm RD - Sector NW
# Name: 22, dtype: object)
#
# first item:  22
#
# second item:  Seizure DateTime                        3/3/2020 0:41
# CallTypeId                                  911 Calls
# ALI Latitude                                    36.22
# ALI Longitude                                -86.8064
# Cell Tower Address    615 Moormans Arm RD - Sector NW
# Name: 22, dtype: object
#
# row:  (23, Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1772
# ALI Longitude                -86.8787
# Cell Tower Address    WIRELESS CALLER
# Name: 23, dtype: object)
#
# first item:  23
#
# second item:  Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1772
# ALI Longitude                -86.8787
# Cell Tower Address    WIRELESS CALLER
# Name: 23, dtype: object
#
# row:  (24, Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 24, dtype: object)
#
# first item:  24
#
# second item:  Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 24, dtype: object
#
# row:  (25, Seizure DateTime                                3/3/2020 0:42
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 25, dtype: object)
#
# first item:  25
#
# second item:  Seizure DateTime                                3/3/2020 0:42
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 25, dtype: object
#
# row:  (26, Seizure DateTime                         3/3/2020 0:42
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 26, dtype: object)
#
# first item:  26
#
# second item:  Seizure DateTime                         3/3/2020 0:42
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 26, dtype: object
#
# row:  (27, Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1742
# ALI Longitude                 -86.806
# Cell Tower Address    WIRELESS CALLER
# Name: 27, dtype: object)
#
# first item:  27
#
# second item:  Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1742
# ALI Longitude                 -86.806
# Cell Tower Address    WIRELESS CALLER
# Name: 27, dtype: object
#
# row:  (28, Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 28, dtype: object)
#
# first item:  28
#
# second item:  Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 28, dtype: object
#
# row:  (29, Seizure DateTime                    3/3/2020 0:42
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608F ROSA L PARKS BLVD - S
# Name: 29, dtype: object)
#
# first item:  29
#
# second item:  Seizure DateTime                    3/3/2020 0:42
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608F ROSA L PARKS BLVD - S
# Name: 29, dtype: object
#
# row:  (30, Seizure DateTime              3/3/2020 0:43
# CallTypeId                        911 Calls
# ALI Latitude                        36.1515
# ALI Longitude                      -86.7888
# Cell Tower Address    1313 DIVISION ST - OM
# Name: 30, dtype: object)
#
# first item:  30
#
# second item:  Seizure DateTime              3/3/2020 0:43
# CallTypeId                        911 Calls
# ALI Latitude                        36.1515
# ALI Longitude                      -86.7888
# Cell Tower Address    1313 DIVISION ST - OM
# Name: 30, dtype: object
#
# row:  (31, Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1759
# ALI Longitude                                   -86.7808
# Cell Tower Address    300 JAMES ROBERTSON PKY - N Sector
# Name: 31, dtype: object)
#
# first item:  31
#
# second item:  Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1759
# ALI Longitude                                   -86.7808
# Cell Tower Address    300 JAMES ROBERTSON PKY - N Sector
# Name: 31, dtype: object
#
# row:  (32, Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 32, dtype: object)
#
# first item:  32
#
# second item:  Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 32, dtype: object
#
# row:  (33, Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 33, dtype: object)
#
# first item:  33
#
# second item:  Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 33, dtype: object
#
# row:  (34, Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.3226
# ALI Longitude                            -86.8674
# Cell Tower Address    945 CLAY LICK CT - SECTOR N
# Name: 34, dtype: object)
#
# first item:  34
#
# second item:  Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.3226
# ALI Longitude                            -86.8674
# Cell Tower Address    945 CLAY LICK CT - SECTOR N
# Name: 34, dtype: object
#
# row:  (35, Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1677
# ALI Longitude                                   -86.7802
# Cell Tower Address    410 JAMES ROBERTSON PKY - N Sector
# Name: 35, dtype: object)
#
# first item:  35
#
# second item:  Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1677
# ALI Longitude                                   -86.7802
# Cell Tower Address    410 JAMES ROBERTSON PKY - N Sector
# Name: 35, dtype: object
#
# row:  (36, Seizure DateTime                                3/3/2020 0:43
# CallTypeId                                          911 Calls
# ALI Latitude                                          36.1793
# ALI Longitude                                        -86.8835
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 36, dtype: object)
#
# first item:  36
#
# second item:  Seizure DateTime                                3/3/2020 0:43
# CallTypeId                                          911 Calls
# ALI Latitude                                          36.1793
# ALI Longitude                                        -86.8835
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 36, dtype: object
#
# row:  (37, Seizure DateTime           3/3/2020 0:43
# CallTypeId                     911 Calls
# ALI Latitude                     36.1753
# ALI Longitude                    -86.782
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 37, dtype: object)
#
# first item:  37
#
# second item:  Seizure DateTime           3/3/2020 0:43
# CallTypeId                     911 Calls
# ALI Latitude                     36.1753
# ALI Longitude                    -86.782
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 37, dtype: object
#
# row:  (38, Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                   36.173
# ALI Longitude                -86.8049
# Cell Tower Address    WIRELESS CALLER
# Name: 38, dtype: object)
#
# first item:  38
#
# second item:  Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                   36.173
# ALI Longitude                -86.8049
# Cell Tower Address    WIRELESS CALLER
# Name: 38, dtype: object
#
# row:  (39, Seizure DateTime                             3/3/2020 0:43
# CallTypeId                                       911 Calls
# ALI Latitude                                        36.176
# ALI Longitude                                      -86.894
# Cell Tower Address    1816 LINDER INDUSTRIAL DR - W SECTOR
# Name: 39, dtype: object)
#
# first item:  39
#
# second item:  Seizure DateTime                             3/3/2020 0:43
# CallTypeId                                       911 Calls
# ALI Latitude                                        36.176
# ALI Longitude                                      -86.894
# Cell Tower Address    1816 LINDER INDUSTRIAL DR - W SECTOR
# Name: 39, dtype: object
#
# row:  (40, Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                  36.1754
# ALI Longitude                -86.7866
# Cell Tower Address    WIRELESS CALLER
# Name: 40, dtype: object)
#
# first item:  40
#
# second item:  Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                  36.1754
# ALI Longitude                -86.7866
# Cell Tower Address    WIRELESS CALLER
# Name: 40, dtype: object
#
# row:  (41, Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608-B 8TH AV - SECTOR SW N
# Name: 41, dtype: object)
#
# first item:  41
#
# second item:  Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608-B 8TH AV - SECTOR SW N
# Name: 41, dtype: object
#
# row:  (42, Seizure DateTime                  3/3/2020 0:44
# CallTypeId                            911 Calls
# ALI Latitude                            36.1752
# ALI Longitude                          -86.7812
# Cell Tower Address    2301 BOOKER ST - E SECTOR
# Name: 42, dtype: object)
#
# first item:  42
#
# second item:  Seizure DateTime                  3/3/2020 0:44
# CallTypeId                            911 Calls
# ALI Latitude                            36.1752
# ALI Longitude                          -86.7812
# Cell Tower Address    2301 BOOKER ST - E SECTOR
# Name: 42, dtype: object
#
# row:  (43, Seizure DateTime          3/3/2020 0:44
# CallTypeId                    911 Calls
# ALI Latitude                    36.1675
# ALI Longitude                  -86.7968
# Cell Tower Address    907 12TH AV N - N
# Name: 43, dtype: object)
#
# first item:  43
#
# second item:  Seizure DateTime          3/3/2020 0:44
# CallTypeId                    911 Calls
# ALI Latitude                    36.1675
# ALI Longitude                  -86.7968
# Cell Tower Address    907 12TH AV N - N
# Name: 43, dtype: object
#
# row:  (44, Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.1747
# ALI Longitude                             -86.7871
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 44, dtype: object)
#
# first item:  44
#
# second item:  Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.1747
# ALI Longitude                             -86.7871
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 44, dtype: object
#
# row:  (45, Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1544
# ALI Longitude                            -86.8292
# Cell Tower Address    435 B 37TH AVE N - N Sector
# Name: 45, dtype: object)
#
# first item:  45
#
# second item:  Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1544
# ALI Longitude                            -86.8292
# Cell Tower Address    435 B 37TH AVE N - N Sector
# Name: 45, dtype: object
#
# row:  (46, Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                            36.185
# ALI Longitude                         -86.7483
# Cell Tower Address    1051G CHICAMAUGA AVE - S
# Name: 46, dtype: object)
#
# first item:  46
#
# second item:  Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                            36.185
# ALI Longitude                         -86.7483
# Cell Tower Address    1051G CHICAMAUGA AVE - S
# Name: 46, dtype: object
#
# row:  (47, Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                           36.1747
# ALI Longitude                          -86.783
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 47, dtype: object)
#
# first item:  47
#
# second item:  Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                           36.1747
# ALI Longitude                          -86.783
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 47, dtype: object
#
# row:  (48, Seizure DateTime            3/3/2020 0:44
# CallTypeId                      911 Calls
# ALI Latitude                      36.1431
# ALI Longitude                    -86.8006
# Cell Tower Address    1161 21ST AV S - SE
# Name: 48, dtype: object)
#
# first item:  48
#
# second item:  Seizure DateTime            3/3/2020 0:44
# CallTypeId                      911 Calls
# ALI Latitude                      36.1431
# ALI Longitude                    -86.8006
# Cell Tower Address    1161 21ST AV S - SE
# Name: 48, dtype: object
#
# row:  (49, Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.2455
# ALI Longitude                              -86.838
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 49, dtype: object)
#
# first item:  49
#
# second item:  Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.2455
# ALI Longitude                              -86.838
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 49, dtype: object
#
# row:  (50, Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1785
# ALI Longitude                            -86.7745
# Cell Tower Address    10 C LUCILLE ST - SE SECTOR
# Name: 50, dtype: object)
#
# first item:  50
#
# second item:  Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1785
# ALI Longitude                            -86.7745
# Cell Tower Address    10 C LUCILLE ST - SE SECTOR
# Name: 50, dtype: object
#
# row:  (51, Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                            36.1962
# ALI Longitude                          -86.7741
# Cell Tower Address    10D LUCILE ST - SECTOR SE
# Name: 51, dtype: object)
#
# first item:  51
#
# second item:  Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                            36.1962
# ALI Longitude                          -86.7741
# Cell Tower Address    10D LUCILE ST - SECTOR SE
# Name: 51, dtype: object
#
# row:  (52, Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1751
# ALI Longitude                                -86.7862
# Cell Tower Address    5043 HILLSBORO PIKE - SECTOR NE
# Name: 52, dtype: object)
#
# first item:  52
#
# second item:  Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1751
# ALI Longitude                                -86.7862
# Cell Tower Address    5043 HILLSBORO PIKE - SECTOR NE
# Name: 52, dtype: object
#
# row:  (53, Seizure DateTime        3/3/2020 0:45
# CallTypeId                  911 Calls
# ALI Latitude                   36.171
# ALI Longitude                -86.7906
# Cell Tower Address    WIRELESS CALLER
# Name: 53, dtype: object)
#
# first item:  53
#
# second item:  Seizure DateTime        3/3/2020 0:45
# CallTypeId                  911 Calls
# ALI Latitude                   36.171
# ALI Longitude                -86.7906
# Cell Tower Address    WIRELESS CALLER
# Name: 53, dtype: object
#
# row:  (54, Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1774
# ALI Longitude                                 -86.754
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 54, dtype: object)
#
# first item:  54
#
# second item:  Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1774
# ALI Longitude                                 -86.754
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 54, dtype: object
#
# row:  (55, Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 55, dtype: object)
#
# first item:  55
#
# second item:  Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 55, dtype: object
#
# row:  (56, Seizure DateTime           3/3/2020 0:45
# CallTypeId                     911 Calls
# ALI Latitude                      36.177
# ALI Longitude                   -86.7781
# Cell Tower Address    19C OLDHAM ST - SE
# Name: 56, dtype: object)
#
# first item:  56
#
# second item:  Seizure DateTime           3/3/2020 0:45
# CallTypeId                     911 Calls
# ALI Latitude                      36.177
# ALI Longitude                   -86.7781
# Cell Tower Address    19C OLDHAM ST - SE
# Name: 56, dtype: object
#
# row:  (57, Seizure DateTime          3/3/2020 0:47
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 57, dtype: object)
#
# first item:  57
#
# second item:  Seizure DateTime          3/3/2020 0:47
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 57, dtype: object
#
# row:  (58, Seizure DateTime              3/3/2020 0:50
# CallTypeId                        911 Calls
# ALI Latitude                        36.1679
# ALI Longitude                      -86.8158
# Cell Tower Address    2101 E HEIMAN ST - SW
# Name: 58, dtype: object)
#
# first item:  58
#
# second item:  Seizure DateTime              3/3/2020 0:50
# CallTypeId                        911 Calls
# ALI Latitude                        36.1679
# ALI Longitude                      -86.8158
# Cell Tower Address    2101 E HEIMAN ST - SW
# Name: 58, dtype: object
#
# row:  (59, Seizure DateTime           3/3/2020 0:50
# CallTypeId                     911 Calls
# ALI Latitude                     36.1751
# ALI Longitude                   -86.7822
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 59, dtype: object)
#
# first item:  59
#
# second item:  Seizure DateTime           3/3/2020 0:50
# CallTypeId                     911 Calls
# ALI Latitude                     36.1751
# ALI Longitude                   -86.7822
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 59, dtype: object
#
# row:  (60, Seizure DateTime          3/3/2020 0:51
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 60, dtype: object)
#
# first item:  60
#
# second item:  Seizure DateTime          3/3/2020 0:51
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 60, dtype: object
#
# row:  (61, Seizure DateTime                  3/3/2020 0:51
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 61, dtype: object)
#
# first item:  61
#
# second item:  Seizure DateTime                  3/3/2020 0:51
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 61, dtype: object
#
# row:  (62, Seizure DateTime          3/3/2020 0:52
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 62, dtype: object)
#
# first item:  62
#
# second item:  Seizure DateTime          3/3/2020 0:52
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 62, dtype: object
#
# row:  (63, Seizure DateTime           3/3/2020 0:52
# CallTypeId                     911 Calls
# ALI Latitude                     36.1735
# ALI Longitude                   -86.7856
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 63, dtype: object)
#
# first item:  63
#
# second item:  Seizure DateTime           3/3/2020 0:52
# CallTypeId                     911 Calls
# ALI Latitude                     36.1735
# ALI Longitude                   -86.7856
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 63, dtype: object
#
# row:  (64, Seizure DateTime            3/3/2020 0:53
# CallTypeId                      911 Calls
# ALI Latitude                        36.05
# ALI Longitude                    -86.6506
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 64, dtype: object)
#
# first item:  64
#
# second item:  Seizure DateTime            3/3/2020 0:53
# CallTypeId                      911 Calls
# ALI Latitude                        36.05
# ALI Longitude                    -86.6506
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 64, dtype: object
#
# row:  (65, Seizure DateTime                          3/3/2020 0:53
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1704
# ALI Longitude                                  -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - SW Sector
# Name: 65, dtype: object)
#
# first item:  65
#
# second item:  Seizure DateTime                          3/3/2020 0:53
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1704
# ALI Longitude                                  -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - SW Sector
# Name: 65, dtype: object
#
# row:  (66, Seizure DateTime             3/3/2020 0:54
# CallTypeId                       911 Calls
# ALI Latitude                       36.1744
# ALI Longitude                     -86.7271
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 66, dtype: object)
#
# first item:  66
#
# second item:  Seizure DateTime             3/3/2020 0:54
# CallTypeId                       911 Calls
# ALI Latitude                       36.1744
# ALI Longitude                     -86.7271
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 66, dtype: object
#
# row:  (67, Seizure DateTime        3/3/2020 0:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1737
# ALI Longitude                -86.8088
# Cell Tower Address    WIRELESS CALLER
# Name: 67, dtype: object)
#
# first item:  67
#
# second item:  Seizure DateTime        3/3/2020 0:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1737
# ALI Longitude                -86.8088
# Cell Tower Address    WIRELESS CALLER
# Name: 67, dtype: object
#
# row:  (69, Seizure DateTime               3/3/2020 0:54
# CallTypeId                         911 Calls
# ALI Latitude                          36.187
# ALI Longitude                       -86.6281
# Cell Tower Address    3333 LEBANON PIKE - SW
# Name: 69, dtype: object)
#
# first item:  69
#
# second item:  Seizure DateTime               3/3/2020 0:54
# CallTypeId                         911 Calls
# ALI Latitude                          36.187
# ALI Longitude                       -86.6281
# Cell Tower Address    3333 LEBANON PIKE - SW
# Name: 69, dtype: object
#
# row:  (71, Seizure DateTime          3/3/2020 0:55
# CallTypeId                    911 Calls
# ALI Latitude                    36.1755
# ALI Longitude                  -86.7867
# Cell Tower Address    907 12TH AV N - N
# Name: 71, dtype: object)
#
# first item:  71
#
# second item:  Seizure DateTime          3/3/2020 0:55
# CallTypeId                    911 Calls
# ALI Latitude                    36.1755
# ALI Longitude                  -86.7867
# Cell Tower Address    907 12TH AV N - N
# Name: 71, dtype: object
#
# row:  (72, Seizure DateTime                          3/3/2020 0:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1351
# ALI Longitude                                  -86.8113
# Cell Tower Address    1301 MEDICAL CENTER DR - S Sector
# Name: 72, dtype: object)
#
# first item:  72
#
# second item:  Seizure DateTime                          3/3/2020 0:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1351
# ALI Longitude                                  -86.8113
# Cell Tower Address    1301 MEDICAL CENTER DR - S Sector
# Name: 72, dtype: object
#
# row:  (73, Seizure DateTime               3/3/2020 0:56
# CallTypeId                         911 Calls
# ALI Latitude                         36.1725
# ALI Longitude                       -86.5761
# Cell Tower Address    4316 CENTRAL PIKE - SE
# Name: 73, dtype: object)
#
# first item:  73
#
# second item:  Seizure DateTime               3/3/2020 0:56
# CallTypeId                         911 Calls
# ALI Latitude                         36.1725
# ALI Longitude                       -86.5761
# Cell Tower Address    4316 CENTRAL PIKE - SE
# Name: 73, dtype: object
#
# row:  (75, Seizure DateTime          3/3/2020 0:58
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 75, dtype: object)
#
# first item:  75
#
# second item:  Seizure DateTime          3/3/2020 0:58
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 75, dtype: object
#
# row:  (76, Seizure DateTime                  3/3/2020 0:58
# CallTypeId                            911 Calls
# ALI Latitude                            36.1704
# ALI Longitude                          -86.8017
# Cell Tower Address    179 8TH AVE N - NW SECTOR
# Name: 76, dtype: object)
#
# first item:  76
#
# second item:  Seizure DateTime                  3/3/2020 0:58
# CallTypeId                            911 Calls
# ALI Latitude                            36.1704
# ALI Longitude                          -86.8017
# Cell Tower Address    179 8TH AVE N - NW SECTOR
# Name: 76, dtype: object
#
# row:  (77, Seizure DateTime                    3/3/2020 0:58
# CallTypeId                              911 Calls
# ALI Latitude                              36.1796
# ALI Longitude                            -86.6005
# Cell Tower Address    5655 FIRST BLVD - SECTOR NE
# Name: 77, dtype: object)
#
# first item:  77
#
# second item:  Seizure DateTime                    3/3/2020 0:58
# CallTypeId                              911 Calls
# ALI Latitude                              36.1796
# ALI Longitude                            -86.6005
# Cell Tower Address    5655 FIRST BLVD - SECTOR NE
# Name: 77, dtype: object
#
# row:  (78, Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                   36.175
# ALI Longitude                                -86.7819
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 78, dtype: object)
#
# first item:  78
#
# second item:  Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                   36.175
# ALI Longitude                                -86.7819
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 78, dtype: object
#
# row:  (79, Seizure DateTime                              3/3/2020 0:58
# CallTypeId                                        911 Calls
# ALI Latitude                                        36.0721
# ALI Longitude                                      -86.6368
# Cell Tower Address    2747-B MURFREESBORO PKE - SECTOR SWNE
# Name: 79, dtype: object)
#
# first item:  79
#
# second item:  Seizure DateTime                              3/3/2020 0:58
# CallTypeId                                        911 Calls
# ALI Latitude                                        36.0721
# ALI Longitude                                      -86.6368
# Cell Tower Address    2747-B MURFREESBORO PKE - SECTOR SWNE
# Name: 79, dtype: object
#
# row:  (80, Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1706
# ALI Longitude                -86.7914
# Cell Tower Address    WIRELESS CALLER
# Name: 80, dtype: object)
#
# first item:  80
#
# second item:  Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1706
# ALI Longitude                -86.7914
# Cell Tower Address    WIRELESS CALLER
# Name: 80, dtype: object
#
# row:  (81, Seizure DateTime            3/3/2020 0:58
# CallTypeId                      911 Calls
# ALI Latitude                      36.1732
# ALI Longitude                    -86.7852
# Cell Tower Address    401 JACKSON ST - NW
# Name: 81, dtype: object)
#
# first item:  81
#
# second item:  Seizure DateTime            3/3/2020 0:58
# CallTypeId                      911 Calls
# ALI Latitude                      36.1732
# ALI Longitude                    -86.7852
# Cell Tower Address    401 JACKSON ST - NW
# Name: 81, dtype: object
#
# row:  (82, Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1752
# ALI Longitude                -86.7412
# Cell Tower Address    WIRELESS CALLER
# Name: 82, dtype: object)
#
# first item:  82
#
# second item:  Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1752
# ALI Longitude                -86.7412
# Cell Tower Address    WIRELESS CALLER
# Name: 82, dtype: object
#
# row:  (83, Seizure DateTime             3/3/2020 0:58
# CallTypeId                       911 Calls
# ALI Latitude                       36.1761
# ALI Longitude                       -86.72
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 83, dtype: object)
#
# first item:  83
#
# second item:  Seizure DateTime             3/3/2020 0:58
# CallTypeId                       911 Calls
# ALI Latitude                       36.1761
# ALI Longitude                       -86.72
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 83, dtype: object
#
# row:  (84, Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.2386
# ALI Longitude                                -86.8225
# Cell Tower Address    822 C FLINT RIDGE DR - W Sector
# Name: 84, dtype: object)
#
# first item:  84
#
# second item:  Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.2386
# ALI Longitude                                -86.8225
# Cell Tower Address    822 C FLINT RIDGE DR - W Sector
# Name: 84, dtype: object
#
# row:  (85, Seizure DateTime              3/3/2020 0:58
# CallTypeId                        911 Calls
# ALI Latitude                        36.1744
# ALI Longitude                      -86.7271
# Cell Tower Address    254 RIVERSIDE DR - SE
# Name: 85, dtype: object)
#
# first item:  85
#
# second item:  Seizure DateTime              3/3/2020 0:58
# CallTypeId                        911 Calls
# ALI Latitude                        36.1744
# ALI Longitude                      -86.7271
# Cell Tower Address    254 RIVERSIDE DR - SE
# Name: 85, dtype: object
#
# row:  (86, Seizure DateTime                           3/3/2020 0:59
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1801
# ALI Longitude                                   -86.6002
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 86, dtype: object)
#
# first item:  86
#
# second item:  Seizure DateTime                           3/3/2020 0:59
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1801
# ALI Longitude                                   -86.6002
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 86, dtype: object
#
# row:  (87, Seizure DateTime            3/3/2020 0:59
# CallTypeId                      911 Calls
# ALI Latitude                      36.0489
# ALI Longitude                    -86.7228
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 87, dtype: object)
#
# first item:  87
#
# second item:  Seizure DateTime            3/3/2020 0:59
# CallTypeId                      911 Calls
# ALI Latitude                      36.0489
# ALI Longitude                    -86.7228
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 87, dtype: object
#
# row:  (88, Seizure DateTime                         3/3/2020 0:59
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1729
# ALI Longitude                                 -86.7931
# Cell Tower Address    1409 JEFFERSON STREET - N SECTOR
# Name: 88, dtype: object)
#
# first item:  88
#
# second item:  Seizure DateTime                         3/3/2020 0:59
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1729
# ALI Longitude                                 -86.7931
# Cell Tower Address    1409 JEFFERSON STREET - N SECTOR
# Name: 88, dtype: object
#
# row:  (89, Seizure DateTime                        3/3/2020 0:59
# ...
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 445, dtype: object)
#
# first item:  445
#
# second item:  Seizure DateTime                         3/3/2020 4:26
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 445, dtype: object
#
# row:  (446, Seizure DateTime                    3/3/2020 4:28
# CallTypeId                              911 Calls
# ALI Latitude                              36.1832
# ALI Longitude                            -87.0068
# Cell Tower Address    5060 TIDWELL HOLLOW RD - SW
# Name: 446, dtype: object)
#
# first item:  446
#
# second item:  Seizure DateTime                    3/3/2020 4:28
# CallTypeId                              911 Calls
# ALI Latitude                              36.1832
# ALI Longitude                            -87.0068
# Cell Tower Address    5060 TIDWELL HOLLOW RD - SW
# Name: 446, dtype: object
#
# row:  (447, Seizure DateTime               3/3/2020 4:29
# CallTypeId                         911 Calls
# ALI Latitude                         36.1764
# ALI Longitude                       -86.6862
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 447, dtype: object)
#
# first item:  447
#
# second item:  Seizure DateTime               3/3/2020 4:29
# CallTypeId                         911 Calls
# ALI Latitude                         36.1764
# ALI Longitude                       -86.6862
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 447, dtype: object
#
# row:  (448, Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1896
# ALI Longitude                    -86.9987
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 448, dtype: object)
#
# first item:  448
#
# second item:  Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1896
# ALI Longitude                    -86.9987
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 448, dtype: object
#
# row:  (449, Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1908
# ALI Longitude                    -86.9988
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 449, dtype: object)
#
# first item:  449
#
# second item:  Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1908
# ALI Longitude                    -86.9988
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 449, dtype: object
#
# row:  (450, Seizure DateTime                          3/3/2020 4:31
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.2728
# ALI Longitude                                  -86.7808
# Cell Tower Address    7479 OLD HICKORY BLVD. - E SECTOR
# Name: 450, dtype: object)
#
# first item:  450
#
# second item:  Seizure DateTime                          3/3/2020 4:31
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.2728
# ALI Longitude                                  -86.7808
# Cell Tower Address    7479 OLD HICKORY BLVD. - E SECTOR
# Name: 450, dtype: object
#
# row:  (451, Seizure DateTime        3/3/2020 4:32
# CallTypeId                  911 Calls
# ALI Latitude                   36.141
# ALI Longitude                -86.7661
# Cell Tower Address    WIRELESS CALLER
# Name: 451, dtype: object)
#
# first item:  451
#
# second item:  Seizure DateTime        3/3/2020 4:32
# CallTypeId                  911 Calls
# ALI Latitude                   36.141
# ALI Longitude                -86.7661
# Cell Tower Address    WIRELESS CALLER
# Name: 451, dtype: object
#
# row:  (452, Seizure DateTime                        3/3/2020 4:34
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1527
# ALI Longitude                                -86.7734
# Cell Tower Address    707 3RD AVENUE SOUTH - W SECTOR
# Name: 452, dtype: object)
#
# first item:  452
#
# second item:  Seizure DateTime                        3/3/2020 4:34
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1527
# ALI Longitude                                -86.7734
# Cell Tower Address    707 3RD AVENUE SOUTH - W SECTOR
# Name: 452, dtype: object
#
# row:  (453, Seizure DateTime                         3/3/2020 4:35
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 453, dtype: object)
#
# first item:  453
#
# second item:  Seizure DateTime                         3/3/2020 4:35
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 453, dtype: object
#
# row:  (454, Seizure DateTime           3/3/2020 4:36
# CallTypeId                     911 Calls
# ALI Latitude                     36.2014
# ALI Longitude                   -86.7294
# Cell Tower Address    2002 CAHAL AVE - N
# Name: 454, dtype: object)
#
# first item:  454
#
# second item:  Seizure DateTime           3/3/2020 4:36
# CallTypeId                     911 Calls
# ALI Latitude                     36.2014
# ALI Longitude                   -86.7294
# Cell Tower Address    2002 CAHAL AVE - N
# Name: 454, dtype: object
#
# row:  (455, Seizure DateTime              3/3/2020 4:37
# CallTypeId                        911 Calls
# ALI Latitude                        36.2799
# ALI Longitude                      -86.8027
# Cell Tower Address    6292 FRUDEMAN RD - SE
# Name: 455, dtype: object)
#
# first item:  455
#
# second item:  Seizure DateTime              3/3/2020 4:37
# CallTypeId                        911 Calls
# ALI Latitude                        36.2799
# ALI Longitude                      -86.8027
# Cell Tower Address    6292 FRUDEMAN RD - SE
# Name: 455, dtype: object
#
# row:  (456, Seizure DateTime                      3/3/2020 4:37
# CallTypeId                                911 Calls
# ALI Latitude                                36.1436
# ALI Longitude                              -86.6676
# Cell Tower Address    571D Clairidge DR - SE Sector
# Name: 456, dtype: object)
#
# first item:  456
#
# second item:  Seizure DateTime                      3/3/2020 4:37
# CallTypeId                                911 Calls
# ALI Latitude                                36.1436
# ALI Longitude                              -86.6676
# Cell Tower Address    571D Clairidge DR - SE Sector
# Name: 456, dtype: object
#
# row:  (457, Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.1951
# ALI Longitude                         -86.7549
# Cell Tower Address    1316 JEWEL ST - W Sector
# Name: 457, dtype: object)
#
# first item:  457
#
# second item:  Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.1951
# ALI Longitude                         -86.7549
# Cell Tower Address    1316 JEWEL ST - W Sector
# Name: 457, dtype: object
#
# row:  (458, Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.2693
# ALI Longitude                         -86.7931
# Cell Tower Address    3565 TRAIL HOLLOW LN - N
# Name: 458, dtype: object)
#
# first item:  458
#
# second item:  Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.2693
# ALI Longitude                         -86.7931
# Cell Tower Address    3565 TRAIL HOLLOW LN - N
# Name: 458, dtype: object
#
# row:  (459, Seizure DateTime        3/3/2020 4:39
# CallTypeId                  911 Calls
# ALI Latitude                  36.1755
# ALI Longitude                -86.7515
# Cell Tower Address    WIRELESS CALLER
# Name: 459, dtype: object)
#
# first item:  459
#
# second item:  Seizure DateTime        3/3/2020 4:39
# CallTypeId                  911 Calls
# ALI Latitude                  36.1755
# ALI Longitude                -86.7515
# Cell Tower Address    WIRELESS CALLER
# Name: 459, dtype: object
#
# row:  (460, Seizure DateTime        3/3/2020 4:40
# CallTypeId                  911 Calls
# ALI Latitude                  36.1802
# ALI Longitude                -86.7928
# Cell Tower Address    WIRELESS CALLER
# Name: 460, dtype: object)
#
# first item:  460
#
# second item:  Seizure DateTime        3/3/2020 4:40
# CallTypeId                  911 Calls
# ALI Latitude                  36.1802
# ALI Longitude                -86.7928
# Cell Tower Address    WIRELESS CALLER
# Name: 460, dtype: object
#
# row:  (461, Seizure DateTime        3/3/2020 4:41
# CallTypeId                  911 Calls
# ALI Latitude                   36.271
# ALI Longitude                -86.7604
# Cell Tower Address    WIRELESS CALLER
# Name: 461, dtype: object)
#
# first item:  461
#
# second item:  Seizure DateTime        3/3/2020 4:41
# CallTypeId                  911 Calls
# ALI Latitude                   36.271
# ALI Longitude                -86.7604
# Cell Tower Address    WIRELESS CALLER
# Name: 461, dtype: object
#
# row:  (462, Seizure DateTime                     3/3/2020 4:42
# CallTypeId                               911 Calls
# ALI Latitude                               36.1353
# ALI Longitude                             -86.7894
# Cell Tower Address    1823 C 12TH AVE S - N Sector
# Name: 462, dtype: object)
#
# first item:  462
#
# second item:  Seizure DateTime                     3/3/2020 4:42
# CallTypeId                               911 Calls
# ALI Latitude                               36.1353
# ALI Longitude                             -86.7894
# Cell Tower Address    1823 C 12TH AVE S - N Sector
# Name: 462, dtype: object
#
# row:  (464, Seizure DateTime                 3/3/2020 4:43
# CallTypeId                           911 Calls
# ALI Latitude                           36.1095
# ALI Longitude                         -86.9338
# Cell Tower Address    301 FOREST VALLEY DR - N
# Name: 464, dtype: object)
#
# first item:  464
#
# second item:  Seizure DateTime                 3/3/2020 4:43
# CallTypeId                           911 Calls
# ALI Latitude                           36.1095
# ALI Longitude                         -86.9338
# Cell Tower Address    301 FOREST VALLEY DR - N
# Name: 464, dtype: object
#
# row:  (465, Seizure DateTime                       3/3/2020 4:45
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2789
# ALI Longitude                               -86.7737
# Cell Tower Address    1345 DICKERSON PKE - SECTOR SW
# Name: 465, dtype: object)
#
# first item:  465
#
# second item:  Seizure DateTime                       3/3/2020 4:45
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2789
# ALI Longitude                               -86.7737
# Cell Tower Address    1345 DICKERSON PKE - SECTOR SW
# Name: 465, dtype: object
#
# row:  (466, Seizure DateTime                     3/3/2020 4:46
# CallTypeId                               911 Calls
# ALI Latitude                               36.1769
# ALI Longitude                             -86.6759
# Cell Tower Address    610 BEN ALLEN RD - SECTOR SE
# Name: 466, dtype: object)
#
# first item:  466
#
# second item:  Seizure DateTime                     3/3/2020 4:46
# CallTypeId                               911 Calls
# ALI Latitude                               36.1769
# ALI Longitude                             -86.6759
# Cell Tower Address    610 BEN ALLEN RD - SECTOR SE
# Name: 466, dtype: object
#
# row:  (467, Seizure DateTime            3/3/2020 4:49
# CallTypeId                      911 Calls
# ALI Latitude                      36.1774
# ALI Longitude                    -86.7583
# Cell Tower Address    859 GRANADA AVE - S
# Name: 467, dtype: object)
#
# first item:  467
#
# second item:  Seizure DateTime            3/3/2020 4:49
# CallTypeId                      911 Calls
# ALI Latitude                      36.1774
# ALI Longitude                    -86.7583
# Cell Tower Address    859 GRANADA AVE - S
# Name: 467, dtype: object
#
# row:  (468, Seizure DateTime        3/3/2020 4:52
# CallTypeId                  911 Calls
# ALI Latitude                  36.1944
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 468, dtype: object)
#
# first item:  468
#
# second item:  Seizure DateTime        3/3/2020 4:52
# CallTypeId                  911 Calls
# ALI Latitude                  36.1944
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 468, dtype: object
#
# row:  (469, Seizure DateTime               3/3/2020 4:53
# CallTypeId                         911 Calls
# ALI Latitude                         36.2725
# ALI Longitude                       -86.7949
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 469, dtype: object)
#
# first item:  469
#
# second item:  Seizure DateTime               3/3/2020 4:53
# CallTypeId                         911 Calls
# ALI Latitude                         36.2725
# ALI Longitude                       -86.7949
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 469, dtype: object
#
# row:  (470, Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1426
# ALI Longitude                -86.6353
# Cell Tower Address    WIRELESS CALLER
# Name: 470, dtype: object)
#
# first item:  470
#
# second item:  Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1426
# ALI Longitude                -86.6353
# Cell Tower Address    WIRELESS CALLER
# Name: 470, dtype: object
#
# row:  (471, Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1894
# ALI Longitude                -86.8136
# Cell Tower Address    WIRELESS CALLER
# Name: 471, dtype: object)
#
# first item:  471
#
# second item:  Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1894
# ALI Longitude                -86.8136
# Cell Tower Address    WIRELESS CALLER
# Name: 471, dtype: object
#
# row:  (472, Seizure DateTime        3/3/2020 4:55
# CallTypeId                  911 Calls
# ALI Latitude                  36.2235
# ALI Longitude                -86.7579
# Cell Tower Address    WIRELESS CALLER
# Name: 472, dtype: object)
#
# first item:  472
#
# second item:  Seizure DateTime        3/3/2020 4:55
# CallTypeId                  911 Calls
# ALI Latitude                  36.2235
# ALI Longitude                -86.7579
# Cell Tower Address    WIRELESS CALLER
# Name: 472, dtype: object
#
# row:  (473, Seizure DateTime                          3/3/2020 4:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1684
# ALI Longitude                                  -86.7838
# Cell Tower Address    600 DR MARTIN L KING JR BLVD - NE
# Name: 473, dtype: object)
#
# first item:  473
#
# second item:  Seizure DateTime                          3/3/2020 4:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1684
# ALI Longitude                                  -86.7838
# Cell Tower Address    600 DR MARTIN L KING JR BLVD - NE
# Name: 473, dtype: object
#
# row:  (474, Seizure DateTime               3/3/2020 4:58
# CallTypeId                         911 Calls
# ALI Latitude                         36.2766
# ALI Longitude                       -86.7994
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 474, dtype: object)
#
# first item:  474
#
# second item:  Seizure DateTime               3/3/2020 4:58
# CallTypeId                         911 Calls
# ALI Latitude                         36.2766
# ALI Longitude                       -86.7994
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 474, dtype: object

# %%
for ind, row in tornado_calls.iterrows():
    print('ind: ', ind, '\n')
    print('row: ', row, '\n')
# Out:
# ind:  0
#
# row:  Seizure DateTime                   3/3/2020 0:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.0727
# ALI Longitude                           -86.6658
# Cell Tower Address    620 Richards RD - N Sector
# Name: 0, dtype: object
#
# ind:  1
#
# row:  Seizure DateTime               3/3/2020 0:36
# CallTypeId                         911 Calls
# ALI Latitude                         36.1596
# ALI Longitude                       -86.8419
# Cell Tower Address    4507D KENTUCKY AV - SE
# Name: 1, dtype: object
#
# ind:  2
#
# row:  Seizure DateTime                 3/3/2020 0:36
# CallTypeId                           911 Calls
# ALI Latitude                           36.2642
# ALI Longitude                         -86.7089
# Cell Tower Address    329 THELMA ST - S Sector
# Name: 2, dtype: object
#
# ind:  4
#
# row:  Seizure DateTime             3/3/2020 0:36
# CallTypeId                       911 Calls
# ALI Latitude                       36.2335
# ALI Longitude                     -86.7211
# Cell Tower Address    5007B RUSKIN AVE - N
# Name: 4, dtype: object
#
# ind:  5
#
# row:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                   36.149
# ALI Longitude                -86.7957
# Cell Tower Address    WIRELESS CALLER
# Name: 5, dtype: object
#
# ind:  6
#
# row:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1758
# ALI Longitude                -86.8957
# Cell Tower Address    WIRELESS CALLER
# Name: 6, dtype: object
#
# ind:  7
#
# row:  Seizure DateTime        3/3/2020 0:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1805
# ALI Longitude                -86.8837
# Cell Tower Address    WIRELESS CALLER
# Name: 7, dtype: object
#
# ind:  8
#
# row:  Seizure DateTime                         3/3/2020 0:38
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.071
# ALI Longitude                                   -86.94
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 8, dtype: object
#
# ind:  9
#
# row:  Seizure DateTime      3/3/2020 0:38
# CallTypeId                911 Calls
# ALI Latitude                36.1632
# ALI Longitude              -86.7797
# Cell Tower Address    415 CHURCH ST
# Name: 9, dtype: object
#
# ind:  10
#
# row:  Seizure DateTime                  3/3/2020 0:38
# CallTypeId                            911 Calls
# ALI Latitude                            36.0521
# ALI Longitude                          -86.6483
# Cell Tower Address    745 BELL RD - OMNI Sector
# Name: 10, dtype: object
#
# ind:  11
#
# row:  Seizure DateTime          3/3/2020 0:39
# CallTypeId                    911 Calls
# ALI Latitude                    36.1732
# ALI Longitude                  -86.7973
# Cell Tower Address    907 12TH AV N - N
# Name: 11, dtype: object
#
# ind:  12
#
# row:  Seizure DateTime           3/3/2020 0:39
# CallTypeId                     911 Calls
# ALI Latitude                     36.1549
# ALI Longitude                   -86.7634
# Cell Tower Address    18B ACADEMY PL - E
# Name: 12, dtype: object
#
# ind:  13
#
# row:  Seizure DateTime                                3/3/2020 0:40
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 13, dtype: object
#
# ind:  14
#
# row:  Seizure DateTime                         3/3/2020 0:40
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0796
# ALI Longitude                                 -86.9334
# Cell Tower Address    201 FORREST VALLEY DR - SECTOR S
# Name: 14, dtype: object
#
# ind:  15
#
# row:  Seizure DateTime                   3/3/2020 0:40
# CallTypeId                             911 Calls
# ALI Latitude                             36.1039
# ALI Longitude                           -86.7978
# Cell Tower Address    3901 GRANNY WHITE PIKE - N
# Name: 15, dtype: object
#
# ind:  16
#
# row:  Seizure DateTime                   3/3/2020 0:41
# CallTypeId                             911 Calls
# ALI Latitude                             36.1206
# ALI Longitude                           -86.8045
# Cell Tower Address    2505 21ST AV - SECTOR SE S
# Name: 16, dtype: object
#
# ind:  17
#
# row:  Seizure DateTime                                3/3/2020 0:41
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 17, dtype: object
#
# ind:  18
#
# row:  Seizure DateTime                          3/3/2020 0:41
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1834
# ALI Longitude                                  -86.7716
# Cell Tower Address    1608 ROSA L PARKS BLVD - E Sector
# Name: 18, dtype: object
#
# ind:  19
#
# row:  Seizure DateTime                 3/3/2020 0:41
# CallTypeId                           911 Calls
# ALI Latitude                           36.1754
# ALI Longitude                         -86.7827
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 19, dtype: object
#
# ind:  20
#
# row:  Seizure DateTime        3/3/2020 0:41
# CallTypeId                  911 Calls
# ALI Latitude                  36.1663
# ALI Longitude                -86.8539
# Cell Tower Address    WIRELESS CALLER
# Name: 20, dtype: object
#
# ind:  21
#
# row:  Seizure DateTime                         3/3/2020 0:41
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 21, dtype: object
#
# ind:  22
#
# row:  Seizure DateTime                        3/3/2020 0:41
# CallTypeId                                  911 Calls
# ALI Latitude                                    36.22
# ALI Longitude                                -86.8064
# Cell Tower Address    615 Moormans Arm RD - Sector NW
# Name: 22, dtype: object
#
# ind:  23
#
# row:  Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1772
# ALI Longitude                -86.8787
# Cell Tower Address    WIRELESS CALLER
# Name: 23, dtype: object
#
# ind:  24
#
# row:  Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 24, dtype: object
#
# ind:  25
#
# row:  Seizure DateTime                                3/3/2020 0:42
# CallTypeId                                          911 Calls
# ALI Latitude                                            36.17
# ALI Longitude                                          -86.86
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 25, dtype: object
#
# ind:  26
#
# row:  Seizure DateTime                         3/3/2020 0:42
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1704
# ALI Longitude                                 -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - N Sector
# Name: 26, dtype: object
#
# ind:  27
#
# row:  Seizure DateTime        3/3/2020 0:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.1742
# ALI Longitude                 -86.806
# Cell Tower Address    WIRELESS CALLER
# Name: 27, dtype: object
#
# ind:  28
#
# row:  Seizure DateTime          3/3/2020 0:42
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 28, dtype: object
#
# ind:  29
#
# row:  Seizure DateTime                    3/3/2020 0:42
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608F ROSA L PARKS BLVD - S
# Name: 29, dtype: object
#
# ind:  30
#
# row:  Seizure DateTime              3/3/2020 0:43
# CallTypeId                        911 Calls
# ALI Latitude                        36.1515
# ALI Longitude                      -86.7888
# Cell Tower Address    1313 DIVISION ST - OM
# Name: 30, dtype: object
#
# ind:  31
#
# row:  Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1759
# ALI Longitude                                   -86.7808
# Cell Tower Address    300 JAMES ROBERTSON PKY - N Sector
# Name: 31, dtype: object
#
# ind:  32
#
# row:  Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 32, dtype: object
#
# ind:  33
#
# row:  Seizure DateTime          3/3/2020 0:43
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 33, dtype: object
#
# ind:  34
#
# row:  Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.3226
# ALI Longitude                            -86.8674
# Cell Tower Address    945 CLAY LICK CT - SECTOR N
# Name: 34, dtype: object
#
# ind:  35
#
# row:  Seizure DateTime                           3/3/2020 0:43
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1677
# ALI Longitude                                   -86.7802
# Cell Tower Address    410 JAMES ROBERTSON PKY - N Sector
# Name: 35, dtype: object
#
# ind:  36
#
# row:  Seizure DateTime                                3/3/2020 0:43
# CallTypeId                                          911 Calls
# ALI Latitude                                          36.1793
# ALI Longitude                                        -86.8835
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 36, dtype: object
#
# ind:  37
#
# row:  Seizure DateTime           3/3/2020 0:43
# CallTypeId                     911 Calls
# ALI Latitude                     36.1753
# ALI Longitude                    -86.782
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 37, dtype: object
#
# ind:  38
#
# row:  Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                   36.173
# ALI Longitude                -86.8049
# Cell Tower Address    WIRELESS CALLER
# Name: 38, dtype: object
#
# ind:  39
#
# row:  Seizure DateTime                             3/3/2020 0:43
# CallTypeId                                       911 Calls
# ALI Latitude                                        36.176
# ALI Longitude                                      -86.894
# Cell Tower Address    1816 LINDER INDUSTRIAL DR - W SECTOR
# Name: 39, dtype: object
#
# ind:  40
#
# row:  Seizure DateTime        3/3/2020 0:43
# CallTypeId                  911 Calls
# ALI Latitude                  36.1754
# ALI Longitude                -86.7866
# Cell Tower Address    WIRELESS CALLER
# Name: 40, dtype: object
#
# ind:  41
#
# row:  Seizure DateTime                    3/3/2020 0:43
# CallTypeId                              911 Calls
# ALI Latitude                              36.1797
# ALI Longitude                            -86.7952
# Cell Tower Address    1608-B 8TH AV - SECTOR SW N
# Name: 41, dtype: object
#
# ind:  42
#
# row:  Seizure DateTime                  3/3/2020 0:44
# CallTypeId                            911 Calls
# ALI Latitude                            36.1752
# ALI Longitude                          -86.7812
# Cell Tower Address    2301 BOOKER ST - E SECTOR
# Name: 42, dtype: object
#
# ind:  43
#
# row:  Seizure DateTime          3/3/2020 0:44
# CallTypeId                    911 Calls
# ALI Latitude                    36.1675
# ALI Longitude                  -86.7968
# Cell Tower Address    907 12TH AV N - N
# Name: 43, dtype: object
#
# ind:  44
#
# row:  Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.1747
# ALI Longitude                             -86.7871
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 44, dtype: object
#
# ind:  45
#
# row:  Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1544
# ALI Longitude                            -86.8292
# Cell Tower Address    435 B 37TH AVE N - N Sector
# Name: 45, dtype: object
#
# ind:  46
#
# row:  Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                            36.185
# ALI Longitude                         -86.7483
# Cell Tower Address    1051G CHICAMAUGA AVE - S
# Name: 46, dtype: object
#
# ind:  47
#
# row:  Seizure DateTime                 3/3/2020 0:44
# CallTypeId                           911 Calls
# ALI Latitude                           36.1747
# ALI Longitude                          -86.783
# Cell Tower Address    500 5TH AV - SECTOR NE N
# Name: 47, dtype: object
#
# ind:  48
#
# row:  Seizure DateTime            3/3/2020 0:44
# CallTypeId                      911 Calls
# ALI Latitude                      36.1431
# ALI Longitude                    -86.8006
# Cell Tower Address    1161 21ST AV S - SE
# Name: 48, dtype: object
#
# ind:  49
#
# row:  Seizure DateTime                     3/3/2020 0:44
# CallTypeId                               911 Calls
# ALI Latitude                               36.2455
# ALI Longitude                              -86.838
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 49, dtype: object
#
# ind:  50
#
# row:  Seizure DateTime                    3/3/2020 0:44
# CallTypeId                              911 Calls
# ALI Latitude                              36.1785
# ALI Longitude                            -86.7745
# Cell Tower Address    10 C LUCILLE ST - SE SECTOR
# Name: 50, dtype: object
#
# ind:  51
#
# row:  Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                            36.1962
# ALI Longitude                          -86.7741
# Cell Tower Address    10D LUCILE ST - SECTOR SE
# Name: 51, dtype: object
#
# ind:  52
#
# row:  Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1751
# ALI Longitude                                -86.7862
# Cell Tower Address    5043 HILLSBORO PIKE - SECTOR NE
# Name: 52, dtype: object
#
# ind:  53
#
# row:  Seizure DateTime        3/3/2020 0:45
# CallTypeId                  911 Calls
# ALI Latitude                   36.171
# ALI Longitude                -86.7906
# Cell Tower Address    WIRELESS CALLER
# Name: 53, dtype: object
#
# ind:  54
#
# row:  Seizure DateTime                        3/3/2020 0:45
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1774
# ALI Longitude                                 -86.754
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 54, dtype: object
#
# ind:  55
#
# row:  Seizure DateTime                  3/3/2020 0:45
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 55, dtype: object
#
# ind:  56
#
# row:  Seizure DateTime           3/3/2020 0:45
# CallTypeId                     911 Calls
# ALI Latitude                      36.177
# ALI Longitude                   -86.7781
# Cell Tower Address    19C OLDHAM ST - SE
# Name: 56, dtype: object
#
# ind:  57
#
# row:  Seizure DateTime          3/3/2020 0:47
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 57, dtype: object
#
# ind:  58
#
# row:  Seizure DateTime              3/3/2020 0:50
# CallTypeId                        911 Calls
# ALI Latitude                        36.1679
# ALI Longitude                      -86.8158
# Cell Tower Address    2101 E HEIMAN ST - SW
# Name: 58, dtype: object
#
# ind:  59
#
# row:  Seizure DateTime           3/3/2020 0:50
# CallTypeId                     911 Calls
# ALI Latitude                     36.1751
# ALI Longitude                   -86.7822
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 59, dtype: object
#
# ind:  60
#
# row:  Seizure DateTime          3/3/2020 0:51
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 60, dtype: object
#
# ind:  61
#
# row:  Seizure DateTime                  3/3/2020 0:51
# CallTypeId                            911 Calls
# ALI Latitude                             36.173
# ALI Longitude                          -86.7647
# Cell Tower Address    411D FATHERLAND STRE - NE
# Name: 61, dtype: object
#
# ind:  62
#
# row:  Seizure DateTime          3/3/2020 0:52
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 62, dtype: object
#
# ind:  63
#
# row:  Seizure DateTime           3/3/2020 0:52
# CallTypeId                     911 Calls
# ALI Latitude                     36.1735
# ALI Longitude                   -86.7856
# Cell Tower Address    19C OLDHAM ST - SW
# Name: 63, dtype: object
#
# ind:  64
#
# row:  Seizure DateTime            3/3/2020 0:53
# CallTypeId                      911 Calls
# ALI Latitude                        36.05
# ALI Longitude                    -86.6506
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 64, dtype: object
#
# ind:  65
#
# row:  Seizure DateTime                          3/3/2020 0:53
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1704
# ALI Longitude                                  -86.8017
# Cell Tower Address    1409 E E JEFFERSON ST - SW Sector
# Name: 65, dtype: object
#
# ind:  66
#
# row:  Seizure DateTime             3/3/2020 0:54
# CallTypeId                       911 Calls
# ALI Latitude                       36.1744
# ALI Longitude                     -86.7271
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 66, dtype: object
#
# ind:  67
#
# row:  Seizure DateTime        3/3/2020 0:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1737
# ALI Longitude                -86.8088
# Cell Tower Address    WIRELESS CALLER
# Name: 67, dtype: object
#
# ind:  69
#
# row:  Seizure DateTime               3/3/2020 0:54
# CallTypeId                         911 Calls
# ALI Latitude                          36.187
# ALI Longitude                       -86.6281
# Cell Tower Address    3333 LEBANON PIKE - SW
# Name: 69, dtype: object
#
# ind:  71
#
# row:  Seizure DateTime          3/3/2020 0:55
# CallTypeId                    911 Calls
# ALI Latitude                    36.1755
# ALI Longitude                  -86.7867
# Cell Tower Address    907 12TH AV N - N
# Name: 71, dtype: object
#
# ind:  72
#
# row:  Seizure DateTime                          3/3/2020 0:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1351
# ALI Longitude                                  -86.8113
# Cell Tower Address    1301 MEDICAL CENTER DR - S Sector
# Name: 72, dtype: object
#
# ind:  73
#
# row:  Seizure DateTime               3/3/2020 0:56
# CallTypeId                         911 Calls
# ALI Latitude                         36.1725
# ALI Longitude                       -86.5761
# Cell Tower Address    4316 CENTRAL PIKE - SE
# Name: 73, dtype: object
#
# ind:  75
#
# row:  Seizure DateTime          3/3/2020 0:58
# CallTypeId                    911 Calls
# ALI Latitude                    36.1674
# ALI Longitude                  -86.7969
# Cell Tower Address    907 12TH AV N - N
# Name: 75, dtype: object
#
# ind:  76
#
# row:  Seizure DateTime                  3/3/2020 0:58
# CallTypeId                            911 Calls
# ALI Latitude                            36.1704
# ALI Longitude                          -86.8017
# Cell Tower Address    179 8TH AVE N - NW SECTOR
# Name: 76, dtype: object
#
# ind:  77
#
# row:  Seizure DateTime                    3/3/2020 0:58
# CallTypeId                              911 Calls
# ALI Latitude                              36.1796
# ALI Longitude                            -86.6005
# Cell Tower Address    5655 FIRST BLVD - SECTOR NE
# Name: 77, dtype: object
#
# ind:  78
#
# row:  Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                   36.175
# ALI Longitude                                -86.7819
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 78, dtype: object
#
# ind:  79
#
# row:  Seizure DateTime                              3/3/2020 0:58
# CallTypeId                                        911 Calls
# ALI Latitude                                        36.0721
# ALI Longitude                                      -86.6368
# Cell Tower Address    2747-B MURFREESBORO PKE - SECTOR SWNE
# Name: 79, dtype: object
#
# ind:  80
#
# row:  Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1706
# ALI Longitude                -86.7914
# Cell Tower Address    WIRELESS CALLER
# Name: 80, dtype: object
#
# ind:  81
#
# row:  Seizure DateTime            3/3/2020 0:58
# CallTypeId                      911 Calls
# ALI Latitude                      36.1732
# ALI Longitude                    -86.7852
# Cell Tower Address    401 JACKSON ST - NW
# Name: 81, dtype: object
#
# ind:  82
#
# row:  Seizure DateTime        3/3/2020 0:58
# CallTypeId                  911 Calls
# ALI Latitude                  36.1752
# ALI Longitude                -86.7412
# Cell Tower Address    WIRELESS CALLER
# Name: 82, dtype: object
#
# ind:  83
#
# row:  Seizure DateTime             3/3/2020 0:58
# CallTypeId                       911 Calls
# ALI Latitude                       36.1761
# ALI Longitude                       -86.72
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 83, dtype: object
#
# ind:  84
#
# row:  Seizure DateTime                        3/3/2020 0:58
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.2386
# ALI Longitude                                -86.8225
# Cell Tower Address    822 C FLINT RIDGE DR - W Sector
# Name: 84, dtype: object
#
# ind:  85
#
# row:  Seizure DateTime              3/3/2020 0:58
# CallTypeId                        911 Calls
# ALI Latitude                        36.1744
# ALI Longitude                      -86.7271
# Cell Tower Address    254 RIVERSIDE DR - SE
# Name: 85, dtype: object
#
# ind:  86
#
# row:  Seizure DateTime                           3/3/2020 0:59
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1801
# ALI Longitude                                   -86.6002
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 86, dtype: object
#
# ind:  87
#
# row:  Seizure DateTime            3/3/2020 0:59
# CallTypeId                      911 Calls
# ALI Latitude                      36.0489
# ALI Longitude                    -86.7228
# Cell Tower Address    5646 AMALIE DR - SE
# Name: 87, dtype: object
#
# ind:  88
#
# row:  Seizure DateTime                         3/3/2020 0:59
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1729
# ALI Longitude                                 -86.7931
# Cell Tower Address    1409 JEFFERSON STREET - N SECTOR
# Name: 88, dtype: object
#
# ind:  89
#
# row:  Seizure DateTime                        3/3/2020 0:59
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1746
# ALI Longitude                                -86.7618
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 89, dtype: object
#
# ind:  90
#
# row:  Seizure DateTime               3/3/2020 0:59
# CallTypeId                         911 Calls
# ALI Latitude                         36.1725
# ALI Longitude                       -86.5761
# Cell Tower Address    4316 CENTRAL PIKE - SE
# Name: 90, dtype: object
#
# ind:  91
#
# row:  Seizure DateTime              3/3/2020 0:59
# CallTypeId                        911 Calls
# ALI Latitude                        36.1744
# ALI Longitude                      -86.7271
# Cell Tower Address    254 RIVERSIDE DR - SE
# Name: 91, dtype: object
#
# ind:  92
#
# row:  Seizure DateTime        3/3/2020 0:59
# CallTypeId                  911 Calls
# ALI Latitude                   36.185
# ALI Longitude                -86.7482
# Cell Tower Address    WIRELESS CALLER
# Name: 92, dtype: object
#
# ind:  93
#
# row:  Seizure DateTime                              3/3/2020 0:59
# CallTypeId                                        911 Calls
# ALI Latitude                                        36.2217
# ALI Longitude                                      -86.7681
# Cell Tower Address    2955 BRICK CHURCH PARKWAY - SE SECTOR
# Name: 93, dtype: object
#
# ind:  94
#
# row:  Seizure DateTime             3/3/2020 0:59
# CallTypeId                       911 Calls
# ALI Latitude                       36.1744
# ALI Longitude                     -86.7271
# Cell Tower Address    254 RIVERSIDE DR - N
# Name: 94, dtype: object
#
# ind:  95
#
# row:  Seizure DateTime        3/3/2020 0:59
# CallTypeId                  911 Calls
# ALI Latitude                  36.1815
# ALI Longitude                -86.7596
# Cell Tower Address    WIRELESS CALLER
# Name: 95, dtype: object
#
# ind:  96
#
# row:  Seizure DateTime                        3/3/2020 0:59
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1961
# ALI Longitude                                -86.7739
# Cell Tower Address    10-C LUCILLE STREET - SE SECTOR
# Name: 96, dtype: object
#
# ind:  97
#
# row:  Seizure DateTime            3/3/2020 1:00
# CallTypeId                      911 Calls
# ALI Latitude                      36.1892
# ALI Longitude                    -86.7572
# Cell Tower Address    859 GRANADA AVE - S
# Name: 97, dtype: object
#
# ind:  98
#
# row:  Seizure DateTime             3/3/2020 1:00
# CallTypeId                       911 Calls
# ALI Latitude                       36.1698
# ALI Longitude                      -86.813
# Cell Tower Address    2101 E HEIMAN ST - N
# Name: 98, dtype: object
#
# ind:  99
#
# row:  Seizure DateTime               3/3/2020 1:00
# CallTypeId                         911 Calls
# ALI Latitude                          36.187
# ALI Longitude                       -86.6281
# Cell Tower Address    3333 LEBANON PIKE - SE
# Name: 99, dtype: object
#
# ind:  100
#
# row:  Seizure DateTime                     3/3/2020 1:00
# CallTypeId                               911 Calls
# ALI Latitude                               36.1754
# ALI Longitude                             -86.8048
# Cell Tower Address    1409 JEFFERSON ST - N SECTOR
# Name: 100, dtype: object
#
# ind:  101
#
# row:  Seizure DateTime            3/3/2020 1:00
# CallTypeId                      911 Calls
# ALI Latitude                      36.1948
# ALI Longitude                    -86.7291
# Cell Tower Address    2002 CAHAL AVE - SE
# Name: 101, dtype: object
#
# ind:  102
#
# row:  Seizure DateTime            3/3/2020 1:00
# CallTypeId                      911 Calls
# ALI Latitude                      36.1765
# ALI Longitude                    -86.7545
# Cell Tower Address    859 GRANADA AVE - S
# Name: 102, dtype: object
#
# ind:  103
#
# row:  Seizure DateTime        3/3/2020 1:00
# CallTypeId                  911 Calls
# ALI Latitude                  36.1782
# ALI Longitude                -86.6923
# Cell Tower Address    WIRELESS CALLER
# Name: 103, dtype: object
#
# ind:  104
#
# row:  Seizure DateTime                    3/3/2020 1:00
# CallTypeId                              911 Calls
# ALI Latitude                               36.175
# ALI Longitude                            -86.8147
# Cell Tower Address    2101-D HEIMAN ST - SECTOR N
# Name: 104, dtype: object
#
# ind:  105
#
# row:  Seizure DateTime            3/3/2020 1:01
# CallTypeId                      911 Calls
# ALI Latitude                      36.1764
# ALI Longitude                    -86.7461
# Cell Tower Address    2002 CAHAL AVE - SW
# Name: 105, dtype: object
#
# ind:  106
#
# row:  Seizure DateTime                        3/3/2020 1:01
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1792
# ALI Longitude                                -86.7546
# Cell Tower Address    1051 CHICAMAUGA AVE - SECTOR SW
# Name: 106, dtype: object
#
# ind:  107
#
# row:  Seizure DateTime                            3/3/2020 1:02
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.1676
# ALI Longitude                                    -86.7802
# Cell Tower Address    300 JAMES ROBERTSON PKY - SE Sector
# Name: 107, dtype: object
#
# ind:  108
#
# row:  Seizure DateTime            3/3/2020 1:02
# CallTypeId                      911 Calls
# ALI Latitude                      36.1892
# ALI Longitude                    -86.7572
# Cell Tower Address    861C GRANADA AV - S
# Name: 108, dtype: object
#
# ind:  109
#
# row:  Seizure DateTime                 3/3/2020 1:02
# CallTypeId                           911 Calls
# ALI Latitude                           36.1984
# ALI Longitude                          -86.767
# Cell Tower Address    1316 JEWEL ST - W Sector
# Name: 109, dtype: object
#
# ind:  110
#
# row:  Seizure DateTime                          3/3/2020 1:02
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1915
# ALI Longitude                                  -86.6021
# Cell Tower Address    4800 OLD HICKORY BLVD - SECTOR SE
# Name: 110, dtype: object
#
# ind:  111
#
# row:  Seizure DateTime                          3/3/2020 1:02
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1997
# ALI Longitude                                    -86.62
# Cell Tower Address    4914 OLD HICKORY BLVD - SE Sector
# Name: 111, dtype: object
#
# ind:  112
#
# row:  Seizure DateTime              3/3/2020 1:02
# CallTypeId                        911 Calls
# ALI Latitude                        36.1392
# ALI Longitude                      -86.8108
# Cell Tower Address    1519 NATCHEZ TRCE - N
# Name: 112, dtype: object
#
# ind:  113
#
# row:  Seizure DateTime             3/3/2020 1:02
# CallTypeId                       911 Calls
# ALI Latitude                        36.163
# ALI Longitude                     -86.7768
# Cell Tower Address    212 COMMERCE ST - NW
# Name: 113, dtype: object
#
# ind:  115
#
# row:  Seizure DateTime                           3/3/2020 1:04
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1677
# ALI Longitude                                   -86.7805
# Cell Tower Address    300 JAMES ROBERTSON PKY - N Sector
# Name: 115, dtype: object
#
# ind:  116
#
# row:  Seizure DateTime        3/3/2020 1:04
# CallTypeId                  911 Calls
# ALI Latitude                  36.1753
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 116, dtype: object
#
# ind:  117
#
# row:  Seizure DateTime                     3/3/2020 1:05
# CallTypeId                               911 Calls
# ALI Latitude                               36.1697
# ALI Longitude                              -86.765
# Cell Tower Address    411 FATHERLAND ST - N Sector
# Name: 117, dtype: object
#
# ind:  118
#
# row:  Seizure DateTime                            3/3/2020 1:05
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.1749
# ALI Longitude                                    -86.7551
# Cell Tower Address    2025B METRO CENTER BLVD. - E SECTOR
# Name: 118, dtype: object
#
# ind:  119
#
# row:  Seizure DateTime                 3/3/2020 1:06
# CallTypeId                           911 Calls
# ALI Latitude                           36.2313
# ALI Longitude                          -86.601
# Cell Tower Address    451 SHUTE LN - SECTOR SE
# Name: 119, dtype: object
#
# ind:  122
#
# row:  Seizure DateTime                           3/3/2020 1:08
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1794
# ALI Longitude                                   -86.5999
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 122, dtype: object
#
# ind:  123
#
# row:  Seizure DateTime                 3/3/2020 1:08
# CallTypeId                           911 Calls
# ALI Latitude                            36.185
# ALI Longitude                         -86.7483
# Cell Tower Address    1051G CHICAMAUGA AVE - S
# Name: 123, dtype: object
#
# ind:  124
#
# row:  Seizure DateTime                   3/3/2020 1:08
# CallTypeId                             911 Calls
# ALI Latitude                             36.1703
# ALI Longitude                           -86.8036
# Cell Tower Address    2301 BOOKER ST - NW SECTOR
# Name: 124, dtype: object
#
# ind:  125
#
# row:  Seizure DateTime        3/3/2020 1:08
# CallTypeId                  911 Calls
# ALI Latitude                   36.185
# ALI Longitude                -86.6453
# Cell Tower Address    WIRELESS CALLER
# Name: 125, dtype: object
#
# ind:  126
#
# row:  Seizure DateTime                         3/3/2020 1:08
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.166
# ALI Longitude                                 -86.7629
# Cell Tower Address    707 3RD AVENUE SOUTH - NE SECTOR
# Name: 126, dtype: object
#
# ind:  127
#
# row:  Seizure DateTime             3/3/2020 1:09
# CallTypeId                       911 Calls
# ALI Latitude                       36.1698
# ALI Longitude                      -86.813
# Cell Tower Address    2101 E HEIMAN ST - N
# Name: 127, dtype: object
#
# ind:  128
#
# row:  Seizure DateTime        3/3/2020 1:09
# CallTypeId                  911 Calls
# ALI Latitude                  36.1841
# ALI Longitude                -86.6485
# Cell Tower Address    WIRELESS CALLER
# Name: 128, dtype: object
#
# ind:  129
#
# row:  Seizure DateTime                            3/3/2020 1:09
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.1813
# ALI Longitude                                    -86.5997
# Cell Tower Address    906 CHANDLER RADFORD RD - SECTOR SW
# Name: 129, dtype: object
#
# ind:  130
#
# row:  Seizure DateTime        3/3/2020 1:10
# CallTypeId                  911 Calls
# ALI Latitude                  36.1439
# ALI Longitude                -86.7518
# Cell Tower Address    WIRELESS CALLER
# Name: 130, dtype: object
#
# ind:  131
#
# row:  Seizure DateTime                          3/3/2020 1:10
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1799
# ALI Longitude                                   -86.601
# Cell Tower Address    4940 OLD HICKORY BLVD - SE SECTOR
# Name: 131, dtype: object
#
# ind:  133
#
# row:  Seizure DateTime                          3/3/2020 1:11
# CallTypeId                                    911 Calls
# ALI Latitude                                      36.18
# ALI Longitude                                     -86.6
# Cell Tower Address    4940 OLD HICKORY BLVD - SE SECTOR
# Name: 133, dtype: object
#
# ind:  134
#
# row:  Seizure DateTime            3/3/2020 1:12
# CallTypeId                      911 Calls
# ALI Latitude                      36.1774
# ALI Longitude                    -86.7559
# Cell Tower Address    861C GRANADA AV - S
# Name: 134, dtype: object
#
# ind:  135
#
# row:  Seizure DateTime                          3/3/2020 1:13
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1017
# ALI Longitude                                  -86.8711
# Cell Tower Address    5801 OLD HARDING PIKE - SW SECTOR
# Name: 135, dtype: object
#
# ind:  136
#
# row:  Seizure DateTime                                3/3/2020 1:13
# CallTypeId                                          911 Calls
# ALI Latitude                                          36.1767
# ALI Longitude                                         -86.878
# Cell Tower Address    1820-A LINDER INDUSTRIAL DR - SECTOR SW
# Name: 136, dtype: object
#
# ind:  137
#
# row:  Seizure DateTime            3/3/2020 1:13
# CallTypeId                      911 Calls
# ALI Latitude                      36.1892
# ALI Longitude                    -86.7572
# Cell Tower Address    859 GRANADA AVE - S
# Name: 137, dtype: object
#
# ind:  138
#
# row:  Seizure DateTime                           3/3/2020 1:14
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1819
# ALI Longitude                                   -86.6112
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 138, dtype: object
#
# ind:  139
#
# row:  Seizure DateTime                        3/3/2020 1:14
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1742
# ALI Longitude                                -86.7623
# Cell Tower Address    411-C Fatherland ST - SE Sector
# Name: 139, dtype: object
#
# ind:  140
#
# row:  Seizure DateTime          3/3/2020 1:14
# CallTypeId                    911 Calls
# ALI Latitude                    36.1536
# ALI Longitude                  -86.8869
# Cell Tower Address    5758 RIVER RD - N
# Name: 140, dtype: object
#
# ind:  141
#
# row:  Seizure DateTime              3/3/2020 1:14
# CallTypeId                        911 Calls
# ALI Latitude                        36.1742
# ALI Longitude                      -86.7379
# Cell Tower Address    859C GRANADA AVE - SE
# Name: 141, dtype: object
#
# ind:  142
#
# row:  Seizure DateTime                          3/3/2020 1:14
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1997
# ALI Longitude                                    -86.62
# Cell Tower Address    4914 OLD HICKORY BLVD - SE Sector
# Name: 142, dtype: object
#
# ind:  143
#
# row:  Seizure DateTime                     3/3/2020 1:14
# CallTypeId                               911 Calls
# ALI Latitude                               36.1854
# ALI Longitude                             -86.3965
# Cell Tower Address    5792 LEEVILLE RD - NE Sector
# Name: 143, dtype: object
#
# ind:  144
#
# row:  Seizure DateTime                      3/3/2020 1:14
# CallTypeId                                911 Calls
# ALI Latitude                                36.1842
# ALI Longitude                              -86.3075
# Cell Tower Address    3280 A HICKORY RDG - S Sector
# Name: 144, dtype: object
#
# ind:  145
#
# row:  Seizure DateTime        3/3/2020 1:15
# CallTypeId                  911 Calls
# ALI Latitude                  36.0718
# ALI Longitude                -86.9302
# Cell Tower Address    WIRELESS CALLER
# Name: 145, dtype: object
#
# ind:  146
#
# row:  Seizure DateTime               3/3/2020 1:15
# CallTypeId                         911 Calls
# ALI Latitude                         36.1811
# ALI Longitude                       -86.6411
# Cell Tower Address    3333 LEBANON PIKE - SW
# Name: 146, dtype: object
#
# ind:  147
#
# row:  Seizure DateTime            3/3/2020 1:15
# CallTypeId                      911 Calls
# ALI Latitude                      36.1536
# ALI Longitude                    -86.8869
# Cell Tower Address    3744B ANNEX AVE - N
# Name: 147, dtype: object
#
# ind:  148
#
# row:  Seizure DateTime                          3/3/2020 1:15
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.5378
# ALI Longitude                                  -85.8625
# Cell Tower Address    8101 HEADY RIDGE ROAD - SW SECTOR
# Name: 148, dtype: object
#
# ind:  149
#
# row:  Seizure DateTime        3/3/2020 1:15
# CallTypeId                  911 Calls
# ALI Latitude                  36.1758
# ALI Longitude                -86.7519
# Cell Tower Address    WIRELESS CALLER
# Name: 149, dtype: object
#
# ind:  150
#
# row:  Seizure DateTime             3/3/2020 1:16
# CallTypeId                       911 Calls
# ALI Latitude                       36.1737
# ALI Longitude                     -86.7387
# Cell Tower Address    254 RIVERSIDE DR - W
# Name: 150, dtype: object
#
# ind:  151
#
# row:  Seizure DateTime        3/3/2020 1:16
# CallTypeId                  911 Calls
# ALI Latitude                  36.1932
# ALI Longitude                -86.7575
# Cell Tower Address    WIRELESS CALLER
# Name: 151, dtype: object
#
# ind:  152
#
# row:  Seizure DateTime                 3/3/2020 1:16
# CallTypeId                           911 Calls
# ALI Latitude                            36.185
# ALI Longitude                         -86.7483
# Cell Tower Address    1051G CHICAMAUGA AVE - S
# Name: 152, dtype: object
#
# ind:  153
#
# row:  Seizure DateTime                            3/3/2020 1:16
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.1755
# ALI Longitude                                    -86.7545
# Cell Tower Address    2025B METRO CENTER BLVD. - E SECTOR
# Name: 153, dtype: object
#
# ind:  154
#
# row:  Seizure DateTime             3/3/2020 1:16
# CallTypeId                       911 Calls
# ALI Latitude                       36.1739
# ALI Longitude                     -86.7384
# Cell Tower Address    254 RIVERSIDE DR - W
# Name: 154, dtype: object
#
# ind:  155
#
# row:  Seizure DateTime                          3/3/2020 1:16
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.2454
# ALI Longitude                                  -86.7709
# Cell Tower Address    2955 BRICK CHURCH PKWY - N SECTOR
# Name: 155, dtype: object
#
# ind:  157
#
# row:  Seizure DateTime               3/3/2020 1:16
# CallTypeId                         911 Calls
# ALI Latitude                          36.187
# ALI Longitude                        -86.628
# Cell Tower Address    3333 LEBANON PIKE - SW
# Name: 157, dtype: object
#
# ind:  158
#
# row:  Seizure DateTime               3/3/2020 1:17
# CallTypeId                         911 Calls
# ALI Latitude                         36.1761
# ALI Longitude                       -86.7187
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 158, dtype: object
#
# ind:  159
#
# row:  Seizure DateTime                        3/3/2020 1:17
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1772
# ALI Longitude                                -86.7598
# Cell Tower Address    411-C Fatherland ST - SE Sector
# Name: 159, dtype: object
#
# ind:  160
#
# row:  Seizure DateTime                     3/3/2020 1:18
# CallTypeId                               911 Calls
# ALI Latitude                               36.1722
# ALI Longitude                             -86.5757
# Cell Tower Address    4316 CENTRAL PKE - NE Sector
# Name: 160, dtype: object
#
# ind:  161
#
# row:  Seizure DateTime        3/3/2020 1:18
# CallTypeId                  911 Calls
# ALI Latitude                  36.1755
# ALI Longitude                -86.7261
# Cell Tower Address    WIRELESS CALLER
# Name: 161, dtype: object
#
# ind:  162
#
# row:  Seizure DateTime                       3/3/2020 1:19
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2453
# ALI Longitude                                 -86.72
# Cell Tower Address    619 DUE WEST AVE. W - S SECTOR
# Name: 162, dtype: object
#
# ind:  163
#
# row:  Seizure DateTime            3/3/2020 1:19
# CallTypeId                      911 Calls
# ALI Latitude                      36.2119
# ALI Longitude                    -86.2922
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 163, dtype: object
#
# ind:  164
#
# row:  Seizure DateTime                    3/3/2020 1:20
# CallTypeId                              911 Calls
# ALI Latitude                              36.1769
# ALI Longitude                             -86.815
# Cell Tower Address    2101-D HEIMAN ST - SECTOR N
# Name: 164, dtype: object
#
# ind:  165
#
# row:  Seizure DateTime        3/3/2020 1:21
# CallTypeId                  911 Calls
# ALI Latitude                  36.1789
# ALI Longitude                -86.7608
# Cell Tower Address    WIRELESS CALLER
# Name: 165, dtype: object
#
# ind:  166
#
# row:  Seizure DateTime        3/3/2020 1:21
# CallTypeId                  911 Calls
# ALI Latitude                  36.1735
# ALI Longitude                -86.6969
# Cell Tower Address    WIRELESS CALLER
# Name: 166, dtype: object
#
# ind:  167
#
# row:  Seizure DateTime                      3/3/2020 1:21
# CallTypeId                                911 Calls
# ALI Latitude                                36.2004
# ALI Longitude                              -86.3573
# Cell Tower Address    3280 A HICKORY RDG - S Sector
# Name: 167, dtype: object
#
# ind:  168
#
# row:  Seizure DateTime              3/3/2020 1:21
# CallTypeId                        911 Calls
# ALI Latitude                        36.1744
# ALI Longitude                      -86.7271
# Cell Tower Address    254 RIVERSIDE DR - SE
# Name: 168, dtype: object
#
# ind:  169
#
# row:  Seizure DateTime                    3/3/2020 1:22
# CallTypeId                              911 Calls
# ALI Latitude                              36.1834
# ALI Longitude                            -86.5615
# Cell Tower Address    981 CHANDLER RD - NE Sector
# Name: 169, dtype: object
#
# ind:  170
#
# row:  Seizure DateTime                     3/3/2020 1:22
# CallTypeId                               911 Calls
# ALI Latitude                                36.176
# ALI Longitude                             -86.7592
# Cell Tower Address    411 FATHERLAND ST - N Sector
# Name: 170, dtype: object
#
# ind:  171
#
# row:  Seizure DateTime        3/3/2020 1:22
# CallTypeId                  911 Calls
# ALI Latitude                  36.1761
# ALI Longitude                 -86.648
# Cell Tower Address    WIRELESS CALLER
# Name: 171, dtype: object
#
# ind:  172
#
# row:  Seizure DateTime       3/3/2020 1:23
# CallTypeId                 911 Calls
# ALI Latitude                 36.1855
# ALI Longitude               -86.8071
# Cell Tower Address    1014 LOOBY CIR
# Name: 172, dtype: object
#
# ind:  173
#
# row:  Seizure DateTime               3/3/2020 1:23
# CallTypeId                         911 Calls
# ALI Latitude                         36.1804
# ALI Longitude                       -86.6012
# Cell Tower Address    3333 LEBANON PIKE - SE
# Name: 173, dtype: object
#
# ind:  174
#
# row:  Seizure DateTime                         3/3/2020 1:23
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 174, dtype: object
#
# ind:  175
#
# row:  Seizure DateTime        3/3/2020 1:23
# CallTypeId                  911 Calls
# ALI Latitude                   36.187
# ALI Longitude                -86.6503
# Cell Tower Address    WIRELESS CALLER
# Name: 175, dtype: object
#
# ind:  176
#
# row:  Seizure DateTime                          3/3/2020 1:23
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1785
# ALI Longitude                                  -86.5986
# Cell Tower Address    4800 OLD HICKORY BLVD - SECTOR SE
# Name: 176, dtype: object
#
# ind:  177
#
# row:  Seizure DateTime                   3/3/2020 1:23
# CallTypeId                             911 Calls
# ALI Latitude                             36.1837
# ALI Longitude                           -86.7952
# Cell Tower Address    10 C LUCILLE ST - W SECTOR
# Name: 177, dtype: object
#
# ind:  178
#
# row:  Seizure DateTime                           3/3/2020 1:24
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.1818
# ALI Longitude                                   -86.6056
# Cell Tower Address    4940 OLD HICKORY BLVD. - SE SECTOR
# Name: 178, dtype: object
#
# ind:  179
#
# row:  Seizure DateTime                3/3/2020 1:25
# CallTypeId                          911 Calls
# ALI Latitude                          36.1776
# ALI Longitude                        -86.6746
# Cell Tower Address    2281E RIDGELAND DR - SE
# Name: 179, dtype: object
#
# ind:  180
#
# row:  Seizure DateTime        3/3/2020 1:25
# CallTypeId                  911 Calls
# ALI Latitude                  36.1763
# ALI Longitude                -86.5889
# ...
# Name: 413, dtype: object
#
# ind:  414
#
# row:  Seizure DateTime              3/3/2020 3:42
# CallTypeId                        911 Calls
# ALI Latitude                        36.2071
# ALI Longitude                      -86.6113
# Cell Tower Address    3333 LEBANON PIKE - N
# Name: 414, dtype: object
#
# ind:  415
#
# row:  Seizure DateTime                          3/3/2020 3:42
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.2073
# ALI Longitude                                  -86.6107
# Cell Tower Address    4914 OLD HICKORY BLVD - NE Sector
# Name: 415, dtype: object
#
# ind:  416
#
# row:  Seizure DateTime        3/3/2020 3:49
# CallTypeId                  911 Calls
# ALI Latitude                  36.2547
# ALI Longitude                -86.6849
# Cell Tower Address    WIRELESS CALLER
# Name: 416, dtype: object
#
# ind:  417
#
# row:  Seizure DateTime            3/3/2020 3:49
# CallTypeId                      911 Calls
# ALI Latitude                      36.2132
# ALI Longitude                    -86.6032
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 417, dtype: object
#
# ind:  418
#
# row:  Seizure DateTime        3/3/2020 3:50
# CallTypeId                  911 Calls
# ALI Latitude                  36.1681
# ALI Longitude                -86.8179
# Cell Tower Address    WIRELESS CALLER
# Name: 418, dtype: object
#
# ind:  419
#
# row:  Seizure DateTime        3/3/2020 3:50
# CallTypeId                  911 Calls
# ALI Latitude                   36.182
# ALI Longitude                 -86.772
# Cell Tower Address    WIRELESS CALLER
# Name: 419, dtype: object
#
# ind:  420
#
# row:  Seizure DateTime              3/3/2020 3:51
# CallTypeId                        911 Calls
# ALI Latitude                        36.1677
# ALI Longitude                      -86.8159
# Cell Tower Address    2101 E HEIMAN ST - SW
# Name: 420, dtype: object
#
# ind:  421
#
# row:  Seizure DateTime                          3/3/2020 3:52
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.0899
# ALI Longitude                                   -86.888
# Cell Tower Address    5801 OLD HARDING PIKE - SW SECTOR
# Name: 421, dtype: object
#
# ind:  422
#
# row:  Seizure DateTime        3/3/2020 3:52
# CallTypeId                  911 Calls
# ALI Latitude                  36.1676
# ALI Longitude                -86.7607
# Cell Tower Address    WIRELESS CALLER
# Name: 422, dtype: object
#
# ind:  423
#
# row:  Seizure DateTime                      3/3/2020 3:54
# CallTypeId                                911 Calls
# ALI Latitude                                36.0669
# ALI Longitude                              -86.6919
# Cell Tower Address    3930 APACHE TRAIL - SE SECTOR
# Name: 423, dtype: object
#
# ind:  424
#
# row:  Seizure DateTime        3/3/2020 3:57
# CallTypeId                  911 Calls
# ALI Latitude                  36.1904
# ALI Longitude                -86.8778
# Cell Tower Address    WIRELESS CALLER
# Name: 424, dtype: object
#
# ind:  425
#
# row:  Seizure DateTime        3/3/2020 3:57
# CallTypeId                  911 Calls
# ALI Latitude                  36.2049
# ALI Longitude                -86.6082
# Cell Tower Address    WIRELESS CALLER
# Name: 425, dtype: object
#
# ind:  426
#
# row:  Seizure DateTime               3/3/2020 3:58
# CallTypeId                         911 Calls
# ALI Latitude                         36.2786
# ALI Longitude                       -86.7733
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 426, dtype: object
#
# ind:  427
#
# row:  Seizure DateTime        3/3/2020 3:59
# CallTypeId                  911 Calls
# ALI Latitude                  36.1618
# ALI Longitude                -86.6233
# Cell Tower Address    WIRELESS CALLER
# Name: 427, dtype: object
#
# ind:  428
#
# row:  Seizure DateTime           3/3/2020 4:04
# CallTypeId                     911 Calls
# ALI Latitude                     36.1761
# ALI Longitude                    -86.775
# Cell Tower Address    19C OLDHAM ST - SE
# Name: 428, dtype: object
#
# ind:  429
#
# row:  Seizure DateTime        3/3/2020 4:05
# CallTypeId                  911 Calls
# ALI Latitude                  36.1801
# ALI Longitude                -86.7927
# Cell Tower Address    WIRELESS CALLER
# Name: 429, dtype: object
#
# ind:  430
#
# row:  Seizure DateTime                  3/3/2020 4:07
# CallTypeId                            911 Calls
# ALI Latitude                            36.1706
# ALI Longitude                          -86.7887
# Cell Tower Address    1316 JEWEL ST - SECTOR SW
# Name: 430, dtype: object
#
# ind:  431
#
# row:  Seizure DateTime                        3/3/2020 4:14
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1706
# ALI Longitude                                -86.7886
# Cell Tower Address    5043 HILLSBORO PIKE - SECTOR NE
# Name: 431, dtype: object
#
# ind:  432
#
# row:  Seizure DateTime              3/3/2020 4:14
# CallTypeId                        911 Calls
# ALI Latitude                        36.1435
# ALI Longitude                      -86.6884
# Cell Tower Address    600D MARRIOTT DR - SW
# Name: 432, dtype: object
#
# ind:  433
#
# row:  Seizure DateTime                3/3/2020 4:14
# CallTypeId                          911 Calls
# ALI Latitude                          36.0922
# ALI Longitude                        -86.6547
# Cell Tower Address    630F BROOKSBORO TER - N
# Name: 433, dtype: object
#
# ind:  434
#
# row:  Seizure DateTime         3/3/2020 4:17
# CallTypeId                   911 Calls
# ALI Latitude                    36.164
# ALI Longitude                 -86.7591
# Cell Tower Address    755 S 5TH ST - N
# Name: 434, dtype: object
#
# ind:  435
#
# row:  Seizure DateTime                         3/3/2020 4:19
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.2465
# ALI Longitude                                 -86.6678
# Cell Tower Address    1327-B NEELYS BEND RD - SECTOR N
# Name: 435, dtype: object
#
# ind:  436
#
# row:  Seizure DateTime                  3/3/2020 4:20
# CallTypeId                            911 Calls
# ALI Latitude                            36.2347
# ALI Longitude                          -86.6305
# Cell Tower Address    127 LEGIONS DR - S SECTOR
# Name: 436, dtype: object
#
# ind:  437
#
# row:  Seizure DateTime                  3/3/2020 4:20
# CallTypeId                            911 Calls
# ALI Latitude                            36.0964
# ALI Longitude                          -86.9408
# Cell Tower Address    301 FOREST VALLEY DR - SW
# Name: 437, dtype: object
#
# ind:  438
#
# row:  Seizure DateTime               3/3/2020 4:23
# CallTypeId                         911 Calls
# ALI Latitude                         36.2713
# ALI Longitude                       -86.7942
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 438, dtype: object
#
# ind:  439
#
# row:  Seizure DateTime        3/3/2020 4:23
# CallTypeId                  911 Calls
# ALI Latitude                   36.175
# ALI Longitude                -86.7392
# Cell Tower Address    121 S. 17TH ST.
# Name: 439, dtype: object
#
# ind:  440
#
# row:  Seizure DateTime                     3/3/2020 4:23
# CallTypeId                               911 Calls
# ALI Latitude                               36.1433
# ALI Longitude                             -86.6999
# Cell Tower Address    B 147 B SPENCE LN - E SECTOR
# Name: 440, dtype: object
#
# ind:  442
#
# row:  Seizure DateTime        3/3/2020 4:24
# CallTypeId                  911 Calls
# ALI Latitude                  36.0559
# ALI Longitude                  -86.69
# Cell Tower Address    WIRELESS CALLER
# Name: 442, dtype: object
#
# ind:  443
#
# row:  Seizure DateTime             3/3/2020 4:25
# CallTypeId                       911 Calls
# ALI Latitude                       36.1733
# ALI Longitude                     -86.8103
# Cell Tower Address    2101 E HEIMAN ST - N
# Name: 443, dtype: object
#
# ind:  444
#
# row:  Seizure DateTime                     3/3/2020 4:25
# CallTypeId                               911 Calls
# ALI Latitude                               36.1905
# ALI Longitude                             -86.8332
# Cell Tower Address    2111 Summitt Ave - Sector SW
# Name: 444, dtype: object
#
# ind:  445
#
# row:  Seizure DateTime                         3/3/2020 4:26
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 445, dtype: object
#
# ind:  446
#
# row:  Seizure DateTime                    3/3/2020 4:28
# CallTypeId                              911 Calls
# ALI Latitude                              36.1832
# ALI Longitude                            -87.0068
# Cell Tower Address    5060 TIDWELL HOLLOW RD - SW
# Name: 446, dtype: object
#
# ind:  447
#
# row:  Seizure DateTime               3/3/2020 4:29
# CallTypeId                         911 Calls
# ALI Latitude                         36.1764
# ALI Longitude                       -86.6862
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 447, dtype: object
#
# ind:  448
#
# row:  Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1896
# ALI Longitude                    -86.9987
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 448, dtype: object
#
# ind:  449
#
# row:  Seizure DateTime            3/3/2020 4:31
# CallTypeId                      911 Calls
# ALI Latitude                      36.1908
# ALI Longitude                    -86.9988
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 449, dtype: object
#
# ind:  450
#
# row:  Seizure DateTime                          3/3/2020 4:31
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.2728
# ALI Longitude                                  -86.7808
# Cell Tower Address    7479 OLD HICKORY BLVD. - E SECTOR
# Name: 450, dtype: object
#
# ind:  451
#
# row:  Seizure DateTime        3/3/2020 4:32
# CallTypeId                  911 Calls
# ALI Latitude                   36.141
# ALI Longitude                -86.7661
# Cell Tower Address    WIRELESS CALLER
# Name: 451, dtype: object
#
# ind:  452
#
# row:  Seizure DateTime                        3/3/2020 4:34
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.1527
# ALI Longitude                                -86.7734
# Cell Tower Address    707 3RD AVENUE SOUTH - W SECTOR
# Name: 452, dtype: object
#
# ind:  453
#
# row:  Seizure DateTime                         3/3/2020 4:35
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.1997
# ALI Longitude                                 -86.6201
# Cell Tower Address    4914 OLD HICKORY BLVD - S Sector
# Name: 453, dtype: object
#
# ind:  454
#
# row:  Seizure DateTime           3/3/2020 4:36
# CallTypeId                     911 Calls
# ALI Latitude                     36.2014
# ALI Longitude                   -86.7294
# Cell Tower Address    2002 CAHAL AVE - N
# Name: 454, dtype: object
#
# ind:  455
#
# row:  Seizure DateTime              3/3/2020 4:37
# CallTypeId                        911 Calls
# ALI Latitude                        36.2799
# ALI Longitude                      -86.8027
# Cell Tower Address    6292 FRUDEMAN RD - SE
# Name: 455, dtype: object
#
# ind:  456
#
# row:  Seizure DateTime                      3/3/2020 4:37
# CallTypeId                                911 Calls
# ALI Latitude                                36.1436
# ALI Longitude                              -86.6676
# Cell Tower Address    571D Clairidge DR - SE Sector
# Name: 456, dtype: object
#
# ind:  457
#
# row:  Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.1951
# ALI Longitude                         -86.7549
# Cell Tower Address    1316 JEWEL ST - W Sector
# Name: 457, dtype: object
#
# ind:  458
#
# row:  Seizure DateTime                 3/3/2020 4:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.2693
# ALI Longitude                         -86.7931
# Cell Tower Address    3565 TRAIL HOLLOW LN - N
# Name: 458, dtype: object
#
# ind:  459
#
# row:  Seizure DateTime        3/3/2020 4:39
# CallTypeId                  911 Calls
# ALI Latitude                  36.1755
# ALI Longitude                -86.7515
# Cell Tower Address    WIRELESS CALLER
# Name: 459, dtype: object
#
# ind:  460
#
# row:  Seizure DateTime        3/3/2020 4:40
# CallTypeId                  911 Calls
# ALI Latitude                  36.1802
# ALI Longitude                -86.7928
# Cell Tower Address    WIRELESS CALLER
# Name: 460, dtype: object
#
# ind:  461
#
# row:  Seizure DateTime        3/3/2020 4:41
# CallTypeId                  911 Calls
# ALI Latitude                   36.271
# ALI Longitude                -86.7604
# Cell Tower Address    WIRELESS CALLER
# Name: 461, dtype: object
#
# ind:  462
#
# row:  Seizure DateTime                     3/3/2020 4:42
# CallTypeId                               911 Calls
# ALI Latitude                               36.1353
# ALI Longitude                             -86.7894
# Cell Tower Address    1823 C 12TH AVE S - N Sector
# Name: 462, dtype: object
#
# ind:  464
#
# row:  Seizure DateTime                 3/3/2020 4:43
# CallTypeId                           911 Calls
# ALI Latitude                           36.1095
# ALI Longitude                         -86.9338
# Cell Tower Address    301 FOREST VALLEY DR - N
# Name: 464, dtype: object
#
# ind:  465
#
# row:  Seizure DateTime                       3/3/2020 4:45
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2789
# ALI Longitude                               -86.7737
# Cell Tower Address    1345 DICKERSON PKE - SECTOR SW
# Name: 465, dtype: object
#
# ind:  466
#
# row:  Seizure DateTime                     3/3/2020 4:46
# CallTypeId                               911 Calls
# ALI Latitude                               36.1769
# ALI Longitude                             -86.6759
# Cell Tower Address    610 BEN ALLEN RD - SECTOR SE
# Name: 466, dtype: object
#
# ind:  467
#
# row:  Seizure DateTime            3/3/2020 4:49
# CallTypeId                      911 Calls
# ALI Latitude                      36.1774
# ALI Longitude                    -86.7583
# Cell Tower Address    859 GRANADA AVE - S
# Name: 467, dtype: object
#
# ind:  468
#
# row:  Seizure DateTime        3/3/2020 4:52
# CallTypeId                  911 Calls
# ALI Latitude                  36.1944
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 468, dtype: object
#
# ind:  469
#
# row:  Seizure DateTime               3/3/2020 4:53
# CallTypeId                         911 Calls
# ALI Latitude                         36.2725
# ALI Longitude                       -86.7949
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 469, dtype: object
#
# ind:  470
#
# row:  Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1426
# ALI Longitude                -86.6353
# Cell Tower Address    WIRELESS CALLER
# Name: 470, dtype: object
#
# ind:  471
#
# row:  Seizure DateTime        3/3/2020 4:54
# CallTypeId                  911 Calls
# ALI Latitude                  36.1894
# ALI Longitude                -86.8136
# Cell Tower Address    WIRELESS CALLER
# Name: 471, dtype: object
#
# ind:  472
#
# row:  Seizure DateTime        3/3/2020 4:55
# CallTypeId                  911 Calls
# ALI Latitude                  36.2235
# ALI Longitude                -86.7579
# Cell Tower Address    WIRELESS CALLER
# Name: 472, dtype: object
#
# ind:  473
#
# row:  Seizure DateTime                          3/3/2020 4:56
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.1684
# ALI Longitude                                  -86.7838
# Cell Tower Address    600 DR MARTIN L KING JR BLVD - NE
# Name: 473, dtype: object
#
# ind:  474
#
# row:  Seizure DateTime               3/3/2020 4:58
# CallTypeId                         911 Calls
# ALI Latitude                         36.2766
# ALI Longitude                       -86.7994
# Cell Tower Address    4884 LICKTON PIKE - SE
# Name: 474, dtype: object

# %%
for row in tornado_dispatch.iterrows():
    print('row: ', row, '\n')
    print('first item: ', row[0], '\n')
    print('second item: ', row[1], '\n')
# Out:
# row:  (0, IncidentDate                                       3/3/2020 12:36:34 AM
# Location                                        6205 COCKRILL BEND CIR
# Latitude1                                                        36.182
# Longitude1                                                     -86.8941
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 0, dtype: object)
#
# first item:  0
#
# second item:  IncidentDate                                       3/3/2020 12:36:34 AM
# Location                                        6205 COCKRILL BEND CIR
# Latitude1                                                        36.182
# Longitude1                                                     -86.8941
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 0, dtype: object
#
# row:  (1, IncidentDate                                       3/3/2020 12:37:24 AM
# Location                                       7337 COCKRILL BEND BLVD
# Latitude1                                                       36.1757
# Longitude1                                                      -86.895
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 1, dtype: object)
#
# first item:  1
#
# second item:  IncidentDate                                       3/3/2020 12:37:24 AM
# Location                                       7337 COCKRILL BEND BLVD
# Latitude1                                                       36.1757
# Longitude1                                                      -86.895
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 1, dtype: object
#
# row:  (2, IncidentDate                                  3/3/2020 12:38:17 AM
# Location                                      110 TUNE AIRPORT DR
# Latitude1                                                  36.1793
# Longitude1                                                -86.8837
# IncidentTypeDescription1    STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# Name: 2, dtype: object)
#
# first item:  2
#
# second item:  IncidentDate                                  3/3/2020 12:38:17 AM
# Location                                      110 TUNE AIRPORT DR
# Latitude1                                                  36.1793
# Longitude1                                                -86.8837
# IncidentTypeDescription1    STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# Name: 2, dtype: object
#
# row:  (3, IncidentDate                                       3/3/2020 12:39:40 AM
# Location                                               555 MARRIOTT DR
# Latitude1                                                       36.1511
# Longitude1                                                     -86.6899
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 3, dtype: object)
#
# first item:  3
#
# second item:  IncidentDate                                       3/3/2020 12:39:40 AM
# Location                                               555 MARRIOTT DR
# Latitude1                                                       36.1511
# Longitude1                                                     -86.6899
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 3, dtype: object
#
# row:  (4, IncidentDate                                       3/3/2020 12:39:42 AM
# Location                                       1414 COUNTY HOSPITAL RD
# Latitude1                                                       36.1779
# Longitude1                                                     -86.8459
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 4, dtype: object)
#
# first item:  4
#
# second item:  IncidentDate                                       3/3/2020 12:39:42 AM
# Location                                       1414 COUNTY HOSPITAL RD
# Latitude1                                                       36.1779
# Longitude1                                                     -86.8459
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 4, dtype: object
#
# row:  (5, IncidentDate                                       3/3/2020 12:40:11 AM
# Location                                       1406 COUNTY HOSPITAL RD
# Latitude1                                                       36.1783
# Longitude1                                                     -86.8505
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 5, dtype: object)
#
# first item:  5
#
# second item:  IncidentDate                                       3/3/2020 12:40:11 AM
# Location                                       1406 COUNTY HOSPITAL RD
# Latitude1                                                       36.1783
# Longitude1                                                     -86.8505
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 5, dtype: object
#
# row:  (6, IncidentDate                                       3/3/2020 12:41:31 AM
# Location                                                  920 BROADWAY
# Latitude1                                                       36.1583
# Longitude1                                                     -86.7842
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 6, dtype: object)
#
# first item:  6
#
# second item:  IncidentDate                                       3/3/2020 12:41:31 AM
# Location                                                  920 BROADWAY
# Latitude1                                                       36.1583
# Longitude1                                                     -86.7842
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 6, dtype: object
#
# row:  (7, IncidentDate                                       3/3/2020 12:42:30 AM
# Location                                                 518 MONROE ST
# Latitude1                                                       36.1765
# Longitude1                                                     -86.7902
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 7, dtype: object)
#
# first item:  7
#
# second item:  IncidentDate                                       3/3/2020 12:42:30 AM
# Location                                                 518 MONROE ST
# Latitude1                                                       36.1765
# Longitude1                                                     -86.7902
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 7, dtype: object
#
# row:  (8, IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 8, dtype: object)
#
# first item:  8
#
# second item:  IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 8, dtype: object
#
# row:  (9, IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 9, dtype: object)
#
# first item:  9
#
# second item:  IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 9, dtype: object
#
# row:  (10, IncidentDate                                       3/3/2020 12:43:03 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 10, dtype: object)
#
# first item:  10
#
# second item:  IncidentDate                                       3/3/2020 12:43:03 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 10, dtype: object
#
# row:  (11, IncidentDate                3/3/2020 12:43:06 AM
# Location                           415 CHURCH ST
# Latitude1                                36.1634
# Longitude1                              -86.7795
# IncidentTypeDescription1          UNKNOWN STATUS
# Name: 11, dtype: object)
#
# first item:  11
#
# second item:  IncidentDate                3/3/2020 12:43:06 AM
# Location                           415 CHURCH ST
# Latitude1                                36.1634
# Longitude1                              -86.7795
# IncidentTypeDescription1          UNKNOWN STATUS
# Name: 11, dtype: object
#
# row:  (12, IncidentDate                                       3/3/2020 12:43:30 AM
# Location                                                 901 MONROE ST
# Latitude1                                                       36.1747
# Longitude1                                                     -86.7939
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 12, dtype: object)
#
# first item:  12
#
# second item:  IncidentDate                                       3/3/2020 12:43:30 AM
# Location                                                 901 MONROE ST
# Latitude1                                                       36.1747
# Longitude1                                                     -86.7939
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 12, dtype: object
#
# row:  (13, IncidentDate                3/3/2020 12:43:57 AM
# Location                       1603 COCKRILL ST
# Latitude1                                 36.175
# Longitude1                              -86.8055
# IncidentTypeDescription1     GENERAL ALARM HOUSE
# Name: 13, dtype: object)
#
# first item:  13
#
# second item:  IncidentDate                3/3/2020 12:43:57 AM
# Location                       1603 COCKRILL ST
# Latitude1                                 36.175
# Longitude1                              -86.8055
# IncidentTypeDescription1     GENERAL ALARM HOUSE
# Name: 13, dtype: object
#
# row:  (14, IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 14, dtype: object)
#
# first item:  14
#
# second item:  IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 14, dtype: object
#
# row:  (15, IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 15, dtype: object)
#
# first item:  15
#
# second item:  IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 15, dtype: object
#
# row:  (16, IncidentDate                           3/3/2020 12:44:29 AM
# Location                                      557 REVELS DR
# Latitude1                                             36.22
# Longitude1                                         -86.8065
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 16, dtype: object)
#
# first item:  16
#
# second item:  IncidentDate                           3/3/2020 12:44:29 AM
# Location                                      557 REVELS DR
# Latitude1                                             36.22
# Longitude1                                         -86.8065
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 16, dtype: object
#
# row:  (17, IncidentDate                            3/3/2020 12:44:49 AM
# Location                             7337 COCKRILL BEND BLVD
# Latitude1                                            36.1757
# Longitude1                                           -86.895
# IncidentTypeDescription1    BUILDING ENTRAPMENT  UNCONFIRMED
# Name: 17, dtype: object)
#
# first item:  17
#
# second item:  IncidentDate                            3/3/2020 12:44:49 AM
# Location                             7337 COCKRILL BEND BLVD
# Latitude1                                            36.1757
# Longitude1                                           -86.895
# IncidentTypeDescription1    BUILDING ENTRAPMENT  UNCONFIRMED
# Name: 17, dtype: object
#
# row:  (18, IncidentDate                                3/3/2020 12:45:08 AM
# Location                                 2ND AV N / JEFFERSON ST
# Latitude1                                                36.1753
# Longitude1                                              -86.7836
# IncidentTypeDescription1    CONFINED SPACE ENTRAPMENT  CONFIRMED
# Name: 18, dtype: object)
#
# first item:  18
#
# second item:  IncidentDate                                3/3/2020 12:45:08 AM
# Location                                 2ND AV N / JEFFERSON ST
# Latitude1                                                36.1753
# Longitude1                                              -86.7836
# IncidentTypeDescription1    CONFINED SPACE ENTRAPMENT  CONFIRMED
# Name: 18, dtype: object
#
# row:  (19, IncidentDate                3/3/2020 12:45:10 AM
# Location                      7135 CENTENNIAL PL
# Latitude1                                36.1769
# Longitude1                              -86.8799
# IncidentTypeDescription1        INSIDE FUEL ODOR
# Name: 19, dtype: object)
#
# first item:  19
#
# second item:  IncidentDate                3/3/2020 12:45:10 AM
# Location                      7135 CENTENNIAL PL
# Latitude1                                36.1769
# Longitude1                              -86.8799
# IncidentTypeDescription1        INSIDE FUEL ODOR
# Name: 19, dtype: object
#
# row:  (20, IncidentDate                                       3/3/2020 12:45:54 AM
# Location                                                  299 COWAN ST
# Latitude1                                                       36.1759
# Longitude1                                                     -86.7772
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 20, dtype: object)
#
# first item:  20
#
# second item:  IncidentDate                                       3/3/2020 12:45:54 AM
# Location                                                  299 COWAN ST
# Latitude1                                                       36.1759
# Longitude1                                                     -86.7772
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 20, dtype: object
#
# row:  (21, IncidentDate                                 3/3/2020 12:46:10 AM
# Location                                           1514 17TH AV N
# Latitude1                                                 36.1741
# Longitude1                                                -86.806
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 21, dtype: object)
#
# first item:  21
#
# second item:  IncidentDate                                 3/3/2020 12:46:10 AM
# Location                                           1514 17TH AV N
# Latitude1                                                 36.1741
# Longitude1                                                -86.806
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 21, dtype: object
#
# row:  (22, IncidentDate                 3/3/2020 12:46:33 AM
# Location                           201 GIFFORD PL
# Latitude1                                 36.3234
# Longitude1                               -86.8676
# IncidentTypeDescription1    DEFECATION / DIARRHEA
# Name: 22, dtype: object)
#
# first item:  22
#
# second item:  IncidentDate                 3/3/2020 12:46:33 AM
# Location                           201 GIFFORD PL
# Latitude1                                 36.3234
# Longitude1                               -86.8676
# IncidentTypeDescription1    DEFECATION / DIARRHEA
# Name: 22, dtype: object
#
# row:  (23, IncidentDate                                       3/3/2020 12:46:48 AM
# Location                                                 500 CHURCH ST
# Latitude1                                                       36.1632
# Longitude1                                                     -86.7805
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 23, dtype: object)
#
# first item:  23
#
# second item:  IncidentDate                                       3/3/2020 12:46:48 AM
# Location                                                 500 CHURCH ST
# Latitude1                                                       36.1632
# Longitude1                                                     -86.7805
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 23, dtype: object
#
# row:  (24, IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 24, dtype: object)
#
# first item:  24
#
# second item:  IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 24, dtype: object
#
# row:  (25, IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 25, dtype: object)
#
# first item:  25
#
# second item:  IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 25, dtype: object
#
# row:  (26, IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 26, dtype: object)
#
# first item:  26
#
# second item:  IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 26, dtype: object
#
# row:  (27, IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 27, dtype: object)
#
# first item:  27
#
# second item:  IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 27, dtype: object
#
# row:  (28, IncidentDate                        3/3/2020 12:50:06 AM
# Location                                  1400 14TH AV N
# Latitude1                                        36.1733
# Longitude1                                       -86.802
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 28, dtype: object)
#
# first item:  28
#
# second item:  IncidentDate                        3/3/2020 12:50:06 AM
# Location                                  1400 14TH AV N
# Latitude1                                        36.1733
# Longitude1                                       -86.802
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 28, dtype: object
#
# row:  (29, IncidentDate                                       3/3/2020 12:50:46 AM
# Location                                                  201 N 8TH ST
# Latitude1                                                       36.1767
# Longitude1                                                      -86.759
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 29, dtype: object)
#
# first item:  29
#
# second item:  IncidentDate                                       3/3/2020 12:50:46 AM
# Location                                                  201 N 8TH ST
# Latitude1                                                       36.1767
# Longitude1                                                      -86.759
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 29, dtype: object
#
# row:  (30, IncidentDate                            3/3/2020 12:52:36 AM
# Location                    JEFFERSON ST / ROSA L PARKS BLVD
# Latitude1                                            36.1733
# Longitude1                                          -86.7914
# IncidentTypeDescription1       UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 30, dtype: object)
#
# first item:  30
#
# second item:  IncidentDate                            3/3/2020 12:52:36 AM
# Location                    JEFFERSON ST / ROSA L PARKS BLVD
# Latitude1                                            36.1733
# Longitude1                                          -86.7914
# IncidentTypeDescription1       UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 30, dtype: object
#
# row:  (31, IncidentDate                                       3/3/2020 12:52:39 AM
# Location                                             300 DANYACREST DR
# Latitude1                                                       36.1837
# Longitude1                                                     -86.6501
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 31, dtype: object)
#
# first item:  31
#
# second item:  IncidentDate                                       3/3/2020 12:52:39 AM
# Location                                             300 DANYACREST DR
# Latitude1                                                       36.1837
# Longitude1                                                     -86.6501
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 31, dtype: object
#
# row:  (32, IncidentDate                                3/3/2020 12:53:28 AM
# Location                                            99 SPRING ST
# Latitude1                                                36.1766
# Longitude1                                              -86.7757
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 32, dtype: object)
#
# first item:  32
#
# second item:  IncidentDate                                3/3/2020 12:53:28 AM
# Location                                            99 SPRING ST
# Latitude1                                                36.1766
# Longitude1                                              -86.7757
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 32, dtype: object
#
# row:  (33, IncidentDate                                             3/3/2020 12:54:20 AM
# Location                                                        1220 2ND AV N
# Latitude1                                                             36.1772
# Longitude1                                                           -86.7847
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 33, dtype: object)
#
# first item:  33
#
# second item:  IncidentDate                                             3/3/2020 12:54:20 AM
# Location                                                        1220 2ND AV N
# Latitude1                                                             36.1772
# Longitude1                                                           -86.7847
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 33, dtype: object
#
# row:  (34, IncidentDate                         3/3/2020 12:54:54 AM
# Location                                    1000 2ND AV N
# Latitude1                                         36.1745
# Longitude1                                       -86.7827
# IncidentTypeDescription1    UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 34, dtype: object)
#
# first item:  34
#
# second item:  IncidentDate                         3/3/2020 12:54:54 AM
# Location                                    1000 2ND AV N
# Latitude1                                         36.1745
# Longitude1                                       -86.7827
# IncidentTypeDescription1    UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 34, dtype: object
#
# row:  (35, IncidentDate                              3/3/2020 12:55:00 AM
# Location                                 909 ROSA L PARKS BLVD
# Latitude1                                               36.171
# Longitude1                                            -86.7901
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 35, dtype: object)
#
# first item:  35
#
# second item:  IncidentDate                              3/3/2020 12:55:00 AM
# Location                                 909 ROSA L PARKS BLVD
# Latitude1                                               36.171
# Longitude1                                            -86.7901
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 35, dtype: object
#
# row:  (36, IncidentDate                                 3/3/2020 12:55:04 AM
# Location                                          1809 RUSSELL ST
# Latitude1                                                 36.1742
# Longitude1                                               -86.7376
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 36, dtype: object)
#
# first item:  36
#
# second item:  IncidentDate                                 3/3/2020 12:55:04 AM
# Location                                          1809 RUSSELL ST
# Latitude1                                                 36.1742
# Longitude1                                               -86.7376
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 36, dtype: object
#
# row:  (37, IncidentDate                                       3/3/2020 12:56:31 AM
# Location                                         5215 OLD HICKORY BLVD
# Latitude1                                                        36.189
# Longitude1                                                     -86.6154
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 37, dtype: object)
#
# first item:  37
#
# second item:  IncidentDate                                       3/3/2020 12:56:31 AM
# Location                                         5215 OLD HICKORY BLVD
# Latitude1                                                        36.189
# Longitude1                                                     -86.6154
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 37, dtype: object
#
# row:  (38, IncidentDate                              3/3/2020 12:56:54 AM
# Location                                      318 RIVERSIDE DR
# Latitude1                                              36.1784
# Longitude1                                            -86.7262
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 38, dtype: object)
#
# first item:  38
#
# second item:  IncidentDate                              3/3/2020 12:56:54 AM
# Location                                      318 RIVERSIDE DR
# Latitude1                                              36.1784
# Longitude1                                            -86.7262
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 38, dtype: object
#
# row:  (39, IncidentDate                               3/3/2020 12:57:10 AM
# Location                                          1072 1ST AV N
# Latitude1                                               36.1753
# Longitude1                                             -86.7819
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT LARGE BUILDING
# Name: 39, dtype: object)
#
# first item:  39
#
# second item:  IncidentDate                               3/3/2020 12:57:10 AM
# Location                                          1072 1ST AV N
# Latitude1                                               36.1753
# Longitude1                                             -86.7819
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT LARGE BUILDING
# Name: 39, dtype: object
#
# row:  (40, IncidentDate                               3/3/2020 12:57:14 AM
# Location                                          1211 6TH AV N
# Latitude1                                               36.1749
# Longitude1                                             -86.7895
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 40, dtype: object)
#
# first item:  40
#
# second item:  IncidentDate                               3/3/2020 12:57:14 AM
# Location                                          1211 6TH AV N
# Latitude1                                               36.1749
# Longitude1                                             -86.7895
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 40, dtype: object
#
# row:  (41, IncidentDate                                       3/3/2020 12:57:15 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 41, dtype: object)
#
# first item:  41
#
# second item:  IncidentDate                                       3/3/2020 12:57:15 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 41, dtype: object
#
# row:  (42, IncidentDate                       3/3/2020 12:58:26 AM
# Location                       1745 DR D B TODD JR BLVD
# Latitude1                                       36.1792
# Longitude1                                      -86.811
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 42, dtype: object)
#
# first item:  42
#
# second item:  IncidentDate                       3/3/2020 12:58:26 AM
# Location                       1745 DR D B TODD JR BLVD
# Latitude1                                       36.1792
# Longitude1                                      -86.811
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 42, dtype: object
#
# row:  (43, IncidentDate                                 3/3/2020 12:59:53 AM
# Location                                         941 JEFFERSON ST
# Latitude1                                                 36.1724
# Longitude1                                               -86.7945
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 43, dtype: object)
#
# first item:  43
#
# second item:  IncidentDate                                 3/3/2020 12:59:53 AM
# Location                                         941 JEFFERSON ST
# Latitude1                                                 36.1724
# Longitude1                                               -86.7945
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 43, dtype: object
#
# row:  (44, IncidentDate                                 3/3/2020 1:00:26 AM
# Location                                          30 MCFERRIN AV
# Latitude1                                                36.1772
# Longitude1                                              -86.7556
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 44, dtype: object)
#
# first item:  44
#
# second item:  IncidentDate                                 3/3/2020 1:00:26 AM
# Location                                          30 MCFERRIN AV
# Latitude1                                                36.1772
# Longitude1                                              -86.7556
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 44, dtype: object
#
# row:  (45, IncidentDate                         3/3/2020 1:00:50 AM
# Location                                 2410 LAZENBY DR
# Latitude1                                        36.1746
# Longitude1                                      -86.7206
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 45, dtype: object)
#
# first item:  45
#
# second item:  IncidentDate                         3/3/2020 1:00:50 AM
# Location                                 2410 LAZENBY DR
# Latitude1                                        36.1746
# Longitude1                                      -86.7206
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 45, dtype: object
#
# row:  (46, IncidentDate                           3/3/2020 1:01:26 AM
# Location                                    515 MADISON ST
# Latitude1                                          36.1747
# Longitude1                                        -86.7892
# IncidentTypeDescription1    BUILDING ENTRAPMENT  CONFIRMED
# Name: 46, dtype: object)
#
# first item:  46
#
# second item:  IncidentDate                           3/3/2020 1:01:26 AM
# Location                                    515 MADISON ST
# Latitude1                                          36.1747
# Longitude1                                        -86.7892
# IncidentTypeDescription1    BUILDING ENTRAPMENT  CONFIRMED
# Name: 46, dtype: object
#
# row:  (47, IncidentDate                       3/3/2020 1:01:34 AM
# Location                                 1608 HOLLY ST
# Latitude1                                      36.1752
# Longitude1                                    -86.7413
# IncidentTypeDescription1    APARTMENT NATURAL GAS ODOR
# Name: 47, dtype: object)
#
# first item:  47
#
# second item:  IncidentDate                       3/3/2020 1:01:34 AM
# Location                                 1608 HOLLY ST
# Latitude1                                      36.1752
# Longitude1                                    -86.7413
# IncidentTypeDescription1    APARTMENT NATURAL GAS ODOR
# Name: 47, dtype: object
#
# row:  (48, IncidentDate                       3/3/2020 1:03:53 AM
# Location                    3008 WHITLAND CROSSING DR
# Latitude1                                      36.1545
# Longitude1                                    -86.6671
# IncidentTypeDescription1      PULL STATION ALARM HOUSE
# Name: 48, dtype: object)
#
# first item:  48
#
# second item:  IncidentDate                       3/3/2020 1:03:53 AM
# Location                    3008 WHITLAND CROSSING DR
# Latitude1                                      36.1545
# Longitude1                                    -86.6671
# IncidentTypeDescription1      PULL STATION ALARM HOUSE
# Name: 48, dtype: object
#
# row:  (49, IncidentDate                                         3/3/2020 1:04:38 AM
# Location                                              2220 MAPLECREST DR
# Latitude1                                                        36.1782
# Longitude1                                                      -86.6923
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 49, dtype: object)
#
# first item:  49
#
# second item:  IncidentDate                                         3/3/2020 1:04:38 AM
# Location                                              2220 MAPLECREST DR
# Latitude1                                                        36.1782
# Longitude1                                                      -86.6923
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 49, dtype: object
#
# row:  (50, IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 50, dtype: object)
#
# first item:  50
#
# second item:  IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 50, dtype: object
#
# row:  (51, IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 51, dtype: object)
#
# first item:  51
#
# second item:  IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 51, dtype: object
#
# row:  (52, IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 52, dtype: object)
#
# first item:  52
#
# second item:  IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 52, dtype: object
#
# row:  (53, IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 53, dtype: object)
#
# first item:  53
#
# second item:  IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 53, dtype: object
#
# row:  (54, IncidentDate                                 3/3/2020 1:06:29 AM
# Location                                            10 S 14TH ST
# Latitude1                                                36.1763
# Longitude1                                              -86.7462
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 54, dtype: object)
#
# first item:  54
#
# second item:  IncidentDate                                 3/3/2020 1:06:29 AM
# Location                                            10 S 14TH ST
# Latitude1                                                36.1763
# Longitude1                                              -86.7462
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 54, dtype: object
#
# row:  (55, IncidentDate                                         3/3/2020 1:06:59 AM
# Location                                                3132 EDGEMONT DR
# Latitude1                                                        36.1838
# Longitude1                                                       -86.645
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 55, dtype: object)
#
# first item:  55
#
# second item:  IncidentDate                                         3/3/2020 1:06:59 AM
# Location                                                3132 EDGEMONT DR
# Latitude1                                                        36.1838
# Longitude1                                                       -86.645
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 55, dtype: object
#
# row:  (56, IncidentDate                                  3/3/2020 1:08:07 AM
# Location                                     4672 FOREST RIDGE DR
# Latitude1                                                 36.1784
# Longitude1                                               -86.5868
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 56, dtype: object)
#
# first item:  56
#
# second item:  IncidentDate                                  3/3/2020 1:08:07 AM
# Location                                     4672 FOREST RIDGE DR
# Latitude1                                                 36.1784
# Longitude1                                               -86.5868
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 56, dtype: object
#
# row:  (57, IncidentDate                         3/3/2020 1:08:53 AM
# Location                                   8 MCFERRIN AV
# Latitude1                                        36.1761
# Longitude1                                      -86.7555
# IncidentTypeDescription1    TRAUMATIC INJURIES NOT ALERT
# Name: 57, dtype: object)
#
# first item:  57
#
# second item:  IncidentDate                         3/3/2020 1:08:53 AM
# Location                                   8 MCFERRIN AV
# Latitude1                                        36.1761
# Longitude1                                      -86.7555
# IncidentTypeDescription1    TRAUMATIC INJURIES NOT ALERT
# Name: 57, dtype: object
#
# row:  (58, IncidentDate                3/3/2020 1:09:44 AM
# Location                          8 MCFERRIN AV
# Latitude1                               36.1761
# Longitude1                             -86.7555
# IncidentTypeDescription1         UNKNOWN STATUS
# Name: 58, dtype: object)
#
# first item:  58
#
# second item:  IncidentDate                3/3/2020 1:09:44 AM
# Location                          8 MCFERRIN AV
# Latitude1                               36.1761
# Longitude1                             -86.7555
# IncidentTypeDescription1         UNKNOWN STATUS
# Name: 58, dtype: object
#
# row:  (59, IncidentDate                         3/3/2020 1:12:27 AM
# Location                                3140 STAFFORD DR
# Latitude1                                        36.1841
# Longitude1                                      -86.6485
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 59, dtype: object)
#
# first item:  59
#
# second item:  IncidentDate                         3/3/2020 1:12:27 AM
# Location                                3140 STAFFORD DR
# Latitude1                                        36.1841
# Longitude1                                      -86.6485
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 59, dtype: object
#
# row:  (60, IncidentDate                                 3/3/2020 1:14:34 AM
# Location                                   5610 OLD HICKORY BLVD
# Latitude1                                                36.1807
# Longitude1                                              -86.6022
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 60, dtype: object)
#
# first item:  60
#
# second item:  IncidentDate                                 3/3/2020 1:14:34 AM
# Location                                   5610 OLD HICKORY BLVD
# Latitude1                                                36.1807
# Longitude1                                              -86.6022
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 60, dtype: object
#
# row:  (61, IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 61, dtype: object)
#
# first item:  61
#
# second item:  IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 61, dtype: object
#
# row:  (62, IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 62, dtype: object)
#
# first item:  62
#
# second item:  IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 62, dtype: object
#
# row:  (63, IncidentDate                3/3/2020 1:19:25 AM
# Location                          120 S 10TH ST
# Latitude1                               36.1758
# Longitude1                             -86.7518
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 63, dtype: object)
#
# first item:  63
#
# second item:  IncidentDate                3/3/2020 1:19:25 AM
# Location                          120 S 10TH ST
# Latitude1                               36.1758
# Longitude1                             -86.7518
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 63, dtype: object
#
# row:  (64, IncidentDate                3/3/2020 1:19:25 AM
# Location                          120 S 10TH ST
# ...
# Location                                  ELLINGTON PKWY S / SPRING ST
# Latitude1                                                       36.176
# Longitude1                                                    -86.7664
# IncidentTypeDescription1    ELECTRICAL INVESTIGATION UNKNOWN SITUATION
# Name: 237, dtype: object
#
# row:  (238, IncidentDate                       3/3/2020 4:26:08 AM
# Location                                 121 S 17TH ST
# Latitude1                                      36.1749
# Longitude1                                    -86.7393
# IncidentTypeDescription1    SMOKE DETECTOR ALARM HOUSE
# Name: 238, dtype: object)
#
# first item:  238
#
# second item:  IncidentDate                       3/3/2020 4:26:08 AM
# Location                                 121 S 17TH ST
# Latitude1                                      36.1749
# Longitude1                                    -86.7393
# IncidentTypeDescription1    SMOKE DETECTOR ALARM HOUSE
# Name: 238, dtype: object
#
# row:  (239, IncidentDate                         3/3/2020 4:26:40 AM
# Location                               1824 UNDERWOOD ST
# Latitude1                                        36.1733
# Longitude1                                      -86.8102
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 239, dtype: object)
#
# first item:  239
#
# second item:  IncidentDate                         3/3/2020 4:26:40 AM
# Location                               1824 UNDERWOOD ST
# Latitude1                                        36.1733
# Longitude1                                      -86.8102
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 239, dtype: object
#
# row:  (240, IncidentDate                                              3/3/2020 4:27:57 AM
# Location                                                      200 ATHENS WAY
# Latitude1                                                             36.1958
# Longitude1                                                           -86.7993
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 240, dtype: object)
#
# first item:  240
#
# second item:  IncidentDate                                              3/3/2020 4:27:57 AM
# Location                                                      200 ATHENS WAY
# Latitude1                                                             36.1958
# Longitude1                                                           -86.7993
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 240, dtype: object
#
# row:  (241, IncidentDate                                 3/3/2020 4:30:49 AM
# Location                                           2322 SELMA AV
# Latitude1                                                36.1757
# Longitude1                                               -86.686
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 241, dtype: object)
#
# first item:  241
#
# second item:  IncidentDate                                 3/3/2020 4:30:49 AM
# Location                                           2322 SELMA AV
# Latitude1                                                36.1757
# Longitude1                                               -86.686
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 241, dtype: object
#
# row:  (242, IncidentDate                   3/3/2020 4:38:03 AM
# Location                             1202 7TH AV N
# Latitude1                                  36.1745
# Longitude1                                -86.7904
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 242, dtype: object)
#
# first item:  242
#
# second item:  IncidentDate                   3/3/2020 4:38:03 AM
# Location                             1202 7TH AV N
# Latitude1                                  36.1745
# Longitude1                                -86.7904
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 242, dtype: object
#
# row:  (243, IncidentDate                                 3/3/2020 4:38:24 AM
# Location                                NEWHALL DR / BRITTANY DR
# Latitude1                                                36.1762
# Longitude1                                               -86.723
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 243, dtype: object)
#
# first item:  243
#
# second item:  IncidentDate                                 3/3/2020 4:38:24 AM
# Location                                NEWHALL DR / BRITTANY DR
# Latitude1                                                36.1762
# Longitude1                                               -86.723
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 243, dtype: object
#
# row:  (244, IncidentDate                  3/3/2020 4:39:10 AM
# Location                        856 BLOOMDALE TRC
# Latitude1                                 36.1802
# Longitude1                               -86.5992
# IncidentTypeDescription1    WATERFLOW ALARM HOUSE
# Name: 244, dtype: object)
#
# first item:  244
#
# second item:  IncidentDate                  3/3/2020 4:39:10 AM
# Location                        856 BLOOMDALE TRC
# Latitude1                                 36.1802
# Longitude1                               -86.5992
# IncidentTypeDescription1    WATERFLOW ALARM HOUSE
# Name: 244, dtype: object
#
# row:  (245, IncidentDate                                 3/3/2020 4:40:25 AM
# Location                                          1736 24TH AV N
# Latitude1                                                36.1789
# Longitude1                                              -86.8154
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 245, dtype: object)
#
# first item:  245
#
# second item:  IncidentDate                                 3/3/2020 4:40:25 AM
# Location                                          1736 24TH AV N
# Latitude1                                                36.1789
# Longitude1                                              -86.8154
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 245, dtype: object
#
# row:  (246, IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 246, dtype: object)
#
# first item:  246
#
# second item:  IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 246, dtype: object
#
# row:  (247, IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 247, dtype: object)
#
# first item:  247
#
# second item:  IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 247, dtype: object
#
# row:  (248, IncidentDate                         3/3/2020 4:43:51 AM
# Location                    OLD HICKORY BLVD / LAWING DR
# Latitude1                                         36.275
# Longitude1                                      -86.7647
# IncidentTypeDescription1       HIGH MECHANISM: ROLLOVERS
# Name: 248, dtype: object)
#
# first item:  248
#
# second item:  IncidentDate                         3/3/2020 4:43:51 AM
# Location                    OLD HICKORY BLVD / LAWING DR
# Latitude1                                         36.275
# Longitude1                                      -86.7647
# IncidentTypeDescription1       HIGH MECHANISM: ROLLOVERS
# Name: 248, dtype: object
#
# row:  (249, IncidentDate                                        3/3/2020 4:44:36 AM
# Location                                                 713 RAMSEY ST
# Latitude1                                                       36.1763
# Longitude1                                                     -86.7606
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 249, dtype: object)
#
# first item:  249
#
# second item:  IncidentDate                                        3/3/2020 4:44:36 AM
# Location                                                 713 RAMSEY ST
# Latitude1                                                       36.1763
# Longitude1                                                     -86.7606
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 249, dtype: object
#
# row:  (250, IncidentDate                    3/3/2020 4:44:59 AM
# Location                           4215 HARDING PKE
# Latitude1                                    36.129
# Longitude1                                 -86.8409
# IncidentTypeDescription1    NOT DANGEROUS BODY AREA
# Name: 250, dtype: object)
#
# first item:  250
#
# second item:  IncidentDate                    3/3/2020 4:44:59 AM
# Location                           4215 HARDING PKE
# Latitude1                                    36.129
# Longitude1                                 -86.8409
# IncidentTypeDescription1    NOT DANGEROUS BODY AREA
# Name: 250, dtype: object
#
# row:  (251, IncidentDate                                 3/3/2020 4:50:09 AM
# Location                                  LINCOYA DR / MERLYN LN
# Latitude1                                                36.1767
# Longitude1                                              -86.6756
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 251, dtype: object)
#
# first item:  251
#
# second item:  IncidentDate                                 3/3/2020 4:50:09 AM
# Location                                  LINCOYA DR / MERLYN LN
# Latitude1                                                36.1767
# Longitude1                                              -86.6756
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 251, dtype: object
#
# row:  (252, IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 252, dtype: object)
#
# first item:  252
#
# second item:  IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 252, dtype: object
#
# row:  (253, IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 253, dtype: object)
#
# first item:  253
#
# second item:  IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 253, dtype: object
#
# row:  (254, IncidentDate                                 3/3/2020 4:51:36 AM
# Location                                           821 RAMSEY ST
# Latitude1                                                36.1771
# Longitude1                                              -86.7579
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 254, dtype: object)
#
# first item:  254
#
# second item:  IncidentDate                                 3/3/2020 4:51:36 AM
# Location                                           821 RAMSEY ST
# Latitude1                                                36.1771
# Longitude1                                              -86.7579
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 254, dtype: object
#
# row:  (255, IncidentDate                                              3/3/2020 4:53:43 AM
# Location                                                       1616 23RD AV N
# Latitude1                                                             36.1757
# Longitude1                                                           -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING POWER DISCO...
# Name: 255, dtype: object)
#
# first item:  255
#
# second item:  IncidentDate                                              3/3/2020 4:53:43 AM
# Location                                                       1616 23RD AV N
# Latitude1                                                             36.1757
# Longitude1                                                           -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING POWER DISCO...
# Name: 255, dtype: object
#
# row:  (256, IncidentDate                         3/3/2020 4:56:56 AM
# Location                           5610 OLD HICKORY BLVD
# Latitude1                                        36.1805
# Longitude1                                      -86.6015
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 256, dtype: object)
#
# first item:  256
#
# second item:  IncidentDate                         3/3/2020 4:56:56 AM
# Location                           5610 OLD HICKORY BLVD
# Latitude1                                        36.1805
# Longitude1                                      -86.6015
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 256, dtype: object
#
# row:  (257, IncidentDate                            3/3/2020 4:57:06 AM
# Location                                2903 MORNINGSIDE DR
# Latitude1                                           36.2236
# Longitude1                                         -86.7579
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 257, dtype: object)
#
# first item:  257
#
# second item:  IncidentDate                            3/3/2020 4:57:06 AM
# Location                                2903 MORNINGSIDE DR
# Latitude1                                           36.2236
# Longitude1                                         -86.7579
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 257, dtype: object
#
# row:  (258, IncidentDate                                   3/3/2020 4:57:14 AM
# Location                                            1730 KELLOW ST
# Latitude1                                                  36.1894
# Longitude1                                                -86.8135
# IncidentTypeDescription1    ABNORMAL BREATHING OTHER LUNG PROBLEMS
# Name: 258, dtype: object)
#
# first item:  258
#
# second item:  IncidentDate                                   3/3/2020 4:57:14 AM
# Location                                            1730 KELLOW ST
# Latitude1                                                  36.1894
# Longitude1                                                -86.8135
# IncidentTypeDescription1    ABNORMAL BREATHING OTHER LUNG PROBLEMS
# Name: 258, dtype: object
#
# row:  (259, IncidentDate                        3/3/2020 4:57:48 AM
# Location                    I24 W / HICKORY HOLLOW PKWY
# Latitude1                                       36.0397
# Longitude1                                     -86.6491
# IncidentTypeDescription1                UNKNOWN STATUS:
# Name: 259, dtype: object)
#
# first item:  259
#
# second item:  IncidentDate                        3/3/2020 4:57:48 AM
# Location                    I24 W / HICKORY HOLLOW PKWY
# Latitude1                                       36.0397
# Longitude1                                     -86.6491
# IncidentTypeDescription1                UNKNOWN STATUS:
# Name: 259, dtype: object

# %%
for ind, row in tornado_dispatch.iterrows():
    print('ind: ', ind, '\n')
    print('row: ', row, '\n')
# Out:
# ind:  0
#
# row:  IncidentDate                                       3/3/2020 12:36:34 AM
# Location                                        6205 COCKRILL BEND CIR
# Latitude1                                                        36.182
# Longitude1                                                     -86.8941
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 0, dtype: object
#
# ind:  1
#
# row:  IncidentDate                                       3/3/2020 12:37:24 AM
# Location                                       7337 COCKRILL BEND BLVD
# Latitude1                                                       36.1757
# Longitude1                                                      -86.895
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 1, dtype: object
#
# ind:  2
#
# row:  IncidentDate                                  3/3/2020 12:38:17 AM
# Location                                      110 TUNE AIRPORT DR
# Latitude1                                                  36.1793
# Longitude1                                                -86.8837
# IncidentTypeDescription1    STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# Name: 2, dtype: object
#
# ind:  3
#
# row:  IncidentDate                                       3/3/2020 12:39:40 AM
# Location                                               555 MARRIOTT DR
# Latitude1                                                       36.1511
# Longitude1                                                     -86.6899
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 3, dtype: object
#
# ind:  4
#
# row:  IncidentDate                                       3/3/2020 12:39:42 AM
# Location                                       1414 COUNTY HOSPITAL RD
# Latitude1                                                       36.1779
# Longitude1                                                     -86.8459
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 4, dtype: object
#
# ind:  5
#
# row:  IncidentDate                                       3/3/2020 12:40:11 AM
# Location                                       1406 COUNTY HOSPITAL RD
# Latitude1                                                       36.1783
# Longitude1                                                     -86.8505
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 5, dtype: object
#
# ind:  6
#
# row:  IncidentDate                                       3/3/2020 12:41:31 AM
# Location                                                  920 BROADWAY
# Latitude1                                                       36.1583
# Longitude1                                                     -86.7842
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 6, dtype: object
#
# ind:  7
#
# row:  IncidentDate                                       3/3/2020 12:42:30 AM
# Location                                                 518 MONROE ST
# Latitude1                                                       36.1765
# Longitude1                                                     -86.7902
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 7, dtype: object
#
# ind:  8
#
# row:  IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 8, dtype: object
#
# ind:  9
#
# row:  IncidentDate                                       3/3/2020 12:42:51 AM
# Location                                      1625 DR D B TODD JR BLVD
# Latitude1                                                       36.1756
# Longitude1                                                     -86.8097
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 9, dtype: object
#
# ind:  10
#
# row:  IncidentDate                                       3/3/2020 12:43:03 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 10, dtype: object
#
# ind:  11
#
# row:  IncidentDate                3/3/2020 12:43:06 AM
# Location                           415 CHURCH ST
# Latitude1                                36.1634
# Longitude1                              -86.7795
# IncidentTypeDescription1          UNKNOWN STATUS
# Name: 11, dtype: object
#
# ind:  12
#
# row:  IncidentDate                                       3/3/2020 12:43:30 AM
# Location                                                 901 MONROE ST
# Latitude1                                                       36.1747
# Longitude1                                                     -86.7939
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 12, dtype: object
#
# ind:  13
#
# row:  IncidentDate                3/3/2020 12:43:57 AM
# Location                       1603 COCKRILL ST
# Latitude1                                 36.175
# Longitude1                              -86.8055
# IncidentTypeDescription1     GENERAL ALARM HOUSE
# Name: 13, dtype: object
#
# ind:  14
#
# row:  IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 14, dtype: object
#
# ind:  15
#
# row:  IncidentDate                                             3/3/2020 12:44:02 AM
# Location                                              1000 ROSA L PARKS BLVD
# Latitude1                                                             36.1725
# Longitude1                                                           -86.7901
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 15, dtype: object
#
# ind:  16
#
# row:  IncidentDate                           3/3/2020 12:44:29 AM
# Location                                      557 REVELS DR
# Latitude1                                             36.22
# Longitude1                                         -86.8065
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 16, dtype: object
#
# ind:  17
#
# row:  IncidentDate                            3/3/2020 12:44:49 AM
# Location                             7337 COCKRILL BEND BLVD
# Latitude1                                            36.1757
# Longitude1                                           -86.895
# IncidentTypeDescription1    BUILDING ENTRAPMENT  UNCONFIRMED
# Name: 17, dtype: object
#
# ind:  18
#
# row:  IncidentDate                                3/3/2020 12:45:08 AM
# Location                                 2ND AV N / JEFFERSON ST
# Latitude1                                                36.1753
# Longitude1                                              -86.7836
# IncidentTypeDescription1    CONFINED SPACE ENTRAPMENT  CONFIRMED
# Name: 18, dtype: object
#
# ind:  19
#
# row:  IncidentDate                3/3/2020 12:45:10 AM
# Location                      7135 CENTENNIAL PL
# Latitude1                                36.1769
# Longitude1                              -86.8799
# IncidentTypeDescription1        INSIDE FUEL ODOR
# Name: 19, dtype: object
#
# ind:  20
#
# row:  IncidentDate                                       3/3/2020 12:45:54 AM
# Location                                                  299 COWAN ST
# Latitude1                                                       36.1759
# Longitude1                                                     -86.7772
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 20, dtype: object
#
# ind:  21
#
# row:  IncidentDate                                 3/3/2020 12:46:10 AM
# Location                                           1514 17TH AV N
# Latitude1                                                 36.1741
# Longitude1                                                -86.806
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 21, dtype: object
#
# ind:  22
#
# row:  IncidentDate                 3/3/2020 12:46:33 AM
# Location                           201 GIFFORD PL
# Latitude1                                 36.3234
# Longitude1                               -86.8676
# IncidentTypeDescription1    DEFECATION / DIARRHEA
# Name: 22, dtype: object
#
# ind:  23
#
# row:  IncidentDate                                       3/3/2020 12:46:48 AM
# Location                                                 500 CHURCH ST
# Latitude1                                                       36.1632
# Longitude1                                                     -86.7805
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 23, dtype: object
#
# ind:  24
#
# row:  IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 24, dtype: object
#
# ind:  25
#
# row:  IncidentDate                                       3/3/2020 12:47:35 AM
# Location                                                   900 MAIN ST
# Latitude1                                                       36.1759
# Longitude1                                                      -86.757
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 25, dtype: object
#
# ind:  26
#
# row:  IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 26, dtype: object
#
# ind:  27
#
# row:  IncidentDate                              3/3/2020 12:49:18 AM
# Location                                        1608 23RD AV N
# Latitude1                                              36.1752
# Longitude1                                            -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 27, dtype: object
#
# ind:  28
#
# row:  IncidentDate                        3/3/2020 12:50:06 AM
# Location                                  1400 14TH AV N
# Latitude1                                        36.1733
# Longitude1                                       -86.802
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 28, dtype: object
#
# ind:  29
#
# row:  IncidentDate                                       3/3/2020 12:50:46 AM
# Location                                                  201 N 8TH ST
# Latitude1                                                       36.1767
# Longitude1                                                      -86.759
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 29, dtype: object
#
# ind:  30
#
# row:  IncidentDate                            3/3/2020 12:52:36 AM
# Location                    JEFFERSON ST / ROSA L PARKS BLVD
# Latitude1                                            36.1733
# Longitude1                                          -86.7914
# IncidentTypeDescription1       UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 30, dtype: object
#
# ind:  31
#
# row:  IncidentDate                                       3/3/2020 12:52:39 AM
# Location                                             300 DANYACREST DR
# Latitude1                                                       36.1837
# Longitude1                                                     -86.6501
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 31, dtype: object
#
# ind:  32
#
# row:  IncidentDate                                3/3/2020 12:53:28 AM
# Location                                            99 SPRING ST
# Latitude1                                                36.1766
# Longitude1                                              -86.7757
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 32, dtype: object
#
# ind:  33
#
# row:  IncidentDate                                             3/3/2020 12:54:20 AM
# Location                                                        1220 2ND AV N
# Latitude1                                                             36.1772
# Longitude1                                                           -86.7847
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 33, dtype: object
#
# ind:  34
#
# row:  IncidentDate                         3/3/2020 12:54:54 AM
# Location                                    1000 2ND AV N
# Latitude1                                         36.1745
# Longitude1                                       -86.7827
# IncidentTypeDescription1    UNKNOWN ENTRAPMENT  CONFIRMED
# Name: 34, dtype: object
#
# ind:  35
#
# row:  IncidentDate                              3/3/2020 12:55:00 AM
# Location                                 909 ROSA L PARKS BLVD
# Latitude1                                               36.171
# Longitude1                                            -86.7901
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 35, dtype: object
#
# ind:  36
#
# row:  IncidentDate                                 3/3/2020 12:55:04 AM
# Location                                          1809 RUSSELL ST
# Latitude1                                                 36.1742
# Longitude1                                               -86.7376
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 36, dtype: object
#
# ind:  37
#
# row:  IncidentDate                                       3/3/2020 12:56:31 AM
# Location                                         5215 OLD HICKORY BLVD
# Latitude1                                                        36.189
# Longitude1                                                     -86.6154
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 37, dtype: object
#
# ind:  38
#
# row:  IncidentDate                              3/3/2020 12:56:54 AM
# Location                                      318 RIVERSIDE DR
# Latitude1                                              36.1784
# Longitude1                                            -86.7262
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 38, dtype: object
#
# ind:  39
#
# row:  IncidentDate                               3/3/2020 12:57:10 AM
# Location                                          1072 1ST AV N
# Latitude1                                               36.1753
# Longitude1                                             -86.7819
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT LARGE BUILDING
# Name: 39, dtype: object
#
# ind:  40
#
# row:  IncidentDate                               3/3/2020 12:57:14 AM
# Location                                          1211 6TH AV N
# Latitude1                                               36.1749
# Longitude1                                             -86.7895
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 40, dtype: object
#
# ind:  41
#
# row:  IncidentDate                                       3/3/2020 12:57:15 AM
# Location                                                   915 3RD AV N
# Latitude1                                                        36.173
# Longitude1                                                     -86.7836
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 41, dtype: object
#
# ind:  42
#
# row:  IncidentDate                       3/3/2020 12:58:26 AM
# Location                       1745 DR D B TODD JR BLVD
# Latitude1                                       36.1792
# Longitude1                                      -86.811
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 42, dtype: object
#
# ind:  43
#
# row:  IncidentDate                                 3/3/2020 12:59:53 AM
# Location                                         941 JEFFERSON ST
# Latitude1                                                 36.1724
# Longitude1                                               -86.7945
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 43, dtype: object
#
# ind:  44
#
# row:  IncidentDate                                 3/3/2020 1:00:26 AM
# Location                                          30 MCFERRIN AV
# Latitude1                                                36.1772
# Longitude1                                              -86.7556
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 44, dtype: object
#
# ind:  45
#
# row:  IncidentDate                         3/3/2020 1:00:50 AM
# Location                                 2410 LAZENBY DR
# Latitude1                                        36.1746
# Longitude1                                      -86.7206
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 45, dtype: object
#
# ind:  46
#
# row:  IncidentDate                           3/3/2020 1:01:26 AM
# Location                                    515 MADISON ST
# Latitude1                                          36.1747
# Longitude1                                        -86.7892
# IncidentTypeDescription1    BUILDING ENTRAPMENT  CONFIRMED
# Name: 46, dtype: object
#
# ind:  47
#
# row:  IncidentDate                       3/3/2020 1:01:34 AM
# Location                                 1608 HOLLY ST
# Latitude1                                      36.1752
# Longitude1                                    -86.7413
# IncidentTypeDescription1    APARTMENT NATURAL GAS ODOR
# Name: 47, dtype: object
#
# ind:  48
#
# row:  IncidentDate                       3/3/2020 1:03:53 AM
# Location                    3008 WHITLAND CROSSING DR
# Latitude1                                      36.1545
# Longitude1                                    -86.6671
# IncidentTypeDescription1      PULL STATION ALARM HOUSE
# Name: 48, dtype: object
#
# ind:  49
#
# row:  IncidentDate                                         3/3/2020 1:04:38 AM
# Location                                              2220 MAPLECREST DR
# Latitude1                                                        36.1782
# Longitude1                                                      -86.6923
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 49, dtype: object
#
# ind:  50
#
# row:  IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 50, dtype: object
#
# ind:  51
#
# row:  IncidentDate                                           3/3/2020 1:05:10 AM
# Location                                                    1620 24TH AV N
# Latitude1                                                           36.175
# Longitude1                                                        -86.8147
# IncidentTypeDescription1    CONFIRMED ENTRAP BUILDING COLLAPSE WITH HAZMAT
# Name: 51, dtype: object
#
# ind:  52
#
# row:  IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 52, dtype: object
#
# ind:  53
#
# row:  IncidentDate                                  3/3/2020 1:06:14 AM
# Location                                            3204 DINAH CT
# Latitude1                                                 36.1842
# Longitude1                                               -86.6426
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 53, dtype: object
#
# ind:  54
#
# row:  IncidentDate                                 3/3/2020 1:06:29 AM
# Location                                            10 S 14TH ST
# Latitude1                                                36.1763
# Longitude1                                              -86.7462
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 54, dtype: object
#
# ind:  55
#
# row:  IncidentDate                                         3/3/2020 1:06:59 AM
# Location                                                3132 EDGEMONT DR
# Latitude1                                                        36.1838
# Longitude1                                                       -86.645
# IncidentTypeDescription1    CONFIRMED ENTRAP SMALL BUILDING  WITH HAZMAT
# Name: 55, dtype: object
#
# ind:  56
#
# row:  IncidentDate                                  3/3/2020 1:08:07 AM
# Location                                     4672 FOREST RIDGE DR
# Latitude1                                                 36.1784
# Longitude1                                               -86.5868
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 56, dtype: object
#
# ind:  57
#
# row:  IncidentDate                         3/3/2020 1:08:53 AM
# Location                                   8 MCFERRIN AV
# Latitude1                                        36.1761
# Longitude1                                      -86.7555
# IncidentTypeDescription1    TRAUMATIC INJURIES NOT ALERT
# Name: 57, dtype: object
#
# ind:  58
#
# row:  IncidentDate                3/3/2020 1:09:44 AM
# Location                          8 MCFERRIN AV
# Latitude1                               36.1761
# Longitude1                             -86.7555
# IncidentTypeDescription1         UNKNOWN STATUS
# Name: 58, dtype: object
#
# ind:  59
#
# row:  IncidentDate                         3/3/2020 1:12:27 AM
# Location                                3140 STAFFORD DR
# Latitude1                                        36.1841
# Longitude1                                      -86.6485
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 59, dtype: object
#
# ind:  60
#
# row:  IncidentDate                                 3/3/2020 1:14:34 AM
# Location                                   5610 OLD HICKORY BLVD
# Latitude1                                                36.1807
# Longitude1                                              -86.6022
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 60, dtype: object
#
# ind:  61
#
# row:  IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 61, dtype: object
#
# ind:  62
#
# row:  IncidentDate                              3/3/2020 1:15:14 AM
# Location                                        1100 3RD AV N
# Latitude1                                             36.1758
# Longitude1                                            -86.785
# IncidentTypeDescription1    HIGH LIFE HAZARD NATURAL GAS LEAK
# Name: 62, dtype: object
#
# ind:  63
#
# row:  IncidentDate                3/3/2020 1:19:25 AM
# Location                          120 S 10TH ST
# Latitude1                               36.1758
# Longitude1                             -86.7518
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 63, dtype: object
#
# ind:  64
#
# row:  IncidentDate                3/3/2020 1:19:25 AM
# Location                          120 S 10TH ST
# Latitude1                               36.1758
# Longitude1                             -86.7518
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 64, dtype: object
#
# ind:  65
#
# row:  IncidentDate                                3/3/2020 1:21:08 AM
# Location                                       263 RIVERSIDE DR
# Latitude1                                               36.1755
# Longitude1                                             -86.7262
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 65, dtype: object
#
# ind:  66
#
# row:  IncidentDate                3/3/2020 1:22:33 AM
# Location                       1303 WOODLAND ST
# Latitude1                               36.1772
# Longitude1                             -86.7468
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 66, dtype: object
#
# ind:  67
#
# row:  IncidentDate                                3/3/2020 1:24:30 AM
# Location                                           201 N 8TH ST
# Latitude1                                               36.1767
# Longitude1                                              -86.759
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT LARGE BUILDING
# Name: 67, dtype: object
#
# ind:  68
#
# row:  IncidentDate                   3/3/2020 1:25:27 AM
# Location                             302 S 15TH ST
# Latitude1                                  36.1732
# Longitude1                                -86.7448
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 68, dtype: object
#
# ind:  69
#
# row:  IncidentDate                                3/3/2020 1:25:30 AM
# Location                                      2140 BROOKVIEW DR
# Latitude1                                               36.1765
# Longitude1                                             -86.6949
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 69, dtype: object
#
# ind:  70
#
# row:  IncidentDate                         3/3/2020 1:26:21 AM
# Location                       731 MARGARET ROBERTSON DR
# Latitude1                                        36.1812
# Longitude1                                      -86.5998
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 70, dtype: object
#
# ind:  71
#
# row:  IncidentDate                                   3/3/2020 1:26:53 AM
# Location                    OLD HICKORY BLVD / ANDREW JACKSON PKWY
# Latitude1                                                  36.1835
# Longitude1                                                -86.6108
# IncidentTypeDescription1        WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 71, dtype: object
#
# ind:  72
#
# row:  IncidentDate                                3/3/2020 1:27:03 AM
# Location                                          1072 1ST AV N
# Latitude1                                               36.1753
# Longitude1                                             -86.7819
# IncidentTypeDescription1    CONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 72, dtype: object
#
# ind:  73
#
# row:  IncidentDate                                  3/3/2020 1:28:18 AM
# Location                                       7135 CENTENNIAL PL
# Latitude1                                                 36.1769
# Longitude1                                               -86.8799
# IncidentTypeDescription1    COMMERCIAL STRUCTURE NATURAL GAS LEAK
# Name: 73, dtype: object
#
# ind:  74
#
# row:  IncidentDate                          3/3/2020 1:28:24 AM
# Location                                    3509 ALBEE DR
# Latitude1                                         36.1816
# Longitude1                                       -86.6113
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 74, dtype: object
#
# ind:  75
#
# row:  IncidentDate                          3/3/2020 1:28:24 AM
# Location                                    3509 ALBEE DR
# Latitude1                                         36.1816
# Longitude1                                       -86.6113
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 75, dtype: object
#
# ind:  76
#
# row:  IncidentDate                         3/3/2020 1:30:32 AM
# Location                          209 JACKSON DOWNS BLVD
# Latitude1                                        36.1802
# Longitude1                                      -86.6401
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 76, dtype: object
#
# ind:  77
#
# row:  IncidentDate                         3/3/2020 1:30:32 AM
# Location                          209 JACKSON DOWNS BLVD
# Latitude1                                        36.1802
# Longitude1                                      -86.6401
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 77, dtype: object
#
# ind:  78
#
# row:  IncidentDate                3/3/2020 1:30:39 AM
# Location                       3113 STAFFORD DR
# Latitude1                               36.1829
# Longitude1                             -86.6458
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 78, dtype: object
#
# ind:  79
#
# row:  IncidentDate                                 3/3/2020 1:32:25 AM
# Location                                        2322 BRITTANY DR
# Latitude1                                                36.1761
# Longitude1                                              -86.7238
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 79, dtype: object
#
# ind:  80
#
# row:  IncidentDate                   3/3/2020 1:33:54 AM
# Location                          1204 WOODLAND ST
# Latitude1                                  36.1769
# Longitude1                                 -86.748
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 80, dtype: object
#
# ind:  81
#
# row:  IncidentDate                           3/3/2020 1:34:00 AM
# Location                            6121 COCKRILL BEND CIR
# Latitude1                                          36.1785
# Longitude1                                         -86.893
# IncidentTypeDescription1    BUILDING ENTRAPMENT  CONFIRMED
# Name: 81, dtype: object
#
# ind:  82
#
# row:  IncidentDate                   3/3/2020 1:34:09 AM
# Location                           1709 RUSSELL ST
# Latitude1                                  36.1743
# Longitude1                                -86.7388
# IncidentTypeDescription1    HOUSE NATURAL GAS ODOR
# Name: 82, dtype: object
#
# ind:  83
#
# row:  IncidentDate                         3/3/2020 1:34:46 AM
# Location                                1027 CHEATHAM PL
# Latitude1                                        36.1744
# Longitude1                                       -86.799
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 83, dtype: object
#
# ind:  84
#
# row:  IncidentDate                3/3/2020 1:35:16 AM
# Location                      1720 UNDERWOOD ST
# Latitude1                               36.1737
# Longitude1                             -86.8077
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 84, dtype: object
#
# ind:  85
#
# row:  IncidentDate                      3/3/2020 1:35:32 AM
# Location                    605 MARGARET ROBERTSON DR
# Latitude1                                     36.1788
# Longitude1                                   -86.5994
# IncidentTypeDescription1               UNKNOWN STATUS
# Name: 85, dtype: object
#
# ind:  86
#
# row:  IncidentDate                       3/3/2020 1:37:25 AM
# Location                              2722 FORTLAND DR
# Latitude1                                      36.1747
# Longitude1                                    -86.7227
# IncidentTypeDescription1    SICK PERSON UNKNOWN STATUS
# Name: 86, dtype: object
#
# ind:  87
#
# row:  IncidentDate                       3/3/2020 1:37:25 AM
# Location                              2722 FORTLAND DR
# Latitude1                                      36.1747
# Longitude1                                    -86.7227
# IncidentTypeDescription1    SICK PERSON UNKNOWN STATUS
# Name: 87, dtype: object
#
# ind:  88
#
# row:  IncidentDate                  3/3/2020 1:39:00 AM
# Location                    1107 FOREST RIDGE WAY
# Latitude1                                 36.1779
# Longitude1                               -86.5855
# IncidentTypeDescription1           UNKNOWN STATUS
# Name: 88, dtype: object
#
# ind:  89
#
# row:  IncidentDate                           3/3/2020 1:39:41 AM
# Location                                    515 MADISON ST
# Latitude1                                          36.1747
# Longitude1                                        -86.7892
# IncidentTypeDescription1    BUILDING ENTRAPMENT  CONFIRMED
# Name: 89, dtype: object
#
# ind:  90
#
# row:  IncidentDate                3/3/2020 1:39:55 AM
# Location                        1807 LILLIAN ST
# Latitude1                               36.1722
# Longitude1                              -86.738
# IncidentTypeDescription1    DIZZINESS / VERTIGO
# Name: 90, dtype: object
#
# ind:  91
#
# row:  IncidentDate                                              3/3/2020 1:41:16 AM
# Location                                                        1900 HOLLY ST
# Latitude1                                                             36.1747
# Longitude1                                                           -86.7365
# IncidentTypeDescription1    OUTSIDE NATURAL GAS LEAK RESIDENTIAL LINR   TA...
# Name: 91, dtype: object
#
# ind:  92
#
# row:  IncidentDate                3/3/2020 1:41:42 AM
# Location                       408 DENNYWOOD DR
# Latitude1                               36.1788
# Longitude1                             -86.6885
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 92, dtype: object
#
# ind:  93
#
# row:  IncidentDate                            3/3/2020 1:41:42 AM
# Location                                 2219 MAPLECREST DR
# Latitude1                                            36.178
# Longitude1                                         -86.6932
# IncidentTypeDescription1    OUTSIDE SMALL TANK LEAK    ODOR
# Name: 93, dtype: object
#
# ind:  94
#
# row:  IncidentDate                   3/3/2020 1:43:08 AM
# Location                          1603 COCKRILL ST
# Latitude1                                   36.175
# Longitude1                                -86.8055
# IncidentTypeDescription1    HOUSE NATURAL GAS ODOR
# Name: 94, dtype: object
#
# ind:  95
#
# row:  IncidentDate                            3/3/2020 1:44:03 AM
# Location                                      3609 QUAIL DR
# Latitude1                                            36.181
# Longitude1                                         -86.6102
# IncidentTypeDescription1    UNCONSCIOUS EFFECTIVE BREATHING
# Name: 95, dtype: object
#
# ind:  96
#
# row:  IncidentDate                              3/3/2020 1:44:29 AM
# Location                                        3204 DINAH CT
# Latitude1                                             36.1842
# Longitude1                                           -86.6426
# IncidentTypeDescription1    REQUEST ADDITIONAL FIRE RESOURCES
# Name: 96, dtype: object
#
# ind:  97
#
# row:  IncidentDate                                 3/3/2020 1:45:12 AM
# Location                                           1901 HOLLY ST
# Latitude1                                                36.1752
# Longitude1                                              -86.7365
# IncidentTypeDescription1    POSSIBLY DANGEROUS HEMORRHAGE TRAUMA
# Name: 97, dtype: object
#
# ind:  98
#
# row:  IncidentDate                                              3/3/2020 1:45:47 AM
# Location                                                       1102 10TH AV N
# Latitude1                                                             36.1727
# Longitude1                                                           -86.7949
# IncidentTypeDescription1    OUTSIDE NATURAL GAS LEAK RESIDENTIAL LINR   TA...
# Name: 98, dtype: object
#
# ind:  99
#
# row:  IncidentDate                               3/3/2020 1:45:48 AM
# Location                                  2265 WILLESDEN GREEN
# Latitude1                                              36.1844
# Longitude1                                            -86.5958
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 99, dtype: object
#
# ind:  100
#
# row:  IncidentDate                    3/3/2020 1:46:00 AM
# Location                        230 BURNING TREE DR
# Latitude1                                   36.1755
# Longitude1                                    -86.6
# IncidentTypeDescription1    GENERAL ALARM APARTMENT
# Name: 100, dtype: object
#
# ind:  101
#
# row:  IncidentDate                            3/3/2020 1:47:12 AM
# Location                              4107 DODSON CHAPEL CT
# Latitude1                                           36.1825
# Longitude1                                         -86.6124
# IncidentTypeDescription1    OUTSIDE SMALL TANK LEAK    ODOR
# Name: 101, dtype: object
#
# ind:  102
#
# row:  IncidentDate                                 3/3/2020 1:47:13 AM
# Location                                      1409 FATHERLAND ST
# Latitude1                                                36.1739
# Longitude1                                              -86.7454
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 102, dtype: object
#
# ind:  103
#
# row:  IncidentDate                                    3/3/2020 1:47:18 AM
# Location                                              406 11TH AV N
# Latitude1                                                   36.1628
# Longitude1                                                 -86.7907
# IncidentTypeDescription1    ELEVATOR MALFUNCTION   OCCUPANTS INSIDE
# Name: 103, dtype: object
#
# ind:  104
#
# row:  IncidentDate                                              3/3/2020 1:48:27 AM
# Location                                                     2219 DEARBORN DR
# Latitude1                                                             36.1733
# Longitude1                                                           -86.6972
# IncidentTypeDescription1    OUTSIDE NATURAL GAS LEAK RESIDENTIAL LINR   TA...
# Name: 104, dtype: object
#
# ind:  105
#
# row:  IncidentDate                         3/3/2020 1:48:46 AM
# Location                                  1603 21ST AV N
# Latitude1                                         36.175
# Longitude1                                      -86.8113
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 105, dtype: object
#
# ind:  106
#
# row:  IncidentDate                3/3/2020 1:48:50 AM
# Location                       3417 LEBANON PKE
# Latitude1                               36.1887
# Longitude1                             -86.6272
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 106, dtype: object
#
# ind:  107
#
# row:  IncidentDate                3/3/2020 1:49:49 AM
# Location                           621 NEILL AV
# Latitude1                               36.1822
# Longitude1                             -86.7597
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 107, dtype: object
#
# ind:  108
#
# row:  IncidentDate                               3/3/2020 1:50:06 AM
# Location                                    1707 FATHERLAND ST
# Latitude1                                              36.1733
# Longitude1                                            -86.7391
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 108, dtype: object
#
# ind:  109
#
# row:  IncidentDate                               3/3/2020 1:50:30 AM
# Location                                       1224 LILLIAN ST
# Latitude1                                              36.1731
# Longitude1                                            -86.7484
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 109, dtype: object
#
# ind:  110
#
# row:  IncidentDate                                 3/3/2020 1:50:32 AM
# Location                                           1901 HOLLY ST
# Latitude1                                                36.1752
# Longitude1                                              -86.7365
# IncidentTypeDescription1    STANDING: SITTING: MOVING OR TALKING
# Name: 110, dtype: object
#
# ind:  111
#
# row:  IncidentDate                         3/3/2020 1:52:04 AM
# Location                                  1630 25TH AV N
# Latitude1                                        36.1757
# Longitude1                                      -86.8159
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 111, dtype: object
#
# ind:  112
#
# row:  IncidentDate                                   3/3/2020 1:52:28 AM
# Location                                              4807 MYRA DR
# Latitude1                                                   36.179
# Longitude1                                                 -86.583
# IncidentTypeDescription1    SERIOUS HEMORRHAGE STILL ON THE GROUND
# Name: 112, dtype: object
#
# ind:  113
#
# row:  IncidentDate                                   3/3/2020 1:53:29 AM
# Location                    OLD HICKORY BLVD / ANDREW JACKSON PKWY
# Latitude1                                                  36.1835
# Longitude1                                                -86.6108
# IncidentTypeDescription1                             MVA INJURIES:
# Name: 113, dtype: object
#
# ind:  114
#
# row:  IncidentDate                3/3/2020 1:53:53 AM
# Location                     1620 FATHERLAND ST
# Latitude1                               36.1732
# Longitude1                             -86.7419
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 114, dtype: object
#
# ind:  115
#
# row:  IncidentDate                        3/3/2020 1:54:39 AM
# Location                    1044 RIVERWOOD VILLAGE BLVD
# Latitude1                                       36.1684
# Longitude1                                     -86.6179
# IncidentTypeDescription1    CARBON MONOXIDE ALARM HOUSE
# Name: 115, dtype: object
#
# ind:  116
#
# row:  IncidentDate                         3/3/2020 1:55:38 AM
# Location                                  1606 22ND AV N
# Latitude1                                        36.1752
# Longitude1                                      -86.8119
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 116, dtype: object
#
# ind:  117
#
# row:  IncidentDate                3/3/2020 1:55:42 AM
# Location                     403 ACHIEVEMENT DR
# Latitude1                                36.147
# Longitude1                             -86.8798
# IncidentTypeDescription1               VOMITING
# Name: 117, dtype: object
#
# ind:  118
#
# row:  IncidentDate                       3/3/2020 1:55:58 AM
# Location                       129 HERMITAGE POINT DR
# Latitude1                                      36.1722
# Longitude1                                    -86.6194
# IncidentTypeDescription1    MEDICAL ALARM NOTIFICATION
# Name: 118, dtype: object
#
# ind:  119
#
# row:  IncidentDate                                 3/3/2020 1:56:01 AM
# Location                                           309 S 10TH ST
# Latitude1                                                36.1735
# Longitude1                                              -86.7517
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 119, dtype: object
#
# ind:  120
#
# row:  IncidentDate                                 3/3/2020 1:56:01 AM
# Location                                           309 S 10TH ST
# Latitude1                                                36.1735
# Longitude1                                              -86.7517
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 120, dtype: object
#
# ind:  121
#
# row:  IncidentDate                               3/3/2020 1:56:07 AM
# Location                             571 MARGARET ROBERTSON DR
# Latitude1                                              36.1782
# Longitude1                                            -86.5989
# IncidentTypeDescription1    ENTRAPMENT UNCONFIRMED  PERIPHERAL
# Name: 121, dtype: object
#
# ind:  122
#
# row:  IncidentDate                3/3/2020 1:56:15 AM
# Location                         1628 25TH AV N
# Latitude1                               36.1755
# Longitude1                             -86.8159
# IncidentTypeDescription1    GENERAL ALARM HOUSE
# Name: 122, dtype: object
#
# ind:  123
#
# row:  IncidentDate                3/3/2020 1:56:15 AM
# Location                         1628 25TH AV N
# Latitude1                               36.1755
# Longitude1                             -86.8159
# IncidentTypeDescription1    GENERAL ALARM HOUSE
# Name: 123, dtype: object
#
# ind:  124
#
# row:  IncidentDate                          3/3/2020 1:56:21 AM
# Location                                      535 MAIN ST
# Latitude1                                         36.1744
# Longitude1                                       -86.7633
# IncidentTypeDescription1    HEART PROBLEMS UNKNOWN STATUS
# Name: 124, dtype: object
#
# ind:  125
#
# row:  IncidentDate                                  3/3/2020 1:56:58 AM
# Location                                            1212 HOLLY ST
# Latitude1                                                 36.1757
# Longitude1                                               -86.7476
# IncidentTypeDescription1    COMMERCIAL STRUCTURE NATURAL GAS LEAK
# Name: 125, dtype: object
#
# ind:  126
#
# row:  IncidentDate                              3/3/2020 1:57:05 AM
# Location                                   MAIN ST / N 6TH ST
# Latitude1                                             36.1738
# Longitude1                                           -86.7628
# IncidentTypeDescription1    SICK PERSON: NO PRIORITY SYMPTOMS
# Name: 126, dtype: object
#
# ind:  127
#
# row:  IncidentDate                                 3/3/2020 1:58:33 AM
# Location                               703 MARGARET ROBERTSON DR
# Latitude1                                                  36.18
# Longitude1                                              -86.6001
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT LARGE BUIDING
# Name: 127, dtype: object
#
# ind:  128
#
# row:  IncidentDate                                   3/3/2020 1:59:03 AM
# Location                                              333 UNION ST
# Latitude1                                                   36.165
# Longitude1                                                -86.7796
# IncidentTypeDescription1    STRUCTURE FIRE COMMERCIAL   INDUSTRIAL
# Name: 128, dtype: object
#
# ind:  129
#
# row:  IncidentDate                       3/3/2020 2:01:33 AM
# Location                              1421 WOODLAND ST
# Latitude1                                      36.1772
# Longitude1                                    -86.7439
# IncidentTypeDescription1    SMOKE DETECTOR ALARM HOUSE
# Name: 129, dtype: object
#
# ind:  130
#
# row:  IncidentDate                                        3/3/2020 2:01:52 AM
# Location                                                2658 BARCLAY DR
# Latitude1                                                       36.1742
# Longitude1                                                     -86.7198
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 130, dtype: object
#
# ind:  131
#
# row:  IncidentDate                                              3/3/2020 2:02:32 AM
# Location                                                   S 9TH ST / MAIN ST
# Latitude1                                                              36.176
# Longitude1                                                           -86.7572
# IncidentTypeDescription1    OUTSIDE NATURAL GAS ODOR COMMERCIAL LINE TANK ...
# Name: 131, dtype: object
#
# ind:  132
#
# row:  IncidentDate                3/3/2020 2:03:06 AM
# Location                         111 EVANDER ST
# Latitude1                                36.176
# Longitude1                             -86.7408
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 132, dtype: object
#
# ind:  133
#
# row:  IncidentDate                3/3/2020 2:04:00 AM
# Location                      938 W EASTLAND AV
# Latitude1                               36.1841
# Longitude1                             -86.7544
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 133, dtype: object
#
# ind:  134
#
# row:  IncidentDate                3/3/2020 2:04:00 AM
# Location                      938 W EASTLAND AV
# Latitude1                               36.1841
# Longitude1                             -86.7544
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 134, dtype: object
#
# ind:  135
#
# row:  IncidentDate                                       3/3/2020 2:04:05 AM
# Location                                       N NEW HOPE RD / MYRA DR
# Latitude1                                                       36.179
# Longitude1                                                    -86.5823
# IncidentTypeDescription1    TRAUMATIC INJURIES NOT DANGEROUS BODY AREA
# Name: 135, dtype: object
#
# ind:  136
#
# ...
# IncidentTypeDescription1    ESCALATOR ELEVATOR INVESTIGATION
# Name: 214, dtype: object
#
# ind:  215
#
# row:  IncidentDate                             3/3/2020 3:23:27 AM
# Location                                     700 GALLATIN AV
# Latitude1                                            36.1839
# Longitude1                                           -86.749
# IncidentTypeDescription1    CITIZEN ASSIST UNKNOWN SITUATION
# Name: 215, dtype: object
#
# ind:  216
#
# row:  IncidentDate                               3/3/2020 3:33:53 AM
# Location                                         2311 WEONA DR
# Latitude1                                              36.1776
# Longitude1                                            -86.6866
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING
# Name: 216, dtype: object
#
# ind:  217
#
# row:  IncidentDate                3/3/2020 3:35:24 AM
# Location                           171 N 6TH ST
# Latitude1                               36.1754
# Longitude1                             -86.7636
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 217, dtype: object
#
# ind:  218
#
# row:  IncidentDate                        3/3/2020 3:36:15 AM
# Location                                1711 KNOWLES ST
# Latitude1                                       36.1726
# Longitude1                                      -86.806
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 218, dtype: object
#
# ind:  219
#
# row:  IncidentDate                3/3/2020 3:40:25 AM
# Location                            535 MAIN ST
# Latitude1                               36.1744
# Longitude1                             -86.7633
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 219, dtype: object
#
# ind:  220
#
# row:  IncidentDate                3/3/2020 3:40:25 AM
# Location                            535 MAIN ST
# Latitude1                               36.1744
# Longitude1                             -86.7633
# IncidentTypeDescription1           OUTSIDE ODOR
# Name: 220, dtype: object
#
# ind:  221
#
# row:  IncidentDate                                             3/3/2020 3:45:22 AM
# Location                                                    4347 LEBANON PKE
# Latitude1                                                            36.2065
# Longitude1                                                           -86.611
# IncidentTypeDescription1    POSSIBLY DANGEROUS BODY AREA STILL ON THE GROUND
# Name: 221, dtype: object
#
# ind:  222
#
# row:  IncidentDate                                              3/3/2020 3:47:15 AM
# Location                                                         299 COWAN ST
# Latitude1                                                             36.1759
# Longitude1                                                           -86.7772
# IncidentTypeDescription1    OUTSIDE NATURAL GAS ODOR COMMERCIAL LINE TANK ...
# Name: 222, dtype: object
#
# ind:  223
#
# row:  IncidentDate                       3/3/2020 3:47:46 AM
# Location                                  185 2ND AV N
# Latitude1                                      36.1641
# Longitude1                                    -86.7769
# IncidentTypeDescription1    SICK PERSON UNKNOWN STATUS
# Name: 223, dtype: object
#
# ind:  224
#
# row:  IncidentDate                                    3/3/2020 3:49:16 AM
# Location                                               315 4TH AV N
# Latitude1                                                   36.1652
# Longitude1                                                 -86.7805
# IncidentTypeDescription1    ELEVATOR MALFUNCTION   OCCUPANTS INSIDE
# Name: 224, dtype: object
#
# ind:  225
#
# row:  IncidentDate                        3/3/2020 3:52:00 AM
# Location                            223 STONERS GLEN CT
# Latitude1                                       36.1956
# Longitude1                                     -86.6006
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 225, dtype: object
#
# ind:  226
#
# row:  IncidentDate                                  3/3/2020 3:53:18 AM
# Location                                      1161 TULIP GROVE RD
# Latitude1                                                 36.1777
# Longitude1                                               -86.5944
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 226, dtype: object
#
# ind:  227
#
# row:  IncidentDate                                 3/3/2020 3:54:33 AM
# Location                                   431 LARKIN SPRINGS RD
# Latitude1                                                36.2547
# Longitude1                                              -86.6853
# IncidentTypeDescription1    HIGH LIFE HAZARD   ODOR WITH PATIENT
# Name: 227, dtype: object
#
# ind:  228
#
# row:  IncidentDate                         3/3/2020 3:55:39 AM
# Location                                 1000 ST LUKE DR
# Latitude1                                        36.0896
# Longitude1                                      -86.8885
# IncidentTypeDescription1    POSSIBLY DANGEROUS BODY AREA
# Name: 228, dtype: object
#
# ind:  229
#
# row:  IncidentDate                                              3/3/2020 4:02:03 AM
# Location                                                        800 COWAN ST
# Latitude1                                                             36.1877
# Longitude1                                                           -86.7778
# IncidentTypeDescription1    WATERFLOW ALARM COMMERCIAL COMMERCIAL   INDUST...
# Name: 229, dtype: object
#
# ind:  230
#
# row:  IncidentDate                         3/3/2020 4:05:54 AM
# Location                               3027 FERNBROOK LN
# Latitude1                                        36.1843
# Longitude1                                      -86.6681
# IncidentTypeDescription1    POSSIBLY DANGEROUS BODY AREA
# Name: 230, dtype: object
#
# ind:  231
#
# row:  IncidentDate                        3/3/2020 4:06:14 AM
# Location                               200 E WEBSTER ST
# Latitude1                                       36.2511
# Longitude1                                     -86.7167
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 231, dtype: object
#
# ind:  232
#
# row:  IncidentDate                        3/3/2020 4:09:11 AM
# Location                                  1600 6TH AV N
# Latitude1                                       36.1802
# Longitude1                                     -86.7927
# IncidentTypeDescription1    CARBON MONOXIDE ALARM HOUSE
# Name: 232, dtype: object
#
# ind:  233
#
# row:  IncidentDate                  3/3/2020 4:10:40 AM
# Location                    900 ROSA L PARKS BLVD
# Latitude1                                 36.1702
# Longitude1                               -86.7886
# IncidentTypeDescription1               OTHER PAIN
# Name: 233, dtype: object
#
# ind:  234
#
# row:  IncidentDate                                3/3/2020 4:16:53 AM
# Location                                   368 BRITISH WOODS DR
# Latitude1                                                36.093
# Longitude1                                             -86.6543
# IncidentTypeDescription1    DIFFICULTY SPEAKING BETWEEN BREATHS
# Name: 234, dtype: object
#
# ind:  235
#
# row:  IncidentDate                                             3/3/2020 4:20:49 AM
# Location                                                     1845 WELCOME LN
# Latitude1                                                            36.2005
# Longitude1                                                          -86.7114
# IncidentTypeDescription1    POSSIBLY DANGEROUS BODY AREA STILL ON THE GROUND
# Name: 235, dtype: object
#
# ind:  236
#
# row:  IncidentDate                                              3/3/2020 4:21:34 AM
# Location                                                         115 LAURA AV
# Latitude1                                                             36.2346
# Longitude1                                                           -86.6304
# IncidentTypeDescription1    DIFFICULTY SPEAKING BETWEEN BREATHS OTHER LUNG...
# Name: 236, dtype: object
#
# ind:  237
#
# row:  IncidentDate                                       3/3/2020 4:23:50 AM
# Location                                  ELLINGTON PKWY S / SPRING ST
# Latitude1                                                       36.176
# Longitude1                                                    -86.7664
# IncidentTypeDescription1    ELECTRICAL INVESTIGATION UNKNOWN SITUATION
# Name: 237, dtype: object
#
# ind:  238
#
# row:  IncidentDate                       3/3/2020 4:26:08 AM
# Location                                 121 S 17TH ST
# Latitude1                                      36.1749
# Longitude1                                    -86.7393
# IncidentTypeDescription1    SMOKE DETECTOR ALARM HOUSE
# Name: 238, dtype: object
#
# ind:  239
#
# row:  IncidentDate                         3/3/2020 4:26:40 AM
# Location                               1824 UNDERWOOD ST
# Latitude1                                        36.1733
# Longitude1                                      -86.8102
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 239, dtype: object
#
# ind:  240
#
# row:  IncidentDate                                              3/3/2020 4:27:57 AM
# Location                                                      200 ATHENS WAY
# Latitude1                                                             36.1958
# Longitude1                                                           -86.7993
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 240, dtype: object
#
# ind:  241
#
# row:  IncidentDate                                 3/3/2020 4:30:49 AM
# Location                                           2322 SELMA AV
# Latitude1                                                36.1757
# Longitude1                                               -86.686
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 241, dtype: object
#
# ind:  242
#
# row:  IncidentDate                   3/3/2020 4:38:03 AM
# Location                             1202 7TH AV N
# Latitude1                                  36.1745
# Longitude1                                -86.7904
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 242, dtype: object
#
# ind:  243
#
# row:  IncidentDate                                 3/3/2020 4:38:24 AM
# Location                                NEWHALL DR / BRITTANY DR
# Latitude1                                                36.1762
# Longitude1                                               -86.723
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 243, dtype: object
#
# ind:  244
#
# row:  IncidentDate                  3/3/2020 4:39:10 AM
# Location                        856 BLOOMDALE TRC
# Latitude1                                 36.1802
# Longitude1                               -86.5992
# IncidentTypeDescription1    WATERFLOW ALARM HOUSE
# Name: 244, dtype: object
#
# ind:  245
#
# row:  IncidentDate                                 3/3/2020 4:40:25 AM
# Location                                          1736 24TH AV N
# Latitude1                                                36.1789
# Longitude1                                              -86.8154
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 245, dtype: object
#
# ind:  246
#
# row:  IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 246, dtype: object
#
# ind:  247
#
# row:  IncidentDate                          3/3/2020 4:43:33 AM
# Location                             S 18TH ST / HOLLY ST
# Latitude1                                         36.1751
# Longitude1                                       -86.7383
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 247, dtype: object
#
# ind:  248
#
# row:  IncidentDate                         3/3/2020 4:43:51 AM
# Location                    OLD HICKORY BLVD / LAWING DR
# Latitude1                                         36.275
# Longitude1                                      -86.7647
# IncidentTypeDescription1       HIGH MECHANISM: ROLLOVERS
# Name: 248, dtype: object
#
# ind:  249
#
# row:  IncidentDate                                        3/3/2020 4:44:36 AM
# Location                                                 713 RAMSEY ST
# Latitude1                                                       36.1763
# Longitude1                                                     -86.7606
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 249, dtype: object
#
# ind:  250
#
# row:  IncidentDate                    3/3/2020 4:44:59 AM
# Location                           4215 HARDING PKE
# Latitude1                                    36.129
# Longitude1                                 -86.8409
# IncidentTypeDescription1    NOT DANGEROUS BODY AREA
# Name: 250, dtype: object
#
# ind:  251
#
# row:  IncidentDate                                 3/3/2020 4:50:09 AM
# Location                                  LINCOYA DR / MERLYN LN
# Latitude1                                                36.1767
# Longitude1                                              -86.6756
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 251, dtype: object
#
# ind:  252
#
# row:  IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 252, dtype: object
#
# ind:  253
#
# row:  IncidentDate                         3/3/2020 4:50:56 AM
# Location                       609 MARGARET ROBERTSON DR
# Latitude1                                        36.1789
# Longitude1                                      -86.5995
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 253, dtype: object
#
# ind:  254
#
# row:  IncidentDate                                 3/3/2020 4:51:36 AM
# Location                                           821 RAMSEY ST
# Latitude1                                                36.1771
# Longitude1                                              -86.7579
# IncidentTypeDescription1    ELECTRICAL HAZARD WITH OR NEAR WATER
# Name: 254, dtype: object
#
# ind:  255
#
# row:  IncidentDate                                              3/3/2020 4:53:43 AM
# Location                                                       1616 23RD AV N
# Latitude1                                                             36.1757
# Longitude1                                                           -86.8132
# IncidentTypeDescription1    WIRES DOWN WITH NO SMOKE OR ARCING POWER DISCO...
# Name: 255, dtype: object
#
# ind:  256
#
# row:  IncidentDate                         3/3/2020 4:56:56 AM
# Location                           5610 OLD HICKORY BLVD
# Latitude1                                        36.1805
# Longitude1                                      -86.6015
# IncidentTypeDescription1    LARGE BUILDING INVESTIGATION
# Name: 256, dtype: object
#
# ind:  257
#
# row:  IncidentDate                            3/3/2020 4:57:06 AM
# Location                                2903 MORNINGSIDE DR
# Latitude1                                           36.2236
# Longitude1                                         -86.7579
# IncidentTypeDescription1    CHEST PAIN - ABNORMAL BREATHING
# Name: 257, dtype: object
#
# ind:  258
# row:  IncidentDate                                   3/3/2020 4:57:14 AM
# Location                                            1730 KELLOW ST
# Latitude1                                                  36.1894
# Longitude1                                                -86.8135
# IncidentTypeDescription1    ABNORMAL BREATHING OTHER LUNG PROBLEMS
# Name: 258, dtype: object
#
# ind:  259
#
# row:  IncidentDate                        3/3/2020 4:57:48 AM
# Location                    I24 W / HICKORY HOLLOW PKWY
# Latitude1                                       36.0397
# Longitude1                                     -86.6491
# IncidentTypeDescription1                UNKNOWN STATUS:
# Name: 259, dtype: object

# %%
for row in derecho_calls.iterrows():
    print('row: ', row, '\n')
    print('first item: ', row[0], '\n')
    print('second item: ', row[1], '\n')
# Out:
# row:  (0, Seizure DateTime       5/3/2020 16:30
# CallTypeId                  911 Calls
# ALI Latitude                  36.2478
# ALI Longitude                -86.7168
# Cell Tower Address    WIRELESS CALLER
# Name: 0, dtype: object)
#
# first item:  0
#
# second item:  Seizure DateTime       5/3/2020 16:30
# CallTypeId                  911 Calls
# ALI Latitude                  36.2478
# ALI Longitude                -86.7168
# Cell Tower Address    WIRELESS CALLER
# Name: 0, dtype: object
#
# row:  (1, Seizure DateTime           5/3/2020 16:30
# CallTypeId                      911 Calls
# ALI Latitude                      36.1431
# ALI Longitude                    -86.8006
# Cell Tower Address    1161 21ST AV S - SE
# Name: 1, dtype: object)
#
# first item:  1
#
# second item:  Seizure DateTime           5/3/2020 16:30
# CallTypeId                      911 Calls
# ALI Latitude                      36.1431
# ALI Longitude                    -86.8006
# Cell Tower Address    1161 21ST AV S - SE
# Name: 1, dtype: object
#
# row:  (2, Seizure DateTime             5/3/2020 16:30
# CallTypeId                        911 Calls
# ALI Latitude                        36.1005
# ALI Longitude                      -87.0563
# Cell Tower Address    8013 C MCCRORY LN - N
# Name: 2, dtype: object)
#
# first item:  2
#
# second item:  Seizure DateTime             5/3/2020 16:30
# CallTypeId                        911 Calls
# ALI Latitude                        36.1005
# ALI Longitude                      -87.0563
# Cell Tower Address    8013 C MCCRORY LN - N
# Name: 2, dtype: object
#
# row:  (3, Seizure DateTime          5/3/2020 16:30
# CallTypeId                     911 Calls
# ALI Latitude                       36.13
# ALI Longitude                   -86.9278
# Cell Tower Address    5758 RIVER RD - SW
# Name: 3, dtype: object)
#
# first item:  3
#
# second item:  Seizure DateTime          5/3/2020 16:30
# CallTypeId                     911 Calls
# ALI Latitude                       36.13
# ALI Longitude                   -86.9278
# Cell Tower Address    5758 RIVER RD - SW
# Name: 3, dtype: object
#
# row:  (4, Seizure DateTime            5/3/2020 16:31
# CallTypeId                       911 Calls
# ALI Latitude                       36.1424
# ALI Longitude                     -86.8819
# Cell Tower Address    3744B ANNEX AVE - SE
# Name: 4, dtype: object)
#
# first item:  4
#
# second item:  Seizure DateTime            5/3/2020 16:31
# CallTypeId                       911 Calls
# ALI Latitude                       36.1424
# ALI Longitude                     -86.8819
# Cell Tower Address    3744B ANNEX AVE - SE
# Name: 4, dtype: object
#
# row:  (5, Seizure DateTime            5/3/2020 16:31
# CallTypeId                       911 Calls
# ALI Latitude                       36.1367
# ALI Longitude                     -86.8613
# Cell Tower Address    3744B ANNEX AVE - SE
# Name: 5, dtype: object)
#
# first item:  5
#
# second item:  Seizure DateTime            5/3/2020 16:31
# CallTypeId                       911 Calls
# ALI Latitude                       36.1367
# ALI Longitude                     -86.8613
# Cell Tower Address    3744B ANNEX AVE - SE
# Name: 5, dtype: object
#
# row:  (6, Seizure DateTime       5/3/2020 16:31
# CallTypeId                  911 Calls
# ALI Latitude                  36.0472
# ALI Longitude                -86.9625
# Cell Tower Address    WIRELESS CALLER
# Name: 6, dtype: object)
#
# first item:  6
#
# second item:  Seizure DateTime       5/3/2020 16:31
# CallTypeId                  911 Calls
# ALI Latitude                  36.0472
# ALI Longitude                -86.9625
# Cell Tower Address    WIRELESS CALLER
# Name: 6, dtype: object
#
# row:  (7, Seizure DateTime       5/3/2020 16:32
# CallTypeId                  911 Calls
# ALI Latitude                  36.0415
# ALI Longitude                -86.6659
# Cell Tower Address    WIRELESS CALLER
# Name: 7, dtype: object)
#
# first item:  7
#
# second item:  Seizure DateTime       5/3/2020 16:32
# CallTypeId                  911 Calls
# ALI Latitude                  36.0415
# ALI Longitude                -86.6659
# Cell Tower Address    WIRELESS CALLER
# Name: 7, dtype: object
#
# row:  (8, Seizure DateTime                 5/3/2020 16:32
# CallTypeId                            911 Calls
# ALI Latitude                            36.0938
# ALI Longitude                          -86.8393
# Cell Tower Address    5043 G HILLSBORO PIKE - W
# Name: 8, dtype: object)
#
# first item:  8
#
# second item:  Seizure DateTime                 5/3/2020 16:32
# CallTypeId                            911 Calls
# ALI Latitude                            36.0938
# ALI Longitude                          -86.8393
# Cell Tower Address    5043 G HILLSBORO PIKE - W
# Name: 8, dtype: object
#
# row:  (9, Seizure DateTime              5/3/2020 16:32
# CallTypeId                         911 Calls
# ALI Latitude                         36.0307
# ALI Longitude                       -86.9816
# Cell Tower Address    8621C HASELTON RD - NE
# Name: 9, dtype: object)
#
# first item:  9
#
# second item:  Seizure DateTime              5/3/2020 16:32
# CallTypeId                         911 Calls
# ALI Latitude                         36.0307
# ALI Longitude                       -86.9816
# Cell Tower Address    8621C HASELTON RD - NE
# Name: 9, dtype: object
#
# row:  (10, Seizure DateTime            5/3/2020 16:32
# CallTypeId                       911 Calls
# ALI Latitude                       36.1116
# ALI Longitude                     -86.8881
# Cell Tower Address    796 DAVIDSON DR - SE
# Name: 10, dtype: object)
#
# first item:  10
#
# second item:  Seizure DateTime            5/3/2020 16:32
# CallTypeId                       911 Calls
# ALI Latitude                       36.1116
# ALI Longitude                     -86.8881
# Cell Tower Address    796 DAVIDSON DR - SE
# Name: 10, dtype: object
#
# row:  (11, Seizure DateTime       5/3/2020 16:32
# CallTypeId                  911 Calls
# ALI Latitude                  36.1739
# ALI Longitude                -86.7599
# Cell Tower Address    WIRELESS CALLER
# Name: 11, dtype: object)
#
# first item:  11
#
# second item:  Seizure DateTime       5/3/2020 16:32
# CallTypeId                  911 Calls
# ALI Latitude                  36.1739
# ALI Longitude                -86.7599
# Cell Tower Address    WIRELESS CALLER
# Name: 11, dtype: object
#
# row:  (12, Seizure DateTime             5/3/2020 16:33
# CallTypeId                        911 Calls
# ALI Latitude                        36.1133
# ALI Longitude                      -86.8425
# Cell Tower Address    2205 CRESTMOOR RD - W
# Name: 12, dtype: object)
#
# first item:  12
#
# second item:  Seizure DateTime             5/3/2020 16:33
# CallTypeId                        911 Calls
# ALI Latitude                        36.1133
# ALI Longitude                      -86.8425
# Cell Tower Address    2205 CRESTMOOR RD - W
# Name: 12, dtype: object
#
# row:  (13, Seizure DateTime                5/3/2020 16:33
# CallTypeId                           911 Calls
# ALI Latitude                           36.0971
# ALI Longitude                         -86.8388
# Cell Tower Address    5043 G HILLSBORO PKE - W
# Name: 13, dtype: object)
#
# first item:  13
#
# second item:  Seizure DateTime                5/3/2020 16:33
# CallTypeId                           911 Calls
# ALI Latitude                           36.0971
# ALI Longitude                         -86.8388
# Cell Tower Address    5043 G HILLSBORO PKE - W
# Name: 13, dtype: object
#
# row:  (14, Seizure DateTime           5/3/2020 16:33
# CallTypeId                      911 Calls
# ALI Latitude                      36.1222
# ALI Longitude                    -86.8121
# Cell Tower Address    2407 21ST AV S - SW
# Name: 14, dtype: object)
#
# first item:  14
#
# second item:  Seizure DateTime           5/3/2020 16:33
# CallTypeId                      911 Calls
# ALI Latitude                      36.1222
# ALI Longitude                    -86.8121
# Cell Tower Address    2407 21ST AV S - SW
# Name: 14, dtype: object
#
# row:  (15, Seizure DateTime       5/3/2020 16:33
# CallTypeId                  911 Calls
# ALI Latitude                  36.1503
# ALI Longitude                -86.8519
# Cell Tower Address    WIRELESS CALLER
# Name: 15, dtype: object)
#
# first item:  15
#
# second item:  Seizure DateTime       5/3/2020 16:33
# CallTypeId                  911 Calls
# ALI Latitude                  36.1503
# ALI Longitude                -86.8519
# Cell Tower Address    WIRELESS CALLER
# Name: 15, dtype: object
#
# row:  (16, Seizure DateTime                     5/3/2020 16:34
# CallTypeId                                911 Calls
# ALI Latitude                                 36.153
# ALI Longitude                              -86.6278
# Cell Tower Address    3324 ELM HILL PKE - SECTOR NE
# Name: 16, dtype: object)
#
# first item:  16
#
# second item:  Seizure DateTime                     5/3/2020 16:34
# CallTypeId                                911 Calls
# ALI Latitude                                 36.153
# ALI Longitude                              -86.6278
# Cell Tower Address    3324 ELM HILL PKE - SECTOR NE
# Name: 16, dtype: object
#
# row:  (17, Seizure DateTime       5/3/2020 16:34
# CallTypeId                  911 Calls
# ALI Latitude                  36.1111
# ALI Longitude                -86.8663
# Cell Tower Address    WIRELESS CALLER
# Name: 17, dtype: object)
#
# first item:  17
#
# second item:  Seizure DateTime       5/3/2020 16:34
# CallTypeId                  911 Calls
# ALI Latitude                  36.1111
# ALI Longitude                -86.8663
# Cell Tower Address    WIRELESS CALLER
# Name: 17, dtype: object
#
# row:  (18, Seizure DateTime                  5/3/2020 16:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.1445
# ALI Longitude                            -86.867
# Cell Tower Address    6019 C HILL CIR - N Sector
# Name: 18, dtype: object)
#
# first item:  18
#
# second item:  Seizure DateTime                  5/3/2020 16:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.1445
# ALI Longitude                            -86.867
# Cell Tower Address    6019 C HILL CIR - N Sector
# Name: 18, dtype: object
#
# row:  (19, Seizure DateTime                  5/3/2020 16:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.0384
# ALI Longitude                           -86.8212
# Cell Tower Address    1406 OLD HICKORY BLVD - SE
# Name: 19, dtype: object)
#
# first item:  19
#
# second item:  Seizure DateTime                  5/3/2020 16:34
# CallTypeId                             911 Calls
# ALI Latitude                             36.0384
# ALI Longitude                           -86.8212
# Cell Tower Address    1406 OLD HICKORY BLVD - SE
# Name: 19, dtype: object
#
# row:  (20, Seizure DateTime       5/3/2020 16:34
# CallTypeId                  911 Calls
# ALI Latitude                  36.1374
# ALI Longitude                 -86.825
# Cell Tower Address    WIRELESS CALLER
# Name: 20, dtype: object)
#
# first item:  20
#
# second item:  Seizure DateTime       5/3/2020 16:34
# CallTypeId                  911 Calls
# ALI Latitude                  36.1374
# ALI Longitude                 -86.825
# Cell Tower Address    WIRELESS CALLER
# Name: 20, dtype: object
#
# row:  (21, Seizure DateTime                   5/3/2020 16:35
# CallTypeId                              911 Calls
# ALI Latitude                              36.1006
# ALI Longitude                            -86.8046
# Cell Tower Address    3901 GRANNY WHITE PIKE - SW
# Name: 21, dtype: object)
#
# first item:  21
#
# second item:  Seizure DateTime                   5/3/2020 16:35
# CallTypeId                              911 Calls
# ALI Latitude                              36.1006
# ALI Longitude                            -86.8046
# Cell Tower Address    3901 GRANNY WHITE PIKE - SW
# Name: 21, dtype: object
#
# row:  (22, Seizure DateTime                      5/3/2020 16:35
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2462
# ALI Longitude                               -86.8385
# Cell Tower Address    3925 B DRY FORK RD - SE Sector
# Name: 22, dtype: object)
#
# first item:  22
#
# second item:  Seizure DateTime                      5/3/2020 16:35
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.2462
# ALI Longitude                               -86.8385
# Cell Tower Address    3925 B DRY FORK RD - SE Sector
# Name: 22, dtype: object
#
# row:  (23, Seizure DateTime                    5/3/2020 16:35
# CallTypeId                               911 Calls
# ALI Latitude                               36.0955
# ALI Longitude                             -86.8274
# Cell Tower Address    5043 HILLSBORO RD - W Sector
# Name: 23, dtype: object)
#
# first item:  23
#
# second item:  Seizure DateTime                    5/3/2020 16:35
# CallTypeId                               911 Calls
# ALI Latitude                               36.0955
# ALI Longitude                             -86.8274
# Cell Tower Address    5043 HILLSBORO RD - W Sector
# Name: 23, dtype: object
#
# row:  (24, Seizure DateTime           5/3/2020 16:35
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 24, dtype: object)
#
# first item:  24
#
# second item:  Seizure DateTime           5/3/2020 16:35
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 24, dtype: object
#
# row:  (25, Seizure DateTime                5/3/2020 16:35
# CallTypeId                           911 Calls
# ALI Latitude                           36.0955
# ALI Longitude                         -86.8274
# Cell Tower Address    5043 G HILLSBORO PKE - W
# Name: 25, dtype: object)
#
# first item:  25
#
# second item:  Seizure DateTime                5/3/2020 16:35
# CallTypeId                           911 Calls
# ALI Latitude                           36.0955
# ALI Longitude                         -86.8274
# Cell Tower Address    5043 G HILLSBORO PKE - W
# Name: 25, dtype: object
#
# row:  (26, Seizure DateTime                 5/3/2020 16:35
# CallTypeId                            911 Calls
# ALI Latitude                            36.0251
# ALI Longitude                          -86.9616
# Cell Tower Address    8609 LEWIS RD - SE SECTOR
# Name: 26, dtype: object)
#
# first item:  26
#
# second item:  Seizure DateTime                 5/3/2020 16:35
# CallTypeId                            911 Calls
# ALI Latitude                            36.0251
# ALI Longitude                          -86.9616
# Cell Tower Address    8609 LEWIS RD - SE SECTOR
# Name: 26, dtype: object
#
# row:  (27, Seizure DateTime              5/3/2020 16:35
# CallTypeId                         911 Calls
# ALI Latitude                         36.1309
# ALI Longitude                       -86.8597
# Cell Tower Address    4400 HARDING PIKE - NW
# Name: 27, dtype: object)
#
# first item:  27
#
# second item:  Seizure DateTime              5/3/2020 16:35
# CallTypeId                         911 Calls
# ALI Latitude                         36.1309
# ALI Longitude                       -86.8597
# Cell Tower Address    4400 HARDING PIKE - NW
# Name: 27, dtype: object
#
# row:  (28, Seizure DateTime                 5/3/2020 16:36
# CallTypeId                            911 Calls
# ALI Latitude                            36.0742
# ALI Longitude                          -86.7253
# Cell Tower Address    4305 NOLENSVILLE PIKE - N
# Name: 28, dtype: object)
#
# first item:  28
#
# second item:  Seizure DateTime                 5/3/2020 16:36
# CallTypeId                            911 Calls
# ALI Latitude                            36.0742
# ALI Longitude                          -86.7253
# Cell Tower Address    4305 NOLENSVILLE PIKE - N
# Name: 28, dtype: object
#
# row:  (29, Seizure DateTime         5/3/2020 16:36
# CallTypeId                    911 Calls
# ALI Latitude                    36.0123
# ALI Longitude                  -87.0244
# Cell Tower Address    9683B HWY 96 - SE
# Name: 29, dtype: object)
#
# first item:  29
#
# second item:  Seizure DateTime         5/3/2020 16:36
# CallTypeId                    911 Calls
# ALI Latitude                    36.0123
# ALI Longitude                  -87.0244
# Cell Tower Address    9683B HWY 96 - SE
# Name: 29, dtype: object
#
# row:  (30, Seizure DateTime                  5/3/2020 16:36
# CallTypeId                             911 Calls
# ALI Latitude                              36.127
# ALI Longitude                           -86.8092
# Cell Tower Address    2505 21ST AV - SECTOR SW S
# Name: 30, dtype: object)
#
# first item:  30
#
# second item:  Seizure DateTime                  5/3/2020 16:36
# CallTypeId                             911 Calls
# ALI Latitude                              36.127
# ALI Longitude                           -86.8092
# Cell Tower Address    2505 21ST AV - SECTOR SW S
# Name: 30, dtype: object
#
# row:  (31, Seizure DateTime          5/3/2020 16:36
# CallTypeId                     911 Calls
# ALI Latitude                      36.121
# ALI Longitude                    -86.743
# Cell Tower Address    2843F LOGAN ST - N
# Name: 31, dtype: object)
#
# first item:  31
#
# second item:  Seizure DateTime          5/3/2020 16:36
# CallTypeId                     911 Calls
# ALI Latitude                      36.121
# ALI Longitude                    -86.743
# Cell Tower Address    2843F LOGAN ST - N
# Name: 31, dtype: object
#
# row:  (32, Seizure DateTime                   5/3/2020 16:36
# CallTypeId                              911 Calls
# ALI Latitude                              36.0687
# ALI Longitude                            -86.9457
# Cell Tower Address    619 MCPHERSON DR - N SECTOR
# Name: 32, dtype: object)
#
# first item:  32
#
# second item:  Seizure DateTime                   5/3/2020 16:36
# CallTypeId                              911 Calls
# ALI Latitude                              36.0687
# ALI Longitude                            -86.9457
# Cell Tower Address    619 MCPHERSON DR - N SECTOR
# Name: 32, dtype: object
#
# row:  (33, Seizure DateTime        5/3/2020 16:36
# CallTypeId                   911 Calls
# ALI Latitude                   36.0825
# ALI Longitude                 -86.9429
# Cell Tower Address    8071 REGENCY DR.
# Name: 33, dtype: object)
#
# first item:  33
#
# second item:  Seizure DateTime        5/3/2020 16:36
# CallTypeId                   911 Calls
# ALI Latitude                   36.0825
# ALI Longitude                 -86.9429
# Cell Tower Address    8071 REGENCY DR.
# Name: 33, dtype: object
#
# row:  (34, Seizure DateTime           5/3/2020 16:36
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 34, dtype: object)
#
# first item:  34
#
# second item:  Seizure DateTime           5/3/2020 16:36
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 34, dtype: object
#
# row:  (35, Seizure DateTime                 5/3/2020 16:36
# CallTypeId                            911 Calls
# ALI Latitude                            36.0465
# ALI Longitude                          -86.8296
# Cell Tower Address    1406 OLD HICKORY BLVD - N
# Name: 35, dtype: object)
#
# first item:  35
#
# second item:  Seizure DateTime                 5/3/2020 16:36
# CallTypeId                            911 Calls
# ALI Latitude                            36.0465
# ALI Longitude                          -86.8296
# Cell Tower Address    1406 OLD HICKORY BLVD - N
# Name: 35, dtype: object
#
# row:  (36, Seizure DateTime           5/3/2020 16:36
# CallTypeId                      911 Calls
# ALI Latitude                       36.109
# ALI Longitude                    -86.8888
# Cell Tower Address    517 BROOK HOLLOW RD
# Name: 36, dtype: object)
#
# first item:  36
#
# second item:  Seizure DateTime           5/3/2020 16:36
# CallTypeId                      911 Calls
# ALI Latitude                       36.109
# ALI Longitude                    -86.8888
# Cell Tower Address    517 BROOK HOLLOW RD
# Name: 36, dtype: object
#
# row:  (37, Seizure DateTime                        5/3/2020 16:36
# CallTypeId                                   911 Calls
# ALI Latitude                                   35.9211
# ALI Longitude                                 -87.2292
# Cell Tower Address    7355 DEER RIDGE RD MAMIE DR - SW
# Name: 37, dtype: object)
#
# first item:  37
#
# second item:  Seizure DateTime                        5/3/2020 16:36
# CallTypeId                                   911 Calls
# ALI Latitude                                   35.9211
# ALI Longitude                                 -87.2292
# Cell Tower Address    7355 DEER RIDGE RD MAMIE DR - SW
# Name: 37, dtype: object
#
# row:  (38, Seizure DateTime                    5/3/2020 16:36
# CallTypeId                               911 Calls
# ALI Latitude                                 36.22
# ALI Longitude                             -86.8054
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 38, dtype: object)
#
# first item:  38
#
# second item:  Seizure DateTime                    5/3/2020 16:36
# CallTypeId                               911 Calls
# ALI Latitude                                 36.22
# ALI Longitude                             -86.8054
# Cell Tower Address    3925 DRY FORK RD - SE SECTOR
# Name: 38, dtype: object
#
# row:  (39, Seizure DateTime              5/3/2020 16:36
# CallTypeId                         911 Calls
# ALI Latitude                         36.0307
# ALI Longitude                       -86.9816
# Cell Tower Address    8621C HASELTON RD - NE
# Name: 39, dtype: object)
#
# first item:  39
#
# second item:  Seizure DateTime              5/3/2020 16:36
# CallTypeId                         911 Calls
# ALI Latitude                         36.0307
# ALI Longitude                       -86.9816
# Cell Tower Address    8621C HASELTON RD - NE
# Name: 39, dtype: object
#
# row:  (40, Seizure DateTime              5/3/2020 16:37
# CallTypeId                         911 Calls
# ALI Latitude                         36.1382
# ALI Longitude                       -86.7983
# Cell Tower Address    2008B BELCOURT AVE - E
# Name: 40, dtype: object)
#
# first item:  40
#
# second item:  Seizure DateTime              5/3/2020 16:37
# CallTypeId                         911 Calls
# ALI Latitude                         36.1382
# ALI Longitude                       -86.7983
# Cell Tower Address    2008B BELCOURT AVE - E
# Name: 40, dtype: object
#
# row:  (41, Seizure DateTime                 5/3/2020 16:37
# CallTypeId                            911 Calls
# ALI Latitude                            36.1489
# ALI Longitude                          -86.8072
# Cell Tower Address    212 25TH AVE N - E SECTOR
# Name: 41, dtype: object)
#
# first item:  41
#
# second item:  Seizure DateTime                 5/3/2020 16:37
# CallTypeId                            911 Calls
# ALI Latitude                            36.1489
# ALI Longitude                          -86.8072
# Cell Tower Address    212 25TH AVE N - E SECTOR
# Name: 41, dtype: object
#
# row:  (42, Seizure DateTime                       5/3/2020 16:37
# CallTypeId                                  911 Calls
# ALI Latitude                                   36.102
# ALI Longitude                                -86.8264
# Cell Tower Address    2120 CRESTMOOR ROAD - SW SECTOR
# Name: 42, dtype: object)
#
# first item:  42
#
# second item:  Seizure DateTime                       5/3/2020 16:37
# CallTypeId                                  911 Calls
# ALI Latitude                                   36.102
# ALI Longitude                                -86.8264
# Cell Tower Address    2120 CRESTMOOR ROAD - SW SECTOR
# Name: 42, dtype: object
#
# row:  (43, Seizure DateTime          5/3/2020 16:37
# CallTypeId                     911 Calls
# ALI Latitude                     36.0489
# ALI Longitude                   -86.7228
# Cell Tower Address    5646 AMALIE DR - N
# Name: 43, dtype: object)
#
# first item:  43
#
# second item:  Seizure DateTime          5/3/2020 16:37
# CallTypeId                     911 Calls
# ALI Latitude                     36.0489
# ALI Longitude                   -86.7228
# Cell Tower Address    5646 AMALIE DR - N
# Name: 43, dtype: object
#
# row:  (44, Seizure DateTime                5/3/2020 16:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.0388
# ALI Longitude                         -86.7419
# Cell Tower Address    5712A EDMONDSON PIKE - W
# Name: 44, dtype: object)
#
# first item:  44
#
# second item:  Seizure DateTime                5/3/2020 16:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.0388
# ALI Longitude                         -86.7419
# Cell Tower Address    5712A EDMONDSON PIKE - W
# Name: 44, dtype: object
#
# row:  (45, Seizure DateTime       5/3/2020 16:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1119
# ALI Longitude                -86.8381
# Cell Tower Address    WIRELESS CALLER
# Name: 45, dtype: object)
#
# first item:  45
#
# second item:  Seizure DateTime       5/3/2020 16:37
# CallTypeId                  911 Calls
# ALI Latitude                  36.1119
# ALI Longitude                -86.8381
# Cell Tower Address    WIRELESS CALLER
# Name: 45, dtype: object
#
# row:  (46, Seizure DateTime                5/3/2020 16:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.1586
# ALI Longitude                         -86.7842
# Cell Tower Address    920 Broadway - SW Sector
# Name: 46, dtype: object)
#
# first item:  46
#
# second item:  Seizure DateTime                5/3/2020 16:37
# CallTypeId                           911 Calls
# ALI Latitude                           36.1586
# ALI Longitude                         -86.7842
# Cell Tower Address    920 Broadway - SW Sector
# Name: 46, dtype: object
#
# row:  (47, Seizure DateTime                     5/3/2020 16:37
# CallTypeId                                911 Calls
# ALI Latitude                                 36.069
# ALI Longitude                              -86.8146
# Cell Tower Address    1480 GEORGETOWN CT - SECTOR S
# Name: 47, dtype: object)
#
# first item:  47
#
# second item:  Seizure DateTime                     5/3/2020 16:37
# CallTypeId                                911 Calls
# ALI Latitude                                 36.069
# ALI Longitude                              -86.8146
# Cell Tower Address    1480 GEORGETOWN CT - SECTOR S
# Name: 47, dtype: object
#
# row:  (48, Seizure DateTime                  5/3/2020 16:37
# CallTypeId                             911 Calls
# ALI Latitude                             36.1044
# ALI Longitude                           -86.8675
# Cell Tower Address    105 B LEAKE AVE - W Sector
# Name: 48, dtype: object)
#
# first item:  48
#
# second item:  Seizure DateTime                  5/3/2020 16:37
# CallTypeId                             911 Calls
# ALI Latitude                             36.1044
# ALI Longitude                           -86.8675
# Cell Tower Address    105 B LEAKE AVE - W Sector
# Name: 48, dtype: object
#
# row:  (49, Seizure DateTime      5/3/2020 16:39
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 49, dtype: object)
#
# first item:  49
#
# second item:  Seizure DateTime      5/3/2020 16:39
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 49, dtype: object
#
# row:  (50, Seizure DateTime             5/3/2020 16:40
# CallTypeId                        911 Calls
# ALI Latitude                        36.1142
# ALI Longitude                      -86.7828
# Cell Tower Address    100 OCEANSIDE DR - SW
# Name: 50, dtype: object)
#
# first item:  50
#
# second item:  Seizure DateTime             5/3/2020 16:40
# CallTypeId                        911 Calls
# ALI Latitude                        36.1142
# ALI Longitude                      -86.7828
# Cell Tower Address    100 OCEANSIDE DR - SW
# Name: 50, dtype: object
#
# row:  (51, Seizure DateTime                  5/3/2020 16:40
# CallTypeId                             911 Calls
# ALI Latitude                             36.0719
# ALI Longitude                           -86.6323
# Cell Tower Address    2747 MURFREESBORO PIKE - N
# Name: 51, dtype: object)
#
# first item:  51
#
# second item:  Seizure DateTime                  5/3/2020 16:40
# CallTypeId                             911 Calls
# ALI Latitude                             36.0719
# ALI Longitude                           -86.6323
# Cell Tower Address    2747 MURFREESBORO PIKE - N
# Name: 51, dtype: object
#
# row:  (52, Seizure DateTime                         5/3/2020 16:41
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.0464
# ALI Longitude                                  -86.8294
# Cell Tower Address    1406 OLD HICKORY BLVD - NE SECTOR
# Name: 52, dtype: object)
#
# first item:  52
#
# second item:  Seizure DateTime                         5/3/2020 16:41
# CallTypeId                                    911 Calls
# ALI Latitude                                    36.0464
# ALI Longitude                                  -86.8294
# Cell Tower Address    1406 OLD HICKORY BLVD - NE SECTOR
# Name: 52, dtype: object
#
# row:  (53, Seizure DateTime      5/3/2020 16:41
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 53, dtype: object)
#
# first item:  53
#
# second item:  Seizure DateTime      5/3/2020 16:41
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 53, dtype: object
#
# row:  (54, Seizure DateTime           5/3/2020 16:41
# CallTypeId                      911 Calls
# ALI Latitude                      36.1793
# ALI Longitude                    -87.0388
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 54, dtype: object)
#
# first item:  54
#
# second item:  Seizure DateTime           5/3/2020 16:41
# CallTypeId                      911 Calls
# ALI Latitude                      36.1793
# ALI Longitude                    -87.0388
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 54, dtype: object
#
# row:  (55, Seizure DateTime           5/3/2020 16:41
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 55, dtype: object)
#
# first item:  55
#
# second item:  Seizure DateTime           5/3/2020 16:41
# CallTypeId                      911 Calls
# ALI Latitude                       36.127
# ALI Longitude                    -86.8049
# Cell Tower Address    2407 21ST AV S - SW
# Name: 55, dtype: object
#
# row:  (56, Seizure DateTime      5/3/2020 16:41
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 56, dtype: object)
#
# first item:  56
#
# second item:  Seizure DateTime      5/3/2020 16:41
# CallTypeId                 911 Calls
# ALI Latitude                     NaN
# ALI Longitude                    NaN
# Cell Tower Address               NaN
# Name: 56, dtype: object
#
# row:  (57, Seizure DateTime              5/3/2020 16:41
# CallTypeId                         911 Calls
# ALI Latitude                         36.0763
# ALI Longitude                       -86.7597
# Cell Tower Address    4813 TROUSDALE DR - SE
# Name: 57, dtype: object)
#
# first item:  57
#
# second item:  Seizure DateTime              5/3/2020 16:41
# CallTypeId                         911 Calls
# ALI Latitude                         36.0763
# ALI Longitude                       -86.7597
# Cell Tower Address    4813 TROUSDALE DR - SE
# Name: 57, dtype: object
#
# row:  (58, Seizure DateTime                     5/3/2020 16:41
# CallTypeId                                911 Calls
# ALI Latitude                                36.1442
# ALI Longitude                              -86.8669
# Cell Tower Address    6019 B HILL CIRCLE - N SECTOR
# Name: 58, dtype: object)
#
# first item:  58
#
# second item:  Seizure DateTime                     5/3/2020 16:41
# CallTypeId                                911 Calls
# ALI Latitude                                36.1442
# ALI Longitude                              -86.8669
# Cell Tower Address    6019 B HILL CIRCLE - N SECTOR
# Name: 58, dtype: object
#
# row:  (59, Seizure DateTime           5/3/2020 16:42
# CallTypeId                      911 Calls
# ALI Latitude                      36.1399
# ALI Longitude                    -87.0223
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 59, dtype: object)
#
# first item:  59
#
# second item:  Seizure DateTime           5/3/2020 16:42
# CallTypeId                      911 Calls
# ALI Latitude                      36.1399
# ALI Longitude                    -87.0223
# Cell Tower Address    4206 LIBBLE RD - SW
# Name: 59, dtype: object
#
# row:  (60, Seizure DateTime       5/3/2020 16:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.0513
# ALI Longitude                -86.8261
# Cell Tower Address    WIRELESS CALLER
# Name: 60, dtype: object)
#
# first item:  60
#
# second item:  Seizure DateTime       5/3/2020 16:42
# CallTypeId                  911 Calls
# ALI Latitude                  36.0513
# ALI Longitude                -86.8261
# Cell Tower Address    WIRELESS CALLER
# Name: 60, dtype: object
#
# row:  (61, Seizure DateTime             5/3/2020 16:42
# CallTypeId                        911 Calls
# ALI Latitude                        36.1257
# ALI Longitude                      -86.8474
# Cell Tower Address    4400 HARDING PIKE - E
# Name: 61, dtype: object)
#
# first item:  61
#
# second item:  Seizure DateTime             5/3/2020 16:42
# CallTypeId                        911 Calls
# ALI Latitude                        36.1257
# ALI Longitude                      -86.8474
# Cell Tower Address    4400 HARDING PIKE - E
# Name: 61, dtype: object
#
# row:  (62, Seizure DateTime           5/3/2020 16:43
# CallTypeId                      911 Calls
# ALI Latitude                      35.9003
# ALI Longitude                    -86.4936
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 62, dtype: object)
#
# first item:  62
#
# second item:  Seizure DateTime           5/3/2020 16:43
# CallTypeId                      911 Calls
# ALI Latitude                      35.9003
# ALI Longitude                    -86.4936
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 62, dtype: object
#
# row:  (63, Seizure DateTime                        5/3/2020 16:43
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0674
# ALI Longitude                                  -86.899
# Cell Tower Address    398D CHIMNEY HILL RD-HWY 70 - SE
# Name: 63, dtype: object)
#
# first item:  63
#
# second item:  Seizure DateTime                        5/3/2020 16:43
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0674
# ALI Longitude                                  -86.899
# Cell Tower Address    398D CHIMNEY HILL RD-HWY 70 - SE
# Name: 63, dtype: object
#
# row:  (64, Seizure DateTime              5/3/2020 16:43
# CallTypeId                         911 Calls
# ALI Latitude                         36.1258
# ALI Longitude                       -86.8476
# Cell Tower Address    4400 HARDING PIKE - NW
# Name: 64, dtype: object)
#
# first item:  64
#
# second item:  Seizure DateTime              5/3/2020 16:43
# CallTypeId                         911 Calls
# ALI Latitude                         36.1258
# ALI Longitude                       -86.8476
# Cell Tower Address    4400 HARDING PIKE - NW
# Name: 64, dtype: object
#
# row:  (65, Seizure DateTime                    5/3/2020 16:43
# CallTypeId                               911 Calls
# ALI Latitude                               36.1208
# ALI Longitude                             -86.7326
# Cell Tower Address    2620 Glenrose AV - NW Sector
# Name: 65, dtype: object)
#
# first item:  65
#
# second item:  Seizure DateTime                    5/3/2020 16:43
# CallTypeId                               911 Calls
# ALI Latitude                               36.1208
# ALI Longitude                             -86.7326
# Cell Tower Address    2620 Glenrose AV - NW Sector
# Name: 65, dtype: object
#
# row:  (66, Seizure DateTime                 5/3/2020 16:43
# CallTypeId                            911 Calls
# ALI Latitude                            36.1017
# ALI Longitude                          -86.8715
# Cell Tower Address    5801C OLD HARDING RD - SW
# Name: 66, dtype: object)
#
# first item:  66
#
# second item:  Seizure DateTime                 5/3/2020 16:43
# CallTypeId                            911 Calls
# ALI Latitude                            36.1017
# ALI Longitude                          -86.8715
# Cell Tower Address    5801C OLD HARDING RD - SW
# Name: 66, dtype: object
#
# row:  (67, Seizure DateTime                 5/3/2020 16:43
# CallTypeId                            911 Calls
# ALI Latitude                            36.0151
# ALI Longitude                          -86.7076
# Cell Tower Address    6329A NOLENSVILLE RD - SE
# Name: 67, dtype: object)
#
# first item:  67
#
# second item:  Seizure DateTime                 5/3/2020 16:43
# CallTypeId                            911 Calls
# ALI Latitude                            36.0151
# ALI Longitude                          -86.7076
# Cell Tower Address    6329A NOLENSVILLE RD - SE
# Name: 67, dtype: object
#
# row:  (68, Seizure DateTime                 5/3/2020 16:44
# CallTypeId                            911 Calls
# ALI Latitude                            36.2655
# ALI Longitude                          -86.7361
# Cell Tower Address    524 BOYDS HILLTOP DR - SW
# Name: 68, dtype: object)
#
# first item:  68
#
# second item:  Seizure DateTime                 5/3/2020 16:44
# CallTypeId                            911 Calls
# ALI Latitude                            36.2655
# ALI Longitude                          -86.7361
# Cell Tower Address    524 BOYDS HILLTOP DR - SW
# Name: 68, dtype: object
#
# row:  (69, Seizure DateTime       5/3/2020 16:44
# CallTypeId                  911 Calls
# ALI Latitude                  36.2089
# ALI Longitude                -86.7089
# Cell Tower Address    WIRELESS CALLER
# Name: 69, dtype: object)
#
# first item:  69
#
# second item:  Seizure DateTime       5/3/2020 16:44
# CallTypeId                  911 Calls
# ALI Latitude                  36.2089
# ALI Longitude                -86.7089
# Cell Tower Address    WIRELESS CALLER
# Name: 69, dtype: object
#
# row:  (70, Seizure DateTime          5/3/2020 16:44
# CallTypeId                     911 Calls
# ALI Latitude                     36.1181
# ALI Longitude                   -86.7784
# Cell Tower Address    2938B VAULX LN - N
# Name: 70, dtype: object)
#
# first item:  70
#
# second item:  Seizure DateTime          5/3/2020 16:44
# CallTypeId                     911 Calls
# ALI Latitude                     36.1181
# ALI Longitude                   -86.7784
# Cell Tower Address    2938B VAULX LN - N
# Name: 70, dtype: object
#
# row:  (71, Seizure DateTime        5/3/2020 16:44
# CallTypeId                   911 Calls
# ALI Latitude                    36.164
# ALI Longitude                 -86.7591
# Cell Tower Address    755 S 5TH ST - E
# Name: 71, dtype: object)
#
# first item:  71
#
# second item:  Seizure DateTime        5/3/2020 16:44
# CallTypeId                   911 Calls
# ALI Latitude                    36.164
# ALI Longitude                 -86.7591
# Cell Tower Address    755 S 5TH ST - E
# Name: 71, dtype: object
#
# row:  (72, Seizure DateTime                      5/3/2020 16:44
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.0533
# ALI Longitude                               -86.6785
# Cell Tower Address    5138 MOUNT VIEW RD - SW SECTOR
# Name: 72, dtype: object)
#
# first item:  72
#
# second item:  Seizure DateTime                      5/3/2020 16:44
# CallTypeId                                 911 Calls
# ALI Latitude                                 36.0533
# ALI Longitude                               -86.6785
# Cell Tower Address    5138 MOUNT VIEW RD - SW SECTOR
# Name: 72, dtype: object
#
# row:  (73, Seizure DateTime                 5/3/2020 16:45
# CallTypeId                            911 Calls
# ALI Latitude                            36.1017
# ALI Longitude                          -86.8715
# Cell Tower Address    5801C OLD HARDING RD - SW
# Name: 73, dtype: object)
#
# first item:  73
#
# second item:  Seizure DateTime                 5/3/2020 16:45
# CallTypeId                            911 Calls
# ALI Latitude                            36.1017
# ALI Longitude                          -86.8715
# Cell Tower Address    5801C OLD HARDING RD - SW
# Name: 73, dtype: object
#
# row:  (74, Seizure DateTime                    5/3/2020 16:45
# CallTypeId                               911 Calls
# ALI Latitude                               36.0839
# ALI Longitude                              -86.705
# Cell Tower Address    1267 ANTIOCH PKE - SECTOR SW
# Name: 74, dtype: object)
#
# first item:  74
#
# second item:  Seizure DateTime                    5/3/2020 16:45
# CallTypeId                               911 Calls
# ALI Latitude                               36.0839
# ALI Longitude                              -86.705
# Cell Tower Address    1267 ANTIOCH PKE - SECTOR SW
# Name: 74, dtype: object
#
# row:  (75, Seizure DateTime       5/3/2020 16:45
# CallTypeId                  911 Calls
# ALI Latitude                  36.1452
# ALI Longitude                -86.7616
# Cell Tower Address    WIRELESS CALLER
# Name: 75, dtype: object)
# first item:  75
#
# second item:  Seizure DateTime       5/3/2020 16:45
# CallTypeId                  911 Calls
# ALI Latitude                  36.1452
# ALI Longitude                -86.7616
# Cell Tower Address    WIRELESS CALLER
# Name: 75, dtype: object
#
# row:  (76, Seizure DateTime                  5/3/2020 16:45
# CallTypeId                             911 Calls
# ALI Latitude                             36.1342
# ALI Longitude                           -86.7582
# Cell Tower Address    510 INTERSTATE BLVD S - SW
# Name: 76, dtype: object)
#
# first item:  76
#
# second item:  Seizure DateTime                  5/3/2020 16:45
# CallTypeId                             911 Calls
# ALI Latitude                             36.1342
# ALI Longitude                           -86.7582
# Cell Tower Address    510 INTERSTATE BLVD S - SW
# Name: 76, dtype: object
#
# row:  (77, Seizure DateTime                 5/3/2020 16:46
# CallTypeId                            911 Calls
# ALI Latitude                            36.0388
# ALI Longitude                          -86.7418
# Cell Tower Address    5712A EDMONDSON PIKE - SE
# Name: 77, dtype: object)
#
# first item:  77
#
# second item:  Seizure DateTime                 5/3/2020 16:46
# CallTypeId                            911 Calls
# ALI Latitude                            36.0388
# ALI Longitude                          -86.7418
# Cell Tower Address    5712A EDMONDSON PIKE - SE
# Name: 77, dtype: object
#
# row:  (78, Seizure DateTime                   5/3/2020 16:46
# CallTypeId                              911 Calls
# ALI Latitude                              36.2507
# ALI Longitude                            -86.6898
# Cell Tower Address    607E LARKIN SPRINGS RD - SW
# Name: 78, dtype: object)
#
# first item:  78
#
# second item:  Seizure DateTime                   5/3/2020 16:46
# CallTypeId                              911 Calls
# ALI Latitude                              36.2507
# ALI Longitude                            -86.6898
# Cell Tower Address    607E LARKIN SPRINGS RD - SW
# Name: 78, dtype: object
#
# row:  (79, Seizure DateTime                   5/3/2020 16:46
# CallTypeId                              911 Calls
# ALI Latitude                              36.2595
# ALI Longitude                            -86.6787
# Cell Tower Address    96 D VANDIVER DR - SECTOR S
# Name: 79, dtype: object)
#
# first item:  79
#
# second item:  Seizure DateTime                   5/3/2020 16:46
# CallTypeId                              911 Calls
# ALI Latitude                              36.2595
# ALI Longitude                            -86.6787
# Cell Tower Address    96 D VANDIVER DR - SECTOR S
# Name: 79, dtype: object
#
# row:  (80, Seizure DateTime           5/3/2020 16:46
# CallTypeId                      911 Calls
# ALI Latitude                      36.1345
# ALI Longitude                    -86.6324
# Cell Tower Address    3342 E LAKE DR - SW
# Name: 80, dtype: object)
#
# first item:  80
#
# second item:  Seizure DateTime           5/3/2020 16:46
# CallTypeId                      911 Calls
# ALI Latitude                      36.1345
# ALI Longitude                    -86.6324
# Cell Tower Address    3342 E LAKE DR - SW
# Name: 80, dtype: object
#
# row:  (81, Seizure DateTime                 5/3/2020 16:46
# CallTypeId                            911 Calls
# ALI Latitude                            36.0151
# ALI Longitude                          -86.7076
# Cell Tower Address    6329A NOLENSVILLE RD - SE
# Name: 81, dtype: object)
#
# first item:  81
#
# second item:  Seizure DateTime                 5/3/2020 16:46
# CallTypeId                            911 Calls
# ALI Latitude                            36.0151
# ALI Longitude                          -86.7076
# Cell Tower Address    6329A NOLENSVILLE RD - SE
# Name: 81, dtype: object
#
# row:  (82, Seizure DateTime             5/3/2020 16:47
# CallTypeId                        911 Calls
# ALI Latitude                        36.0778
# ALI Longitude                       -87.027
# Cell Tower Address    8013 C MCCRORY LN - N
# Name: 82, dtype: object)
#
# first item:  82
#
# second item:  Seizure DateTime             5/3/2020 16:47
# CallTypeId                        911 Calls
# ALI Latitude                        36.0778
# ALI Longitude                       -87.027
# Cell Tower Address    8013 C MCCRORY LN - N
# Name: 82, dtype: object
#
# row:  (83, Seizure DateTime                    5/3/2020 16:47
# CallTypeId                               911 Calls
# ALI Latitude                               36.3874
# ALI Longitude                             -86.8962
# Cell Tower Address    4451A OLD COOPERTOWN RD - SE
# Name: 83, dtype: object)
#
# first item:  83
#
# second item:  Seizure DateTime                    5/3/2020 16:47
# CallTypeId                               911 Calls
# ALI Latitude                               36.3874
# ALI Longitude                             -86.8962
# Cell Tower Address    4451A OLD COOPERTOWN RD - SE
# Name: 83, dtype: object
#
# row:  (84, Seizure DateTime                       5/3/2020 16:47
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.0401
# ALI Longitude                                -86.7379
# Cell Tower Address    483 OLD HICKORY BLVD - E SECTOR
# Name: 84, dtype: object)
#
# first item:  84
#
# second item:  Seizure DateTime                       5/3/2020 16:47
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.0401
# ALI Longitude                                -86.7379
# Cell Tower Address    483 OLD HICKORY BLVD - E SECTOR
# Name: 84, dtype: object
#
# row:  (85, Seizure DateTime             5/3/2020 16:47
# CallTypeId                        911 Calls
# ALI Latitude                        36.1267
# ALI Longitude                      -86.7701
# Cell Tower Address    88C OCEANSIDE DR - SW
# Name: 85, dtype: object)
#
# first item:  85
#
# second item:  Seizure DateTime             5/3/2020 16:47
# CallTypeId                        911 Calls
# ALI Latitude                        36.1267
# ALI Longitude                      -86.7701
# Cell Tower Address    88C OCEANSIDE DR - SW
# Name: 85, dtype: object
#
# row:  (86, Seizure DateTime       5/3/2020 16:48
# CallTypeId                  911 Calls
# ALI Latitude                   36.047
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 86, dtype: object)
#
# first item:  86
#
# second item:  Seizure DateTime       5/3/2020 16:48
# CallTypeId                  911 Calls
# ALI Latitude                   36.047
# ALI Longitude                -86.7504
# Cell Tower Address    WIRELESS CALLER
# Name: 86, dtype: object
#
# row:  (87, Seizure DateTime                        5/3/2020 16:48
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0962
# ALI Longitude                                 -86.7868
# Cell Tower Address    3901 GRANNY WHITE PKE - SECTOR S
# Name: 87, dtype: object)
#
# first item:  87
#
# ...
# Cell Tower Address    WIRELESS CALLER
# Name: 1521, dtype: object)
#
# first item:  1521
#
# second item:  Seizure DateTime       5/3/2020 23:48
# CallTypeId                  911 Calls
# ALI Latitude                  36.1499
# ALI Longitude                -86.8155
# Cell Tower Address    WIRELESS CALLER
# Name: 1521, dtype: object
#
# row:  (1522, Seizure DateTime      5/3/2020 23:48
# CallTypeId                 911 Calls
# ALI Latitude                  36.252
# ALI Longitude                -86.716
# Cell Tower Address     118 EMMITT AV
# Name: 1522, dtype: object)
#
# first item:  1522
#
# second item:  Seizure DateTime      5/3/2020 23:48
# CallTypeId                 911 Calls
# ALI Latitude                  36.252
# ALI Longitude                -86.716
# Cell Tower Address     118 EMMITT AV
# Name: 1522, dtype: object
#
# row:  (1523, Seizure DateTime                        5/3/2020 23:49
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.081
# ALI Longitude                                 -86.8975
# Cell Tower Address    398D CHIMNEY HILL RD-HWY 70 - NE
# Name: 1523, dtype: object)
#
# first item:  1523
#
# second item:  Seizure DateTime                        5/3/2020 23:49
# CallTypeId                                   911 Calls
# ALI Latitude                                    36.081
# ALI Longitude                                 -86.8975
# Cell Tower Address    398D CHIMNEY HILL RD-HWY 70 - NE
# Name: 1523, dtype: object
#
# row:  (1524, Seizure DateTime      5/3/2020 23:49
# CallTypeId                 911 Calls
# ALI Latitude                  36.252
# ALI Longitude                -86.716
# Cell Tower Address     118 EMMITT AV
# Name: 1524, dtype: object)
#
# first item:  1524
#
# second item:  Seizure DateTime      5/3/2020 23:49
# CallTypeId                 911 Calls
# ALI Latitude                  36.252
# ALI Longitude                -86.716
# Cell Tower Address     118 EMMITT AV
# Name: 1524, dtype: object
#
# row:  (1525, Seizure DateTime              5/3/2020 23:50
# CallTypeId                         911 Calls
# ALI Latitude                         36.1322
# ALI Longitude                       -86.7262
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 1525, dtype: object)
#
# first item:  1525
#
# second item:  Seizure DateTime              5/3/2020 23:50
# CallTypeId                         911 Calls
# ALI Latitude                         36.1322
# ALI Longitude                       -86.7262
# Cell Tower Address    1825A LEBANON PIKE - N
# Name: 1525, dtype: object
#
# row:  (1526, Seizure DateTime                            5/3/2020 23:54
# CallTypeId                                       911 Calls
# ALI Latitude                                       36.2429
# ALI Longitude                                     -86.7687
# Cell Tower Address    2955 BRICK CHURCH PARKWAY - N SECTOR
# Name: 1526, dtype: object)
#
# first item:  1526
#
# second item:  Seizure DateTime                            5/3/2020 23:54
# CallTypeId                                       911 Calls
# ALI Latitude                                       36.2429
# ALI Longitude                                     -86.7687
# Cell Tower Address    2955 BRICK CHURCH PARKWAY - N SECTOR
# Name: 1526, dtype: object
#
# row:  (1527, Seizure DateTime                            5/3/2020 23:54
# CallTypeId                                       911 Calls
# ALI Latitude                                       36.2681
# ALI Longitude                                     -86.7771
# Cell Tower Address    2955 BRICK CHURCH PARKWAY - N SECTOR
# Name: 1527, dtype: object)
#
# first item:  1527
#
# second item:  Seizure DateTime                            5/3/2020 23:54
# CallTypeId                                       911 Calls
# ALI Latitude                                       36.2681
# ALI Longitude                                     -86.7771
# Cell Tower Address    2955 BRICK CHURCH PARKWAY - N SECTOR
# Name: 1527, dtype: object
#
# row:  (1528, Seizure DateTime           5/3/2020 23:56
# CallTypeId                      911 Calls
# ALI Latitude                      36.0204
# ALI Longitude                    -86.6383
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 1528, dtype: object)
#
# first item:  1528
#
# second item:  Seizure DateTime           5/3/2020 23:56
# CallTypeId                      911 Calls
# ALI Latitude                      36.0204
# ALI Longitude                    -86.6383
# Cell Tower Address    WIRELESS 911 CALLER
# Name: 1528, dtype: object
#
# row:  (1529, Seizure DateTime             5/3/2020 23:56
# CallTypeId                        911 Calls
# ALI Latitude                        36.1325
# ALI Longitude                      -86.8126
# Cell Tower Address    2126 BERNARD AVE - NE
# Name: 1529, dtype: object)
#
# first item:  1529
#
# second item:  Seizure DateTime             5/3/2020 23:56
# CallTypeId                        911 Calls
# ALI Latitude                        36.1325
# ALI Longitude                      -86.8126
# Cell Tower Address    2126 BERNARD AVE - NE
# Name: 1529, dtype: object
#
# row:  (1530, Seizure DateTime                5/3/2020 23:58
# CallTypeId                           911 Calls
# ALI Latitude                           36.1988
# ALI Longitude                         -86.6092
# Cell Tower Address    3009D DARRINGTON WAY - N
# Name: 1530, dtype: object)
#
# first item:  1530
#
# second item:  Seizure DateTime                5/3/2020 23:58
# CallTypeId                           911 Calls
# ALI Latitude                           36.1988
# ALI Longitude                         -86.6092
# Cell Tower Address    3009D DARRINGTON WAY - N
# Name: 1530, dtype: object
#
# row:  (1531, Seizure DateTime       5/3/2020 23:59
# CallTypeId                  911 Calls
# ALI Latitude                  36.0717
# ALI Longitude                -86.9114
# Cell Tower Address    WIRELESS CALLER
# Name: 1531, dtype: object)
#
# first item:  1531
#
# second item:  Seizure DateTime       5/3/2020 23:59
# CallTypeId                  911 Calls
# ALI Latitude                  36.0717
# ALI Longitude                -86.9114
# Cell Tower Address    WIRELESS CALLER
# Name: 1531, dtype: object
#
# row:  (1532, Seizure DateTime                    5/4/2020 0:03
# CallTypeId                              911 Calls
# ALI Latitude                               36.182
# ALI Longitude                             -86.604
# Cell Tower Address    5655 FIRST BLVD - SECTOR NE
# Name: 1532, dtype: object)
#
# first item:  1532
#
# second item:  Seizure DateTime                    5/4/2020 0:03
# CallTypeId                              911 Calls
# ALI Latitude                               36.182
# ALI Longitude                             -86.604
# Cell Tower Address    5655 FIRST BLVD - SECTOR NE
# Name: 1532, dtype: object
#
# row:  (1533, Seizure DateTime                   5/4/2020 0:04
# CallTypeId                             911 Calls
# ALI Latitude                             36.1773
# ALI Longitude                           -86.6072
# Cell Tower Address    5655 FIRST BLVD - SECTOR N
# Name: 1533, dtype: object)
#
# first item:  1533
#
# second item:  Seizure DateTime                   5/4/2020 0:04
# CallTypeId                             911 Calls
# ALI Latitude                             36.1773
# ALI Longitude                           -86.6072
# Cell Tower Address    5655 FIRST BLVD - SECTOR N
# Name: 1533, dtype: object
#
# row:  (1534, Seizure DateTime               5/4/2020 0:06
# CallTypeId                         911 Calls
# ALI Latitude                         36.0248
# ALI Longitude                       -86.7432
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1534, dtype: object)
#
# first item:  1534
#
# second item:  Seizure DateTime               5/4/2020 0:06
# CallTypeId                         911 Calls
# ALI Latitude                         36.0248
# ALI Longitude                       -86.7432
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1534, dtype: object
#
# row:  (1535, Seizure DateTime                           5/4/2020 0:08
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.0467
# ALI Longitude                                   -86.6699
# Cell Tower Address    5171 HICKORY HOLLOW PKY - W Sector
# Name: 1535, dtype: object)
#
# first item:  1535
#
# second item:  Seizure DateTime                           5/4/2020 0:08
# CallTypeId                                     911 Calls
# ALI Latitude                                     36.0467
# ALI Longitude                                   -86.6699
# Cell Tower Address    5171 HICKORY HOLLOW PKY - W Sector
# Name: 1535, dtype: object
#
# row:  (1536, Seizure DateTime                         5/4/2020 0:09
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0573
# ALI Longitude                                 -86.7406
# Cell Tower Address    5244-C EDMONSON PIKE - SECTOR SE
# Name: 1536, dtype: object)
#
# first item:  1536
#
# second item:  Seizure DateTime                         5/4/2020 0:09
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0573
# ALI Longitude                                 -86.7406
# Cell Tower Address    5244-C EDMONSON PIKE - SECTOR SE
# Name: 1536, dtype: object
#
# row:  (1537, Seizure DateTime                        5/4/2020 0:09
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.2112
# ALI Longitude                                -86.7651
# Cell Tower Address    1991 SOUTHERLAND DR - SECTOR SE
# Name: 1537, dtype: object)
#
# first item:  1537
#
# second item:  Seizure DateTime                        5/4/2020 0:09
# CallTypeId                                  911 Calls
# ALI Latitude                                  36.2112
# ALI Longitude                                -86.7651
# Cell Tower Address    1991 SOUTHERLAND DR - SECTOR SE
# Name: 1537, dtype: object
#
# row:  (1538, Seizure DateTime        5/4/2020 0:10
# CallTypeId                  911 Calls
# ALI Latitude                  36.2432
# ALI Longitude                -86.6706
# Cell Tower Address    WIRELESS CALLER
# Name: 1538, dtype: object)
#
# first item:  1538
#
# second item:  Seizure DateTime        5/4/2020 0:10
# CallTypeId                  911 Calls
# ALI Latitude                  36.2432
# ALI Longitude                -86.6706
# Cell Tower Address    WIRELESS CALLER
# Name: 1538, dtype: object
#
# row:  (1539, Seizure DateTime               5/4/2020 0:10
# CallTypeId                         911 Calls
# ALI Latitude                         36.0423
# ALI Longitude                       -86.7434
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1539, dtype: object)
#
# first item:  1539
#
# second item:  Seizure DateTime               5/4/2020 0:10
# CallTypeId                         911 Calls
# ALI Latitude                         36.0423
# ALI Longitude                       -86.7434
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1539, dtype: object
#
# row:  (1540, Seizure DateTime                    5/4/2020 0:12
# CallTypeId                              911 Calls
# ALI Latitude                              36.0678
# ALI Longitude                            -86.6233
# Cell Tower Address    2747E MURFREESBORO PKE - SE
# Name: 1540, dtype: object)
#
# first item:  1540
#
# second item:  Seizure DateTime                    5/4/2020 0:12
# CallTypeId                              911 Calls
# ALI Latitude                              36.0678
# ALI Longitude                            -86.6233
# Cell Tower Address    2747E MURFREESBORO PKE - SE
# Name: 1540, dtype: object
#
# row:  (1541, Seizure DateTime                   5/4/2020 0:15
# CallTypeId                             911 Calls
# ALI Latitude                              36.048
# ALI Longitude                           -86.7066
# Cell Tower Address    565 Benzing RD - Sector NW
# Name: 1541, dtype: object)
#
# first item:  1541
#
# second item:  Seizure DateTime                   5/4/2020 0:15
# CallTypeId                             911 Calls
# ALI Latitude                              36.048
# ALI Longitude                           -86.7066
# Cell Tower Address    565 Benzing RD - Sector NW
# Name: 1541, dtype: object
#
# row:  (1542, Seizure DateTime        5/4/2020 0:16
# CallTypeId                  911 Calls
# ALI Latitude                  36.1113
# ALI Longitude                -86.8342
# Cell Tower Address    WIRELESS CALLER
# Name: 1542, dtype: object)
#
# first item:  1542
#
# second item:  Seizure DateTime        5/4/2020 0:16
# CallTypeId                  911 Calls
# ALI Latitude                  36.1113
# ALI Longitude                -86.8342
# Cell Tower Address    WIRELESS CALLER
# Name: 1542, dtype: object
#
# row:  (1543, Seizure DateTime        5/4/2020 0:16
# CallTypeId                  911 Calls
# ALI Latitude                  36.0679
# ALI Longitude                 -86.623
# Cell Tower Address    WIRELESS CALLER
# Name: 1543, dtype: object)
#
# first item:  1543
#
# second item:  Seizure DateTime        5/4/2020 0:16
# CallTypeId                  911 Calls
# ALI Latitude                  36.0679
# ALI Longitude                 -86.623
# Cell Tower Address    WIRELESS CALLER
# Name: 1543, dtype: object
#
# row:  (1544, Seizure DateTime                     5/4/2020 0:18
# CallTypeId                               911 Calls
# ALI Latitude                               36.1317
# ALI Longitude                             -86.7705
# Cell Tower Address    1823-C 12TH AV - SECTOR SE S
# Name: 1544, dtype: object)
#
# first item:  1544
#
# second item:  Seizure DateTime                     5/4/2020 0:18
# CallTypeId                               911 Calls
# ALI Latitude                               36.1317
# ALI Longitude                             -86.7705
# Cell Tower Address    1823-C 12TH AV - SECTOR SE S
# Name: 1544, dtype: object
#
# row:  (1545, Seizure DateTime                         5/4/2020 0:22
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0422
# ALI Longitude                                 -86.7435
# Cell Tower Address    5244-C EDMONSON PIKE - SECTOR SE
# Name: 1545, dtype: object)
#
# first item:  1545
#
# second item:  Seizure DateTime                         5/4/2020 0:22
# CallTypeId                                   911 Calls
# ALI Latitude                                   36.0422
# ALI Longitude                                 -86.7435
# Cell Tower Address    5244-C EDMONSON PIKE - SECTOR SE
# Name: 1545, dtype: object
#
# row:  (1546, Seizure DateTime                            5/4/2020 0:25
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.0777
# ALI Longitude                                    -86.6556
# Cell Tower Address    2747-B MURFREESBORO PKE - SECTOR NW
# Name: 1546, dtype: object)
#
# first item:  1546
#
# second item:  Seizure DateTime                            5/4/2020 0:25
# CallTypeId                                      911 Calls
# ALI Latitude                                      36.0777
# ALI Longitude                                    -86.6556
# Cell Tower Address    2747-B MURFREESBORO PKE - SECTOR NW
# Name: 1546, dtype: object
#
# row:  (1547, Seizure DateTime               5/4/2020 0:29
# CallTypeId                         911 Calls
# ALI Latitude                         36.0247
# ALI Longitude                       -86.7436
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1547, dtype: object)
#
# first item:  1547
#
# second item:  Seizure DateTime               5/4/2020 0:29
# CallTypeId                         911 Calls
# ALI Latitude                         36.0247
# ALI Longitude                       -86.7436
# Cell Tower Address    302 SUMMIT VIEW DR - E
# Name: 1547, dtype: object
#
# row:  (1548, Seizure DateTime              5/4/2020 0:29
# CallTypeId                        911 Calls
# ALI Latitude                            NaN
# ALI Longitude                           NaN
# Cell Tower Address    2014 QUAIL HOLLOW CIR
# Name: 1548, dtype: object)
#
# first item:  1548
#
# second item:  Seizure DateTime              5/4/2020 0:29
# CallTypeId                        911 Calls
# ALI Latitude                            NaN
# ALI Longitude                           NaN
# Cell Tower Address    2014 QUAIL HOLLOW CIR
# Name: 1548, dtype: object

# %%
for ind, row in derecho_dispatch.iterrows():
    print('ind: ', ind, '\n')
    print('row: ', row, '\n')
# Out:
# ind:  0
#
# row:  IncidentDate                5/3/2020 4:31:07 PM
# Location                       901 KENWICK CT W
# Latitude1                               36.0469
# Longitude1                             -86.9625
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 0, dtype: object
#
# ind:  1
#
# row:  IncidentDate                5/3/2020 4:32:18 PM
# Location                          8036 ARBOR DR
# Latitude1                               36.0825
# Longitude1                             -86.9407
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 1, dtype: object
#
# ind:  2
#
# row:  IncidentDate                5/3/2020 4:32:23 PM
# Location                      119 DUE WEST AV E
# Latitude1                                36.248
# Longitude1                             -86.7169
# IncidentTypeDescription1         NOT ALERT COPD
# Name: 2, dtype: object
#
# ind:  3
#
# row:  IncidentDate                5/3/2020 4:33:04 PM
# Location                     630 GALLATIN PKE S
# Latitude1                               36.2565
# Longitude1                             -86.7148
# IncidentTypeDescription1         ABDOMINAL PAIN
# Name: 3, dtype: object
#
# ind:  4
#
# row:  IncidentDate                5/3/2020 4:33:52 PM
# Location                      615 W HILLWOOD DR
# Latitude1                               36.1297
# Longitude1                             -86.8798
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 4, dtype: object
#
# ind:  5
#
# row:  IncidentDate                5/3/2020 4:33:53 PM
# Location                    622 BROOK HOLLOW RD
# Latitude1                               36.1118
# Longitude1                             -86.8881
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 5, dtype: object
#
# ind:  6
#
# row:  IncidentDate                            5/3/2020 4:34:19 PM
# Location                    JOCELYN HOLLOW RD / BRESSLYN RD
# Latitude1                                           36.1033
# Longitude1                                         -86.8981
# IncidentTypeDescription1                  ELECTRICAL HAZARD
# Name: 6, dtype: object
#
# ind:  7
#
# row:  IncidentDate                                          5/3/2020 4:35:01 PM
# Location                                           WOODLAND ST / S 7TH ST
# Latitude1                                                         36.1736
# Longitude1                                                       -86.7603
# IncidentTypeDescription1    SEIZURE: EFFECTIVE BREATHING NOT VERIFIED >35
# Name: 7, dtype: object
#
# ind:  8
#
# row:  IncidentDate                                        5/3/2020 4:36:42 PM
# Location                                                3000 POSTON AV
# Latitude1                                                       36.1453
# Longitude1                                                     -86.8154
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 8, dtype: object
#
# ind:  9
#
# row:  IncidentDate                        5/3/2020 4:37:04 PM
# Location                    51ST AV N / CENTENNIAL BLVD
# Latitude1                                       36.1623
# Longitude1                                     -86.8491
# IncidentTypeDescription1              ELECTRICAL HAZARD
# Name: 9, dtype: object
#
# ind:  10
#
# row:  IncidentDate                5/3/2020 4:37:30 PM
# Location                        3525 CENTRAL AV
# Latitude1                               36.1372
# Longitude1                             -86.8253
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 10, dtype: object
#
# ind:  11
#
# row:  IncidentDate                             5/3/2020 4:37:40 PM
# Location                                     114 PROSPECT HL
# Latitude1                                            36.1135
# Longitude1                                          -86.8431
# IncidentTypeDescription1    CITIZEN ASSIST UNKNOWN SITUATION
# Name: 11, dtype: object
#
# ind:  12
#
# row:  IncidentDate                5/3/2020 4:37:53 PM
# Location                         4911 ELKINS AV
# Latitude1                               36.1496
# Longitude1                             -86.8469
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 12, dtype: object
#
# ind:  13
#
# row:  IncidentDate                      5/3/2020 4:38:45 PM
# Location                                4313 ESTES RD
# Latitude1                                     36.0976
# Longitude1                                   -86.8391
# IncidentTypeDescription1    PINNED OR TRAPPED VICTIM:
# Name: 13, dtype: object
#
# ind:  14
#
# row:  IncidentDate                5/3/2020 4:39:11 PM
# Location                      2801 WHITE OAK DR
# Latitude1                                36.122
# Longitude1                             -86.8122
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 14, dtype: object
#
# ind:  15
#
# row:  IncidentDate                5/3/2020 4:39:18 PM
# Location                       2108 W LINDEN AV
# Latitude1                               36.1277
# Longitude1                             -86.8048
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 15, dtype: object
#
# ind:  16
#
# row:  IncidentDate                                        5/3/2020 4:39:33 PM
# Location                                               2106 FAIRFAX AV
# Latitude1                                                       36.1344
# Longitude1                                                     -86.8021
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 16, dtype: object
#
# ind:  17
#
# row:  IncidentDate                 5/3/2020 4:39:57 PM
# Location                    8715 OLD HARDING PKE
# Latitude1                                36.0125
# Longitude1                              -87.0246
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 17, dtype: object
#
# ind:  18
#
# row:  IncidentDate                                        5/3/2020 4:40:05 PM
# Location                                               188 THOMPSON LN
# Latitude1                                                       36.1109
# Longitude1                                                     -86.7393
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 18, dtype: object
#
# ind:  19
#
# row:  IncidentDate                5/3/2020 4:41:02 PM
# Location                      836 HILLWOOD BLVD
# Latitude1                               36.1376
# Longitude1                             -86.8786
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 19, dtype: object
#
# ind:  20
#
# row:  IncidentDate                5/3/2020 4:41:33 PM
# Location                       6535 MARAUDER DR
# Latitude1                               36.1449
# Longitude1                             -86.8886
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 20, dtype: object
#
# ind:  21
#
# row:  IncidentDate                5/3/2020 4:42:01 PM
# Location                       3718 WOODMONT LN
# Latitude1                               36.1118
# Longitude1                             -86.8381
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 21, dtype: object
#
# ind:  22
#
# row:  IncidentDate                                        5/3/2020 4:42:13 PM
# Location                                                 1310 24TH AV S
# Latitude1                                                       36.1421
# Longitude1                                                     -86.8039
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 22, dtype: object
#
# ind:  23
#
# row:  IncidentDate                           5/3/2020 4:43:10 PM
# Location                                 5105 BLUE HOLE RD
# Latitude1                                          36.0523
# Longitude1                                        -86.6728
# IncidentTypeDescription1    GENERAL ALARM HIGH LIFE HAZARD
# Name: 23, dtype: object
#
# ind:  24
#
# row:  IncidentDate                  5/3/2020 4:43:33 PM
# Location                    4206 BELMONT PARK TER
# Latitude1                                 36.0999
# Longitude1                               -86.8051
# IncidentTypeDescription1        ELECTRICAL HAZARD
# Name: 24, dtype: object
#
# ind:  25
#
# row:  IncidentDate                                        5/3/2020 4:43:37 PM
# Location                                        607B LARKIN SPRINGS RD
# Latitude1                                                       36.2536
# Longitude1                                                     -86.6857
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 25, dtype: object
#
# ind:  26
#
# row:  IncidentDate                5/3/2020 4:43:59 PM
# Location                            102 ROSE ST
# Latitude1                               36.1231
# Longitude1                             -86.7405
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 26, dtype: object
#
# ind:  27
#
# row:  IncidentDate                5/3/2020 4:44:27 PM
# Location                    517 BROOK HOLLOW RD
# Latitude1                                36.109
# Longitude1                             -86.8886
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 27, dtype: object
#
# ind:  28
#
# row:  IncidentDate                5/3/2020 4:44:40 PM
# Location                     5025 EDMONDSON PKE
# Latitude1                               36.0704
# Longitude1                              -86.735
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 28, dtype: object
#
# ind:  29
#
# row:  IncidentDate                5/3/2020 4:45:51 PM
# Location                     6007 CLOVERLAND DR
# Latitude1                               36.0304
# Longitude1                             -86.7484
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 29, dtype: object
#
# ind:  30
#
# row:  IncidentDate                                            5/3/2020 4:46:03 PM
# Location                                             SEWANEE RD / TYNE BLVD
# Latitude1                                                           36.0807
# Longitude1                                                         -86.7991
# IncidentTypeDescription1    NO INJURIES (UNCONFIRMED OR >5 PERSONS INVOLVED
# Name: 30, dtype: object
#
# ind:  31
#
# row:  IncidentDate                                            5/3/2020 4:46:03 PM
# Location                                             SEWANEE RD / TYNE BLVD
# Latitude1                                                           36.0807
# Longitude1                                                         -86.7991
# IncidentTypeDescription1    NO INJURIES (UNCONFIRMED OR >5 PERSONS INVOLVED
# Name: 31, dtype: object
#
# ind:  32
#
# row:  IncidentDate                                        5/3/2020 4:46:29 PM
# Location                                              531 DONELSON PKE
# Latitude1                                                       36.1466
# Longitude1                                                     -86.6658
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 32, dtype: object
#
# ind:  33
#
# row:  IncidentDate                5/3/2020 4:46:40 PM
# Location                         60 TUSCULUM RD
# Latitude1                               36.0531
# Longitude1                             -86.6785
# IncidentTypeDescription1       RESIDENTIAL FIRE
# Name: 33, dtype: object
#
# ind:  34
#
# row:  IncidentDate                5/3/2020 4:47:08 PM
# Location                           16 N HILL ST
# Latitude1                               36.1453
# Longitude1                             -86.7616
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 34, dtype: object
#
# ind:  35
#
# row:  IncidentDate                         5/3/2020 4:47:29 PM
# Location                    HARDING PL / NOLENSVILLE PKE
# Latitude1                                        36.0796
# Longitude1                                      -86.7263
# IncidentTypeDescription1                   MVA INJURIES:
# Name: 35, dtype: object
#
# ind:  36
# row:  IncidentDate                                        5/3/2020 4:48:18 PM
# Location                                               555 MARRIOTT DR
# Latitude1                                                       36.1511
# Longitude1                                                     -86.6899
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 36, dtype: object
#
# ind:  37
#
# row:  IncidentDate                5/3/2020 4:48:53 PM
# Location                            511 ELBA DR
# Latitude1                               36.3297
# Longitude1                              -86.695
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 37, dtype: object
#
# ind:  38
#
# row:  IncidentDate                                  5/3/2020 4:49:06 PM
# Location                                        500 CHEYENNE BLVD
# Latitude1                                                 36.2596
# Longitude1                                               -86.6787
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 38, dtype: object
#
# ind:  39
#
# row:  IncidentDate                      5/3/2020 4:49:30 PM
# Location                    S DOUGLAS AV / ELLIOTT AV
# Latitude1                                     36.1311
# Longitude1                                   -86.7811
# IncidentTypeDescription1            ELECTRICAL HAZARD
# Name: 39, dtype: object
#
# ind:  40
#
# row:  IncidentDate                5/3/2020 4:49:38 PM
# Location                        854 KIRKWOOD AV
# Latitude1                               36.1208
# Longitude1                             -86.7823
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 40, dtype: object
#
# ind:  41
#
# row:  IncidentDate                                        5/3/2020 4:49:41 PM
# Location                                                  3960 BELL RD
# Latitude1                                                       36.1665
# Longitude1                                                     -86.6038
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 41, dtype: object
#
# ind:  42
#
# row:  IncidentDate                                        5/3/2020 4:49:41 PM
# Location                                                  3960 BELL RD
# Latitude1                                                       36.1665
# Longitude1                                                     -86.6038
# IncidentTypeDescription1    GENERAL ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 42, dtype: object
#
# ind:  43
#
# row:  IncidentDate                   5/3/2020 4:49:46 PM
# Location                    8495 SYCAMORE CREEK RD
# Latitude1                                  36.3873
# Longitude1                                -86.8963
# IncidentTypeDescription1         ELECTRICAL HAZARD
# Name: 43, dtype: object
#
# ind:  44
#
# row:  IncidentDate                5/3/2020 4:50:01 PM
# Location                            513 HILL RD
# Latitude1                               36.0472
# Longitude1                             -86.7505
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 44, dtype: object
#
# ind:  45
#
# row:  IncidentDate                5/3/2020 4:50:51 PM
# Location                       80 BROOKWOOD TER
# Latitude1                               36.1304
# Longitude1                             -86.8598
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 45, dtype: object
#
# ind:  46
#
# row:  IncidentDate                             5/3/2020 4:51:19 PM
# Location                    OLD HICKORY BLVD / EDMONDSON PKE
# Latitude1                                              36.04
# Longitude1                                          -86.7435
# IncidentTypeDescription1                   MVA OTHER HAZARDS
# Name: 46, dtype: object
#
# ind:  47
#
# row:  IncidentDate                             5/3/2020 4:51:19 PM
# Location                    OLD HICKORY BLVD / EDMONDSON PKE
# Latitude1                                              36.04
# Longitude1                                          -86.7435
# IncidentTypeDescription1                   MVA OTHER HAZARDS
# Name: 47, dtype: object
#
# ind:  48
#
# row:  IncidentDate                         5/3/2020 4:51:45 PM
# Location                              922 SUTTON HILL RD
# Latitude1                                        36.1142
# Longitude1                                       -86.783
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 48, dtype: object
#
# ind:  49
#
# row:  IncidentDate                5/3/2020 4:52:15 PM
# Location                           900 TOWER PL
# Latitude1                               36.0964
# Longitude1                             -86.7868
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 49, dtype: object
#
# ind:  50
#
# row:  IncidentDate                5/3/2020 4:52:45 PM
# Location                          4900 DANBY DR
# Latitude1                               36.0741
# Longitude1                             -86.7457
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 50, dtype: object
#
# ind:  51
#
# row:  IncidentDate                      5/3/2020 4:53:06 PM
# Location                                 1613 ELM RUN
# Latitude1                                     36.1354
# Longitude1                                   -86.6348
# IncidentTypeDescription1    LIGHTNING STRIKE TO HOUSE
# Name: 51, dtype: object
#
# ind:  52
#
# row:  IncidentDate                  5/3/2020 4:54:59 PM
# Location                    8655 WHITES CREEK PKE
# Latitude1                                  36.385
# Longitude1                               -86.8978
# IncidentTypeDescription1         RESIDENTIAL FIRE
# Name: 52, dtype: object
#
# ind:  53
#
# row:  IncidentDate                         5/3/2020 4:55:32 PM
# Location                         14TH AV N / BUCHANAN ST
# Latitude1                                        36.1801
# Longitude1                                      -86.8077
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 53, dtype: object
#
# ind:  54
#
# row:  IncidentDate                5/3/2020 4:55:53 PM
# Location                         1706 22ND AV N
# Latitude1                               36.1774
# Longitude1                             -86.8123
# IncidentTypeDescription1       SMALL GRASS FIRE
# Name: 54, dtype: object
#
# ind:  55
#
# row:  IncidentDate                5/3/2020 4:56:30 PM
# Location                         2044 HUTTON DR
# Latitude1                               36.1282
# Longitude1                             -86.7495
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 55, dtype: object
#
# ind:  56
#
# row:  IncidentDate                5/3/2020 4:57:01 PM
# Location                        718 BRESSLYN RD
# Latitude1                               36.1189
# Longitude1                             -86.8793
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 56, dtype: object
#
# ind:  57
#
# row:  IncidentDate                5/3/2020 4:58:06 PM
# Location                    903 ARBOR LAKE BLVD
# Latitude1                               36.1642
# Longitude1                             -86.6006
# IncidentTypeDescription1         APARTMENT FIRE
# Name: 57, dtype: object
#
# ind:  58
#
# row:  IncidentDate                         5/3/2020 4:58:24 PM
# Location                              808 CLOVERFIELD CT
# Latitude1                                        36.0265
# Longitude1                                      -86.7614
# IncidentTypeDescription1    SMALL BUILDING INVESTIGATION
# Name: 58, dtype: object
#
# ind:  59
#
# row:  IncidentDate                5/3/2020 4:58:53 PM
# Location                         1718 STOKES LN
# Latitude1                               36.1184
# Longitude1                             -86.8049
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 59, dtype: object
#
# ind:  60
#
# row:  IncidentDate                5/3/2020 4:59:07 PM
# Location                        5016 RAGLAND DR
# Latitude1                               36.0711
# Longitude1                             -86.7708
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 60, dtype: object
#
# ind:  61
#
# row:  IncidentDate                           5/3/2020 4:59:33 PM
# Location                                  990 GREERLAND DR
# Latitude1                                          36.1008
# Longitude1                                        -86.7899
# IncidentTypeDescription1    ELECTRICAL HAZARD - WIRES DOWN
# Name: 61, dtype: object
#
# ind:  62
#
# row:  IncidentDate                5/3/2020 5:00:52 PM
# Location                      5004 FRANKLIN PKE
# Latitude1                               36.0712
# Longitude1                             -86.7733
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 62, dtype: object
#
# ind:  63
#
# row:  IncidentDate                            5/3/2020 5:00:56 PM
# Location                    W HAMILTON RD / CLARKSVILLE PKE
# Latitude1                                           36.2083
# Longitude1                                         -86.8396
# IncidentTypeDescription1                  ELECTRICAL HAZARD
# Name: 63, dtype: object
#
# ind:  64
#
# row:  IncidentDate                5/3/2020 5:01:49 PM
# Location                    5944 LONG MEADOW RD
# Latitude1                               36.1085
# Longitude1                             -86.8699
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 64, dtype: object
#
# ind:  65
#
# row:  IncidentDate                5/3/2020 5:02:38 PM
# Location                      2416 RIDGELAND DR
# Latitude1                               36.2012
# Longitude1                             -86.6792
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 65, dtype: object
#
# ind:  66
#
# row:  IncidentDate                   5/3/2020 5:02:52 PM
# Location                        110 MOCKINGBIRD RD
# Latitude1                                  36.1321
# Longitude1                                -86.8359
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 66, dtype: object
#
# ind:  67
#
# row:  IncidentDate                                  5/3/2020 5:03:52 PM
# Location                                         3021 ANDERSON RD
# Latitude1                                                 36.0735
# Longitude1                                               -86.6215
# IncidentTypeDescription1    UNCONFIRMED ENTRAPMENT SMALL BUILDING
# Name: 67, dtype: object
#
# ind:  68
#
# row:  IncidentDate                5/3/2020 5:04:02 PM
# Location                     2303 SPRINGDALE DR
# Latitude1                               36.1228
# Longitude1                             -86.8155
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 68, dtype: object
#
# ind:  69
#
# row:  IncidentDate                5/3/2020 5:04:26 PM
# Location                         3213 ALPINE AV
# Latitude1                               36.2019
# Longitude1                             -86.8282
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 69, dtype: object
#
# ind:  70
#
# row:  IncidentDate                   5/3/2020 5:04:26 PM
# Location                            3609 WILBUR PL
# Latitude1                                  36.1082
# Longitude1                                -86.7844
# IncidentTypeDescription1    HOUSE NATURAL GAS LEAK
# Name: 70, dtype: object
#
# ind:  71
#
# row:  IncidentDate                5/3/2020 5:04:57 PM
# Location                       1008 ANTIOCH PKE
# Latitude1                               36.0997
# Longitude1                             -86.7162
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 71, dtype: object
#
# ind:  72
#
# row:  IncidentDate                                  5/3/2020 5:05:31 PM
# Location                    OLD LEBANON DIRT RD / CHESNEY GLEN DR
# Latitude1                                                  36.189
# Longitude1                                               -86.5854
# IncidentTypeDescription1             ENTRAPMENT UNKNOWN SITUATION
# Name: 72, dtype: object
#
# ind:  73
#
# row:  IncidentDate                    5/3/2020 5:05:46 PM
# Location                           3025 ANDERSON RD
# Latitude1                                   36.0734
# Longitude1                                 -86.6212
# IncidentTypeDescription1    AVALANCHE INVESTIGATION
# Name: 73, dtype: object
#
# ind:  74
#
# row:  IncidentDate                5/3/2020 5:06:03 PM
# Location                         2928 SINBAD DR
# Latitude1                               36.1617
# Longitude1                             -86.6546
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 74, dtype: object
#
# ind:  75
#
# row:  IncidentDate                                              5/3/2020 5:06:04 PM
# Location                                                    2030 BERNARD CIR
# Latitude1                                                             36.1313
# Longitude1                                                           -86.7893
# IncidentTypeDescription1    SMOKE DETECTOR ALARM COMMERCIAL   INDUSTRIAL B...
# Name: 75, dtype: object
#
# ind:  76
#
# row:  IncidentDate                               5/3/2020 5:07:22 PM
# Location                    N NEW HOPE RD / NEW HOPE MEADOW RD
# Latitude1                                              36.1906
# Longitude1                                            -86.5816
# IncidentTypeDescription1                     ELECTRICAL HAZARD
# Name: 76, dtype: object
#
# ind:  77
#
# row:  IncidentDate                5/3/2020 5:07:35 PM
# Location                      407 HILLWOOD BLVD
# Latitude1                               36.1308
# Longitude1                             -86.8671
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 77, dtype: object
#
# ind:  78
#
# row:  IncidentDate                5/3/2020 5:08:46 PM
# Location                        3603 RAINBOW PL
# Latitude1                               36.1077
# Longitude1                             -86.7786
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 78, dtype: object
#
# ind:  79
#
# row:  IncidentDate                5/3/2020 5:09:10 PM
# Location                       4271 CENTRAL PKE
# Latitude1                               36.1739
# Longitude1                              -86.579
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 79, dtype: object
#
# ind:  80
#
# row:  IncidentDate                         5/3/2020 5:09:36 PM
# Location                         S NEW HOPE RD / BELL RD
# Latitude1                                        36.1606
# Longitude1                                      -86.5854
# IncidentTypeDescription1    ENTRAPMENT UNKNOWN SITUATION
# Name: 80, dtype: object
#
# ind:  81
#
# row:  IncidentDate                5/3/2020 5:10:04 PM
# Location                       5537 STANFORD DR
# Latitude1                               36.0821
# Longitude1                             -86.8305
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 81, dtype: object
#
# ind:  82
#
# row:  IncidentDate                5/3/2020 5:10:04 PM
# Location                        5101 HARDING PL
# Latitude1                               36.0892
# Longitude1                             -86.6874
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 82, dtype: object
#
# ind:  83
#
# row:  IncidentDate                                    5/3/2020 5:10:56 PM
# Location                                      300 SEVEN SPRINGS WAY
# Latitude1                                                   36.0421
# Longitude1                                                 -86.7681
# IncidentTypeDescription1    ELEVATOR MALFUNCTION   OCCUPANTS INSIDE
# Name: 83, dtype: object
#
# ind:  84
#
# row:  IncidentDate                        5/3/2020 5:11:01 PM
# Location                    KINWOOD DR / FOREST VIEW DR
# Latitude1                                       36.0722
# Longitude1                                     -86.6251
# IncidentTypeDescription1              ELECTRICAL HAZARD
# Name: 84, dtype: object
#
# ind:  85
#
# row:  IncidentDate                5/3/2020 5:11:03 PM
# Location                          354 BATTLE RD
# Latitude1                               35.9979
# Longitude1                             -86.6284
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 85, dtype: object
#
# ind:  86
#
# row:  IncidentDate                            5/3/2020 5:11:37 PM
# Location                    ELLINGTON PKWY S / E TRINITY LN
# Latitude1                                           36.2047
# Longitude1                                         -86.7504
# IncidentTypeDescription1                    UNKNOWN STATUS:
# Name: 86, dtype: object
#
# ind:  87
#
# row:  IncidentDate                          5/3/2020 5:12:05 PM
# Location                               5037 BONNAMEADE DR
# Latitude1                                         36.1969
# Longitude1                                       -86.6297
# IncidentTypeDescription1    UNKNOWN PROBLEM INVESTIGATION
# Name: 87, dtype: object
#
# ind:  88
#
# row:  IncidentDate                5/3/2020 5:12:40 PM
# Location                           7205 MARK DR
# Latitude1                               36.0658
# Longitude1                             -86.9288
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 88, dtype: object
#
# ind:  89
#
# row:  IncidentDate                 5/3/2020 5:13:01 PM
# Location                    741 MURFREESBORO PKE
# Latitude1                                36.1376
# Longitude1                              -86.7294
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 89, dtype: object
#
# ind:  90
#
# row:  IncidentDate                5/3/2020 5:13:06 PM
# Location                     5584 SADDLEWOOD LN
# Latitude1                               36.0249
# Longitude1                               -86.76
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 90, dtype: object
#
# ind:  91
#
# row:  IncidentDate                5/3/2020 5:13:16 PM
# Location                          700 TIMBER LN
# Latitude1                                36.122
# Longitude1                             -86.8235
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 91, dtype: object
#
# ind:  92
#
# row:  IncidentDate                            5/3/2020 5:13:29 PM
# Location                                       20 N HILL ST
# Latitude1                                           36.1453
# Longitude1                                         -86.7613
# IncidentTypeDescription1    UNKNOWN ENTRAPMENT  UNCONFIRMED
# Name: 92, dtype: object
#
# ind:  93
#
# row:  IncidentDate                5/3/2020 5:14:01 PM
# Location                         4505 BEACON DR
# Latitude1                               36.0892
# Longitude1                             -86.8453
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 93, dtype: object
#
# ind:  94
#
# row:  IncidentDate                            5/3/2020 5:14:56 PM
# Location                            14TH AV N / BUCHANAN ST
# Latitude1                                           36.1801
# Longitude1                                         -86.8077
# IncidentTypeDescription1    UNKNOWN ENTRAPMENT  UNCONFIRMED
# Name: 94, dtype: object
#
# ind:  95
#
# row:  IncidentDate                5/3/2020 5:16:10 PM
# Location                    97 WHITE BRIDGE PKE
# Latitude1                                36.131
# Longitude1                             -86.8582
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 95, dtype: object
#
# ind:  96
#
# row:  IncidentDate                         5/3/2020 5:16:22 PM
# Location                    DOWNEYMEADE DR / LEBANON PKE
# Latitude1                                        36.1818
# Longitude1                                      -86.6416
# IncidentTypeDescription1              SMALL OUTSIDE FIRE
# Name: 96, dtype: object
#
# ind:  97
#
# row:  IncidentDate                5/3/2020 5:16:31 PM
# Location                       4348 CENTRAL PKE
# Latitude1                               36.1736
# Longitude1                             -86.5726
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 97, dtype: object
#
# ind:  98
#
# row:  IncidentDate                5/3/2020 5:17:06 PM
# Location                       2202 SHERIDAN RD
# Latitude1                               36.1928
# Longitude1                             -86.7148
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 98, dtype: object
#
# ind:  99
#
# row:  IncidentDate                 5/3/2020 5:17:09 PM
# Location                      1437 BELL TRACE DR
# Latitude1                                36.0403
# Longitude1                              -86.6708
# IncidentTypeDescription1    ENTRAPMENT / TRAPPED
# Name: 99, dtype: object
#
# ind:  100
#
# row:  IncidentDate                           5/3/2020 5:17:14 PM
# Location                                    632 ROXANNE DR
# Latitude1                                          36.0491
# Longitude1                                         -86.691
# IncidentTypeDescription1    ELECTRICAL HAZARD - WIRES DOWN
# Name: 100, dtype: object
#
# ind:  101
#
# row:  IncidentDate                         5/3/2020 5:17:45 PM
# Location                             2951 NED SHELTON RD
# Latitude1                                        36.1012
# Longitude1                                      -86.6355
# IncidentTypeDescription1    ENTRAPMENT UNKNOWN SITUATION
# Name: 101, dtype: object
#
# ind:  102
#
# row:  IncidentDate                                     5/3/2020 5:17:48 PM
# Location                                            2025 CALDWELL DR
# Latitude1                                                      36.33
# Longitude1                                                  -86.7006
# IncidentTypeDescription1    CARBON MONOXIDE FIRE ALARM INVESTIGATION
# Name: 102, dtype: object
#
# ind:  103
#
# row:  IncidentDate                5/3/2020 5:18:01 PM
# Location                        415 TUSCULUM RD
# Latitude1                               36.0585
# Longitude1                             -86.7179
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 103, dtype: object
#
# ind:  104
#
# row:  IncidentDate                5/3/2020 5:18:01 PM
# Location                        415 TUSCULUM RD
# Latitude1                               36.0585
# Longitude1                             -86.7179
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 104, dtype: object
#
# ind:  105
#
# row:  IncidentDate                            5/3/2020 5:18:55 PM
# Location                                    6424 PREMIER DR
# Latitude1                                           36.1471
# Longitude1                                         -86.8766
# IncidentTypeDescription1    RESIDENTIAL FIRE PERSON TRAPPED
# Name: 105, dtype: object
#
# ind:  106
#
# row:  IncidentDate                5/3/2020 5:19:09 PM
# Location                        3223 LINCOLN AV
# Latitude1                               36.2016
# Longitude1                             -86.8298
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 106, dtype: object
#
# ind:  107
#
# row:  IncidentDate                5/3/2020 5:20:18 PM
# Location                     610 CONTINENTAL DR
# Latitude1                               36.1465
# Longitude1                             -86.8878
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 107, dtype: object
#
# ind:  108
#
# row:  IncidentDate                5/3/2020 5:20:23 PM
# Location                     6203 CHARLOTTE PKE
# Latitude1                               36.1467
# Longitude1                             -86.8695
# IncidentTypeDescription1     SMALL OUTSIDE FIRE
# Name: 108, dtype: object
#
# ind:  109
#
# row:  IncidentDate                                    5/3/2020 5:20:25 PM
# Location                                              625 BENTON AV
# Latitude1                                                   36.1314
# Longitude1                                                 -86.7706
# IncidentTypeDescription1    ELEVATOR MALFUNCTION   OCCUPANTS INSIDE
# Name: 109, dtype: object
#
# ind:  110
#
# row:  IncidentDate                5/3/2020 5:20:40 PM
# Location                       502 PATTERSON ST
# Latitude1                               36.1032
# Longitude1                             -86.7452
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 110, dtype: object
#
# ind:  111
#
# row:  IncidentDate                5/3/2020 5:21:28 PM
# Location                             103 JAY ST
# Latitude1                               36.1189
# Longitude1                             -86.7414
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 111, dtype: object
#
# ind:  112
#
# row:  IncidentDate                5/3/2020 5:21:31 PM
# Location                         2126 ACKLEN AV
# Latitude1                               36.1361
# Longitude1                             -86.8036
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 112, dtype: object
#
# ind:  113
#
# row:  IncidentDate                5/3/2020 5:22:33 PM
# Location                          1408 VILLA PL
# Latitude1                                 36.14
# Longitude1                             -86.7922
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 113, dtype: object
#
# ind:  114
#
# row:  IncidentDate                5/3/2020 5:22:55 PM
# Location                          1030 VILLA PL
# Latitude1                               36.1444
# Longitude1                             -86.7915
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 114, dtype: object
#
# ind:  115
#
# row:  IncidentDate                5/3/2020 5:23:15 PM
# Location                       1853 PRIMROSE AV
# Latitude1                               36.1222
# Longitude1                             -86.8027
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 115, dtype: object
#
# ind:  116
#
# row:  IncidentDate                 5/3/2020 5:25:03 PM
# Location                      1651 CHICKERING RD
# Latitude1                                36.0598
# Longitude1                              -86.8745
# IncidentTypeDescription1    ENTRAPMENT / TRAPPED
# Name: 116, dtype: object
#
# ind:  117
#
# row:  IncidentDate                                   5/3/2020 5:25:12 PM
# Location                    ANDREW JACKSON PKWY / HIGHLAND VIEW DR
# Latitude1                                                  36.2069
# Longitude1                                                -86.6056
# IncidentTypeDescription1                         ELECTRICAL HAZARD
# Name: 117, dtype: object
#
# ind:  118
#
# row:  IncidentDate                5/3/2020 5:25:14 PM
# Location                           446 ANNEX AV
# Latitude1                               36.1477
# Longitude1                             -86.8868
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 118, dtype: object
#
# ind:  119
#
# row:  IncidentDate                5/3/2020 5:25:14 PM
# Location                    836 BROOK HOLLOW RD
# Latitude1                                36.132
# Longitude1                             -86.8829
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 119, dtype: object
#
# ind:  120
#
# row:  IncidentDate                5/3/2020 5:26:40 PM
# Location                        1516 ELM RUN CT
# Latitude1                               36.1365
# Longitude1                             -86.6357
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 120, dtype: object
#
# ind:  121
#
# row:  IncidentDate                  5/3/2020 5:26:43 PM
# Location                    8449 ROLLING HILLS DR
# Latitude1                                 36.0878
# Longitude1                               -86.9845
# IncidentTypeDescription1        ELECTRICAL HAZARD
# Name: 121, dtype: object
#
# ind:  122
#
# row:  IncidentDate                              5/3/2020 5:28:03 PM
# Location                    LEBANON PKE / ANDREW JACKSON PKWY
# Latitude1                                             36.2151
# Longitude1                                           -86.5977
# IncidentTypeDescription1                         OUTSIDE ODOR
# Name: 122, dtype: object
#
# ind:  123
#
# row:  IncidentDate                               5/3/2020 5:28:04 PM
# Location                                       2910 HOBSON PKE
# Latitude1                                              36.0925
# Longitude1                                            -86.5554
# IncidentTypeDescription1    MAN DOWN: LIFE STATUS QUESTIONABLE
# Name: 123, dtype: object
#
# ind:  124
#
# row:  IncidentDate                5/3/2020 5:28:07 PM
# Location                        876 GLENDALE LN
# Latitude1                               36.0927
# Longitude1                             -86.7852
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 124, dtype: object
#
# ind:  125
#
# row:  IncidentDate                     5/3/2020 5:28:43 PM
# Location                             2410 ELLIOTT AV
# Latitude1                                    36.1259
# Longitude1                                  -86.7787
# IncidentTypeDescription1    HEART PROBLEMS NOT ALERT
# Name: 125, dtype: object
#
# ind:  126
#
# row:  IncidentDate                5/3/2020 5:28:59 PM
# Location                     4341 CHICKERING LN
# Latitude1                               36.0633
# Longitude1                             -86.8657
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 126, dtype: object
#
# ind:  127
#
# row:  IncidentDate                5/3/2020 5:29:19 PM
# Location                      497 RURAL HILL RD
# Latitude1                               36.0804
# Longitude1                             -86.6252
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 127, dtype: object
#
# ind:  128
#
# row:  IncidentDate                5/3/2020 5:31:19 PM
# Location                       600 DRY CREEK RD
# Latitude1                               36.3121
# Longitude1                             -86.7536
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 128, dtype: object
#
# ind:  129
#
# row:  IncidentDate                              5/3/2020 5:32:26 PM
# Location                    SUGAR VALLEY DR / NOLENSVILLE PKE
# Latitude1                                             36.0154
# Longitude1                                           -86.7057
# IncidentTypeDescription1                    ELECTRICAL HAZARD
# Name: 129, dtype: object
#
# ind:  130
#
# row:  IncidentDate                5/3/2020 5:32:37 PM
# Location                          195 KENNER AV
# Latitude1                               36.1197
# Longitude1                             -86.8412
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 130, dtype: object
#
# ind:  131
#
# row:  IncidentDate                5/3/2020 5:32:49 PM
# Location                      5608 STONEWAY TRL
# Latitude1                               36.1368
# Longitude1                              -86.859
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 131, dtype: object
#
# ind:  132
#
# row:  IncidentDate                   5/3/2020 5:32:52 PM
# Location                           768 HAYSTACK LN
# Latitude1                                  36.0717
# Longitude1                                -86.6844
# IncidentTypeDescription1    UKNOWN ALARM APARTMENT
# Name: 132, dtype: object
#
# ind:  133
#
# row:  IncidentDate                5/3/2020 5:33:20 PM
# Location                     1155 RURAL HILL RD
# Latitude1                                36.067
# Longitude1                             -86.6439
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 133, dtype: object
#
# ind:  134
#
# row:  IncidentDate                5/3/2020 5:35:25 PM
# Location                     1208 MARITIME PORT
# Latitude1                               36.0533
# Longitude1                             -86.5983
# IncidentTypeDescription1       RESIDENTIAL FIRE
# Name: 134, dtype: object
#
# ind:  135
#
# row:  IncidentDate                5/3/2020 5:35:48 PM
# Location                           450 ANNEX AV
# Latitude1                               36.1483
# Longitude1                             -86.8858
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 135, dtype: object
#
# ind:  136
#
# row:  IncidentDate                5/3/2020 5:36:04 PM
# Location                          617 LEMONT DR
# Latitude1                               36.2348
# Longitude1                             -86.7438
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 136, dtype: object
#
# ind:  137
#
# row:  IncidentDate                5/3/2020 5:37:16 PM
# Location                        2305 BERNARD AV
# Latitude1                               36.1315
# Longitude1                             -86.8053
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 137, dtype: object
#
# ind:  138
#
# row:  IncidentDate                 5/3/2020 5:38:11 PM
# Location                    2012 BAKERS GROVE LN
# Latitude1                                36.1031
# Longitude1                              -86.5519
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 138, dtype: object
#
# ind:  139
#
# row:  IncidentDate                              5/3/2020 5:38:48 PM
# Location                    BAKERS GROVE LN / BAKERS GROVE RD
# Latitude1                                             36.1034
# Longitude1                                            -86.553
# IncidentTypeDescription1                 ENTRAPMENT / TRAPPED
# Name: 139, dtype: object
#
# ind:  140
#
# row:  IncidentDate                                5/3/2020 5:39:07 PM
# Location                                      930 INDUSTRIAL DR
# Latitude1                                                36.264
# Longitude1                                             -86.6589
# IncidentTypeDescription1    DIFFICULTY SPEAKING BETWEEN BREATHS
# Name: 140, dtype: object
#
# ind:  141
#
# row:  IncidentDate                5/3/2020 5:39:41 PM
# Location                       1516 FERGUSON AV
# Latitude1                               36.1195
# Longitude1                             -86.7938
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 141, dtype: object
#
# ind:  142
#
# row:  IncidentDate                             5/3/2020 5:40:21 PM
# Location                                    1445 ANTIOCH PKE
# Latitude1                                            36.0807
# Longitude1                                          -86.6866
# IncidentTypeDescription1    BUILDING ENTRAPMENT  UNCONFIRMED
# Name: 142, dtype: object
#
# ind:  143
#
# row:  IncidentDate                5/3/2020 5:41:06 PM
# Location                          3031 JENRY DR
# Latitude1                               36.1766
# Longitude1                             -86.6485
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 143, dtype: object
#
# ind:  144
#
# row:  IncidentDate                5/3/2020 5:41:34 PM
# Location                      511 BELLE POST RD
# Latitude1                                36.104
# Longitude1                             -86.8713
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 144, dtype: object
#
# ind:  145
#
# row:  IncidentDate                5/3/2020 5:42:01 PM
# Location                         MM 211 8 I40 E
# Latitude1                               36.1489
# Longitude1                             -86.7466
# IncidentTypeDescription1          MVA INJURIES:
# Name: 145, dtype: object
#
# ind:  146
#
# row:  IncidentDate                 5/3/2020 5:42:14 PM
# Location                    1899 BAKERS GROVE RD
# Latitude1                                36.1116
# Longitude1                              -86.5629
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 146, dtype: object
#
# ind:  147
#
# row:  IncidentDate                5/3/2020 5:42:21 PM
# Location                         2824 BRONTE AV
# Latitude1                               36.2003
# Longitude1                             -86.7366
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 147, dtype: object
#
# ind:  148
#
# row:  IncidentDate                5/3/2020 5:43:38 PM
# Location                        2406 OAKLAND AV
# Latitude1                               36.1267
# Longitude1                             -86.7951
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 148, dtype: object
#
# ind:  149
#
# row:  IncidentDate                5/3/2020 5:44:21 PM
# Location                         4608 ELKINS AV
# Latitude1                               36.1501
# Longitude1                              -86.843
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 149, dtype: object
#
# ind:  150
#
# row:  IncidentDate                5/3/2020 5:45:23 PM
# Location                      249 BONNACROFT DR
# Latitude1                               36.1984
# Longitude1                             -86.6255
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 150, dtype: object
#
# ind:  151
#
# row:  IncidentDate                5/3/2020 5:45:42 PM
# Location                      2618 WOODBERRY DR
# Latitude1                               36.1606
# Longitude1                             -86.6705
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 151, dtype: object
#
# ind:  152
#
# row:  IncidentDate                5/3/2020 5:46:00 PM
# Location                     5837 BEAUREGARD DR
# Latitude1                               36.0699
# Longitude1                             -86.8222
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 152, dtype: object
#
# ind:  153
#
# row:  IncidentDate                5/3/2020 5:46:24 PM
# Location                      534 NORTHCREST DR
# Latitude1                               36.0668
# Longitude1                             -86.7261
# IncidentTypeDescription1      ELECTRICAL HAZARD
# Name: 153, dtype: object
#
# ind:  154
#
# row:  IncidentDate                5/3/2020 5:46:42 PM
# ...
#
# ind:  578
#
# row:  IncidentDate                    5/3/2020 10:38:41 PM
# Location                    4216 ANDREW JACKSON PKWY
# Latitude1                                    36.1988
# Longitude1                                  -86.6091
# IncidentTypeDescription1           ELECTRICAL HAZARD
# Name: 578, dtype: object
#
# ind:  579
#
# row:  IncidentDate                5/3/2020 10:41:34 PM
# Location                          2205 REVERE PL
# Latitude1                                36.1712
# Longitude1                              -86.6901
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 579, dtype: object
#
# ind:  580
#
# row:  IncidentDate                5/3/2020 10:41:34 PM
# Location                          2205 REVERE PL
# Latitude1                                36.1712
# Longitude1                              -86.6901
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 580, dtype: object
#
# ind:  581
#
# row:  IncidentDate                               5/3/2020 10:42:02 PM
# Location                                          200 CHEOAH CT
# Latitude1                                               36.0084
# Longitude1                                              -86.683
# IncidentTypeDescription1    DIFFICULTY SPEAKING BETWEEN BREATHS
# Name: 581, dtype: object
#
# ind:  582
#
# row:  IncidentDate                5/3/2020 10:42:36 PM
# Location                        1120 WOODVALE DR
# Latitude1                                36.1023
# Longitude1                              -86.7958
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 582, dtype: object
#
# ind:  583
#
# row:  IncidentDate                5/3/2020 10:44:58 PM
# Location                           181 DELVIN DR
# Latitude1                                36.0521
# Longitude1                              -86.6914
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 583, dtype: object
#
# ind:  584
#
# row:  IncidentDate                5/3/2020 10:47:23 PM
# Location                           1501 CEDAR LN
# Latitude1                                36.1201
# Longitude1                              -86.7932
# IncidentTypeDescription1     GENERAL ALARM HOUSE
# Name: 584, dtype: object
#
# ind:  585
#
# row:  IncidentDate                5/3/2020 10:50:39 PM
# Location                             425 HART AV
# Latitude1                                36.1822
# Longitude1                               -86.756
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 585, dtype: object
#
# ind:  586
#
# row:  IncidentDate                              5/3/2020 10:53:00 PM
# Location                                        205 ANTHONY ST
# Latitude1                                              36.2416
# Longitude1                                            -86.6294
# IncidentTypeDescription1    NOT ALERT STRONG EVIDENCE <3 HOURS
# Name: 586, dtype: object
#
# ind:  587
#
# row:  IncidentDate                5/3/2020 10:55:43 PM
# Location                        912 TAVISTOCK PL
# Latitude1                                36.0803
# Longitude1                              -86.6632
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 587, dtype: object
#
# ind:  588
#
# row:  IncidentDate                                    5/3/2020 10:56:18 PM
# Location                                            3803 WOODMONT LN
# Latitude1                                                    36.1113
# Longitude1                                                  -86.8407
# IncidentTypeDescription1    CARBON MONOXIDE FIRE ALARM INVESTIGATION
# Name: 588, dtype: object
#
# ind:  589
#
# row:  IncidentDate                  5/3/2020 10:59:30 PM
# Location                      860 MURFREESBORO PKE
# Latitude1                                  36.1367
# Longitude1                                -86.7215
# IncidentTypeDescription1    UKNOWN ALARM APARTMENT
# Name: 589, dtype: object
#
# ind:  590
#
# row:  IncidentDate                    5/3/2020 11:01:21 PM
# Location                          3312 DICKERSON PKE
# Latitude1                                    36.2362
# Longitude1                                  -86.7591
# IncidentTypeDescription1    3RD TRIMESTER HEMORRHAGE
# Name: 590, dtype: object
#
# ind:  591
#
# row:  IncidentDate                5/3/2020 11:03:02 PM
# Location                       4107 GALLATIN PKE
# Latitude1                                36.2222
# Longitude1                              -86.7273
# IncidentTypeDescription1               NOT ALERT
# Name: 591, dtype: object
#
# ind:  592
#
# row:  IncidentDate                          5/3/2020 11:03:23 PM
# Location                    NEWSOM STATION RD / HIGHWAY 70
# Latitude1                                          36.0916
# Longitude1                                         -86.987
# IncidentTypeDescription1                 ELECTRICAL HAZARD
# Name: 592, dtype: object
#
# ind:  593
#
# row:  IncidentDate                5/3/2020 11:04:52 PM
# Location                      830 GLASTONBURY RD
# Latitude1                                36.1348
# Longitude1                              -86.7008
# IncidentTypeDescription1      SMALL OUTSIDE FIRE
# Name: 593, dtype: object
#
# ind:  594
#
# row:  IncidentDate                5/3/2020 11:05:19 PM
# Location                           1485 DOLAN RD
# Latitude1                                 36.183
# Longitude1                              -86.8435
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 594, dtype: object
#
# ind:  595
#
# row:  IncidentDate                                    5/3/2020 11:07:51 PM
# Location                                        1800 WILSON CAMP CIR
# Latitude1                                                    36.2423
# Longitude1                                                  -86.6656
# IncidentTypeDescription1    DIFFICULTY SPEAKING BETWEEN BREATHS COPD
# Name: 595, dtype: object
#
# ind:  596
#
# row:  IncidentDate                                  5/3/2020 11:12:56 PM
# Location                                           101 FOOTHILL CT
# Latitude1                                                   36.132
# Longitude1                                                -86.7194
# IncidentTypeDescription1    ABNORMAL BREATHING OTHER LUNG PROBLEMS
# Name: 596, dtype: object
#
# ind:  597
#
# row:  IncidentDate                                   5/3/2020 11:18:12 PM
# Location                    ANDREW JACKSON PKWY / ANDREW JACKSON PL
# Latitude1                                                   36.2045
# Longitude1                                                 -86.6064
# IncidentTypeDescription1                          ELECTRICAL HAZARD
# Name: 597, dtype: object
#
# ind:  598
#
# row:  IncidentDate                       5/3/2020 11:20:26 PM
# Location                                700 N DUPONT AV
# Latitude1                                       36.2661
# Longitude1                                     -86.6952
# IncidentTypeDescription1    CITIZEN ASSIST  NON MEDICAL
# Name: 598, dtype: object
#
# ind:  599
#
# row:  IncidentDate                                 5/3/2020 11:20:34 PM
# Location                    ANDREW JACKSON PKWY / STONERS GLEN DR
# Latitude1                                                 36.1927
# Longitude1                                               -86.6068
# IncidentTypeDescription1                        MVA OTHER HAZARDS
# Name: 599, dtype: object
#
# ind:  600
#
# row:  IncidentDate                5/3/2020 11:22:09 PM
# Location                        3910 CENTRAL PKE
# Latitude1                                36.1735
# Longitude1                              -86.6033
# IncidentTypeDescription1        NOT ALERT ASTHMA
# Name: 600, dtype: object
#
# ind:  601
#
# row:  IncidentDate                  5/3/2020 11:24:58 PM
# Location                        406 ENGLISH IVY DR
# Latitude1                                  36.0446
# Longitude1                                -86.7285
# IncidentTypeDescription1    SICK PERSON: NOT ALERT
# Name: 601, dtype: object
#
# ind:  602
#
# row:  IncidentDate                5/3/2020 11:26:54 PM
# Location                    20TH AV N / STATE ST
# Latitude1                                36.1544
# Longitude1                              -86.8015
# IncidentTypeDescription1          UNKNOWN STATUS
# Name: 602, dtype: object
#
# ind:  603
#
# row:  IncidentDate                      5/3/2020 11:29:24 PM
# Location                         4508 PRICE CIRCLE RD
# Latitude1                                      36.1315
# Longitude1                                    -86.8635
# IncidentTypeDescription1    MEDICAL ALARM NOTIFICATION
# Name: 603, dtype: object
#
# ind:  604
#
# row:  IncidentDate                              5/3/2020 11:30:49 PM
# Location                         2ND AV N / JUNIOR GILLIAM WAY
# Latitude1                                              36.1744
# Longitude1                                             -86.783
# IncidentTypeDescription1    CHEST PAIN - CLAMMY OR COLD SWEATS
# Name: 604, dtype: object
#
# ind:  605
#
# row:  IncidentDate                          5/3/2020 11:31:14 PM
# Location                              7533 LORDS CHAPEL DR
# Latitude1                                          36.0268
# Longitude1                                        -86.7084
# IncidentTypeDescription1    GENERAL ALARM HIGH LIFE HAZARD
# Name: 605, dtype: object
#
# ind:  606
#
# row:  IncidentDate                                      5/3/2020 11:39:35 PM
# Location                                        2022 ROSA L PARKS BLVD
# Latitude1                                                      36.1884
# Longitude1                                                    -86.7981
# IncidentTypeDescription1    TRAUMATIC INJURIES NOT DANGEROUS BODY AREA
# Name: 606, dtype: object
#
# ind:  607
#
# row:  IncidentDate                  5/3/2020 11:40:18 PM
# Location                         3225 CREEKWOOD DR
# Latitude1                                   36.233
# Longitude1                                -86.7713
# IncidentTypeDescription1    NON SUICIDAL AND ALERT
# Name: 607, dtype: object
#
# ind:  608
#
# row:  IncidentDate                   5/3/2020 11:40:18 PM
# Location                        1316 TULIP GROVE RD
# Latitude1                                    36.175
# Longitude1                                 -86.5956
# IncidentTypeDescription1    GENERAL ALARM APARTMENT
# Name: 608, dtype: object
#
# ind:  609
#
# row:  IncidentDate                                5/3/2020 11:42:00 PM
# Location                                           115 NEWELL AV
# Latitude1                                                36.2713
# Longitude1                                               -86.665
# IncidentTypeDescription1    HEART PROBLEMS CLAMMY OR COLD SWEATS
# Name: 609, dtype: object
#
# ind:  610
#
# row:  IncidentDate                             5/3/2020 11:42:08 PM
# Location                               2022 ROSA L PARKS BLVD
# Latitude1                                             36.1884
# Longitude1                                           -86.7981
# IncidentTypeDescription1    REQUEST ADDITIONAL FIRE RESOURCES
# Name: 610, dtype: object
#
# ind:  611
#
# row:  IncidentDate                                             5/3/2020 11:45:17 PM
# Location                                                2284 MURFREESBORO PKE
# Latitude1                                                             36.0884
# Longitude1                                                           -86.6475
# IncidentTypeDescription1    WATERFLOW ALARM COMMERCIAL COMMERCIAL   INDUST...
# Name: 611, dtype: object
#
# ind:  612
#
# row:  IncidentDate                5/3/2020 11:50:16 PM
# Location                           5029 SUTER DR
# Latitude1                                36.0707
# Longitude1                              -86.7377
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 612, dtype: object
#
# ind:  613
#
# row:  IncidentDate                5/3/2020 11:51:33 PM
# Location                           301 28TH AV N
# Latitude1                                36.1473
# Longitude1                              -86.8146
# IncidentTypeDescription1      ABNORMAL BREATHING
# Name: 613, dtype: object
#
# ind:  614
#
# row:  IncidentDate                       5/3/2020 11:51:51 PM
# Location                               2812 HILLSIDE DR
# Latitude1                                       36.1336
# Longitude1                                     -86.8132
# IncidentTypeDescription1    CARBON MONOXIDE ALARM HOUSE
# Name: 614, dtype: object
#
# ind:  615
#
# row:  IncidentDate                5/3/2020 11:52:44 PM
# Location                      6767 BROOKMONT TER
# Latitude1                                36.0826
# Longitude1                              -86.8977
# IncidentTypeDescription1     DIABETIC: NOT ALERT
# Name: 615, dtype: object
#
# ind:  616
#
# row:  IncidentDate                       5/3/2020 11:53:07 PM
# Location                             2916 WINDEMERE CIR
# Latitude1                                       36.1869
# Longitude1                                     -86.6738
# IncidentTypeDescription1    CARBON MONOXIDE ALARM HOUSE
# Name: 616, dtype: object
#
# ind:  617
#
# row:  IncidentDate                5/3/2020 11:58:29 PM
# Location                           2618 ESSEX PL
# Latitude1                                36.1327
# Longitude1                              -86.8108
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 617, dtype: object
#
# ind:  618
#
# row:  IncidentDate                5/3/2020 11:59:51 PM
# Location                        304 ELMINGTON AV
# Latitude1                                 36.133
# Longitude1                              -86.8222
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 618, dtype: object
#
# ind:  619
#
# row:  IncidentDate                                            5/4/2020 12:05:58 AM
# Location                                                      2011 HAYES ST
# Latitude1                                                            36.1518
# Longitude1                                                          -86.8008
# IncidentTypeDescription1    PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 619, dtype: object
#
# ind:  620
#
# row:  IncidentDate                5/4/2020 12:09:25 AM
# Location                        5820 LABRADOR LN
# Latitude1                                36.0319
# Longitude1                              -86.7114
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 620, dtype: object
#
# ind:  621
#
# row:  IncidentDate                5/4/2020 12:12:37 AM
# Location                     1301 NEELYS BEND RD
# Latitude1                                36.2407
# Longitude1                              -86.6731
# IncidentTypeDescription1    FALL - NOT ON STAIRS
# Name: 621, dtype: object
#
# ind:  622
#
# row:  IncidentDate                      5/4/2020 12:21:00 AM
# Location                                 625 BENTON AV
# Latitude1                                      36.1314
# Longitude1                                    -86.7706
# IncidentTypeDescription1    HIGH RISE NATURAL GAS ODOR
# Name: 622, dtype: object
#
# ind:  623
#
# row:  IncidentDate                5/4/2020 12:21:32 AM
# Location                        518 BRENTLAWN DR
# Latitude1                                36.0644
# Longitude1                              -86.7612
# IncidentTypeDescription1          UNKNOWN STATUS
# Name: 623, dtype: object
#
# ind:  624
#
# row:  IncidentDate                5/4/2020 12:22:47 AM
# Location                           517 ALBANY DR
# Latitude1                                36.2128
# Longitude1                              -86.6004
# IncidentTypeDescription1       ELECTRICAL HAZARD
# Name: 624, dtype: object
#
# ind:  625
#
# row:  IncidentDate                             5/4/2020 12:27:52 AM
# Location                                     639 LAFAYETTE ST
# Latitude1                                             36.1538
# Longitude1                                           -86.7775
# IncidentTypeDescription1    SICK PERSON: NO PRIORITY SYMPTOMS
# Name: 625, dtype: object
#
# ind:  626
#
# row:  IncidentDate                                            5/4/2020 12:29:50 AM
# Location                                                      2011 HAYES ST
# Latitude1                                                            36.1518
# Longitude1                                                          -86.8008
# IncidentTypeDescription1    PULL STATION ALARM COMMERCIAL   INDUSTRIAL BUILD
# Name: 626, dtype: object

# %%
gini_index = pd.read_csv('data/gini_index.csv', low_memory=False)
gini_index = gini_index[['ZCTA5A','AKGVE001']]
gini_index.columns = ['zip_code', 'gini_index']
gini_index.head()
# Out:
#    zip_code  gini_index
# 0       601      0.5238
# 1       602      0.5034
# 2       603      0.5666
# 3       606      0.4818
# 4       610      0.4689

# %%
gini_index = gini_index.loc[gini_index['zip_code'].isin(['37013','37015','37027','37064','37072','37076','37080','37086'
                                                 ,'37115','37122','37135','37138','37143','37152','37189','37201'
                                                 ,'37201','37203','37204','37205','37206','37207','37208','37209'
                                                 ,'37210','37211','37212','37213','37214','37215','37216','37217'
                                                 ,'37218','37219','37220','37221','37228','37232','37240'])]
gini_index.head()
# Out:
#        zip_code  gini_index
# 11903     37013      0.3920
# 11905     37015      0.3789
# 11914     37027      0.4650
# 11942     37064      0.4394
# 11946     37072      0.4276

# %%
zipcodes = gpd.read_file('data/zipcodes.geojson')
print(zipcodes.crs)
zipcodes.head()
# Out:
# epsg:4326
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-77-fa6db80ee3f9> in <module>
#       1 zipcodes = gpd.read_file('data/zipcodes.geojson')
#       2 print(zipcodes.crs)
# ----> 3 zipcodes.drop(columns = [['objectid','shape_stlength','shape_starea']])
#       4 zipcodes.head()
#
# ~/opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165                 weight  1.0     0.8
#    4166         """
# -> 4167         return super().drop(
#    4168             labels=labels,
#    4169             axis=axis,
#
# ~/opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~/opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~/opt/anaconda3/envs/geospatial/lib/python3.8/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5282         if mask.any():
#    5283             if errors != "ignore":
# -> 5284                 raise KeyError(f"{labels[mask]} not found in axis")
#    5285             indexer = indexer[~mask]
#    5286         return self.delete(indexer)
#
# KeyError: "[('objectid', 'shape_stlength', 'shape_starea')] not found in axis"

# %%
tornado_map = folium.Map(location = [36.1612, -86.7775], zoom_start = 12)


for ind, row in tornado_calls.iterrows():
    point = [row['ALI Latitude'], row['ALI Longitude']]
    popup = row['Seizure DateTime'] + ':' + row['Cell Tower Address']
    folium.Marker(point, popup = popup, icon=folium.Icon(color='red')).add_to(tornado_map)
    
for ind, row in tornado_dispatch.iterrows():
    point = [row['Latitude1'], row['Longitude1']]
    popup = row['Location'] + row['IncidentTypeDescription1']
    folium.Marker(point, popup = popup, icon=folium.Icon(color='blue')).add_to(tornado_map)
    
       
tornado_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
